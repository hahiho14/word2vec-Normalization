# %% [markdown]
# ### Import Libraries

# %%
import nltk
import sqlite3
import pandas as pd
from gensim.models import Word2Vec
import time
from datetime import timedelta

# %% [markdown]
# ### Read database

# %%
# Create database connection.
cnx = sqlite3.connect('DBnews.db')

t_comments = pd.read_sql_query("SELECT * FROM t_comments", cnx)

# %%
t_comments
# Out:
#        comment_id                                            comment baseline  \
# 0         4207096  WKWKWK, GAK SEKALIAN PAK, SELAWAT KE DPR... KA...       -1
# 1         4207096  Mantab.. ini br dakwah yg sejati.. kl d tempat...        1
# 2         4207096                              Salut buat Gus Miftah        1
# 3         4207096  yg nyinyir gak pernah lihat dan baca atw menge...        1
# 4         4207096  Ada adabnya sholawat. Lebih baik ajak ke majel...        1
# ...           ...                                                ...      ...
# 598092    4416660  212 nggak pernah ngadain acara beginian ya.......     None
# 598093    4416660           TBG... Sayank.. salah pilih kendraaan..�     None
# 598094    4416660                     Saya bersama TGB pilih Jokowi�     None
# 598095    4416660  Hijrah dari hoax ke non hoax, dari ngawur ke b...     None
# 598096    4416660                     MAJU TERUS 01 !!! %uD83D%uDC4D     None
#
#        correct_comment  comment_ptr
# 0                 None            1
# 1                 None            2
# 2                 None            3
# 3                 None            4
# 4                 None            5
# ...                ...          ...
# 598092            None       598093
# 598093            None       598094
# 598094            None       598095
# 598095            None       598096
# 598096            None       598097
#
# [598097 rows x 5 columns]

# %% [markdown]
# ### Case Folding

# %%
t_comments['comment'] = t_comments['comment'].str.lower()

# %%
t_comments
# Out:
#        comment_id                                            comment baseline  \
# 0         4207096  wkwkwk, gak sekalian pak, selawat ke dpr... ka...       -1
# 1         4207096  mantab.. ini br dakwah yg sejati.. kl d tempat...        1
# 2         4207096                              salut buat gus miftah        1
# 3         4207096  yg nyinyir gak pernah lihat dan baca atw menge...        1
# 4         4207096  ada adabnya sholawat. lebih baik ajak ke majel...        1
# ...           ...                                                ...      ...
# 598092    4416660  212 nggak pernah ngadain acara beginian ya.......     None
# 598093    4416660           tbg... sayank.. salah pilih kendraaan..�     None
# 598094    4416660                     saya bersama tgb pilih jokowi�     None
# 598095    4416660  hijrah dari hoax ke non hoax, dari ngawur ke b...     None
# 598096    4416660                     maju terus 01 !!! %ud83d%udc4d     None
#
#        correct_comment  comment_ptr
# 0                 None            1
# 1                 None            2
# 2                 None            3
# 3                 None            4
# 4                 None            5
# ...                ...          ...
# 598092            None       598093
# 598093            None       598094
# 598094            None       598095
# 598095            None       598096
# 598096            None       598097
#
# [598097 rows x 5 columns]

# %% [markdown]
# ### Punctuation Removal

# %%
t_comments['comment'] = t_comments['comment'].str.replace('[^\w\s]','')

# %%
t_comments
# Out:
#        comment_id                                            comment baseline  \
# 0         4207096  wkwkwk gak sekalian pak selawat ke dpr kan ban...       -1
# 1         4207096  mantab ini br dakwah yg sejati kl d tempat umu...        1
# 2         4207096                              salut buat gus miftah        1
# 3         4207096  yg nyinyir gak pernah lihat dan baca atw menge...        1
# 4         4207096  ada adabnya sholawat lebih baik ajak ke majeli...        1
# ...           ...                                                ...      ...
# 598092    4416660  212 nggak pernah ngadain acara beginian yateru...     None
# 598093    4416660                   tbg sayank salah pilih kendraaan     None
# 598094    4416660                      saya bersama tgb pilih jokowi     None
# 598095    4416660  hijrah dari hoax ke non hoax dari ngawur ke be...     None
# 598096    4416660                          maju terus 01  ud83dudc4d     None
#
#        correct_comment  comment_ptr
# 0                 None            1
# 1                 None            2
# 2                 None            3
# 3                 None            4
# 4                 None            5
# ...                ...          ...
# 598092            None       598093
# 598093            None       598094
# 598094            None       598095
# 598095            None       598096
# 598096            None       598097
#
# [598097 rows x 5 columns]

# %% [markdown]
# ### Tokenizing

# %%
t_comments['comment'] = t_comments.apply(lambda row: nltk.word_tokenize(row['comment']), axis=1)

# %%
t_comments
# Out:
#        comment_id                                            comment baseline  \
# 0         4207096  [wkwkwk, gak, sekalian, pak, selawat, ke, dpr,...       -1
# 1         4207096  [mantab, ini, br, dakwah, yg, sejati, kl, d, t...        1
# 2         4207096                         [salut, buat, gus, miftah]        1
# 3         4207096  [yg, nyinyir, gak, pernah, lihat, dan, baca, a...        1
# 4         4207096  [ada, adabnya, sholawat, lebih, baik, ajak, ke...        1
# ...           ...                                                ...      ...
# 598092    4416660  [212, nggak, pernah, ngadain, acara, beginian,...     None
# 598093    4416660             [tbg, sayank, salah, pilih, kendraaan]     None
# 598094    4416660                [saya, bersama, tgb, pilih, jokowi]     None
# 598095    4416660  [hijrah, dari, hoax, ke, non, hoax, dari, ngaw...     None
# 598096    4416660                      [maju, terus, 01, ud83dudc4d]     None
#
#        correct_comment  comment_ptr
# 0                 None            1
# 1                 None            2
# 2                 None            3
# 3                 None            4
# 4                 None            5
# ...                ...          ...
# 598092            None       598093
# 598093            None       598094
# 598094            None       598095
# 598095            None       598096
# 598096            None       598097
#
# [598097 rows x 5 columns]

# %%
# get 10000 comments
t_comments = t_comments[:1000]

# get tokenized comment
tok_comments = t_comments['comment']

# %% [markdown]
# ### Preprocessing the Corpus

# %%
import csv

korpus = []

with open("korpus.csv", encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=',') # change contents to floats
    for row in reader: # each row is a list
        korpus.append(row)

# %%
korpus
# Out:
# [['Persija',
#   'Jakarta',
#   'siap',
#   'tempur',
#   'menghadapi',
#   'Selangor',
#   'FA',
#   'dalam',
#   'laga',
#   'ujicoba',
#   '.'],
#  ['Persija',
#   'ingin',
#   'kembali',
#   'ke',
#   'bentuk',
#   'terbaik',
#   'sebelum',
#   'Liga',
#   '1',
#   'kembali',
#   'digulirkan',
#   '.'],
#  ['Persija',
#   'akan',
#   'melawan',
#   'Selangor',
#   'FA',
#   'di',
#   'Stadion',
#   'Patriot',
#   'Candrabhaga',
#   'malam',
#   '.'],
#  ['Bagi',
#   'Selangor',
#   ',',
#   'ini',
#   'adalah',
#   'ujicoba',
#   'keduanya',
#   'di',
#   'Indonesia',
#   'setelah',
#   'sebelumnya',
#   'menjajal',
#   'Madura',
#   'United',
#   '.'],
#  ['Pada',
#   'laga',
#   'ujicoba',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Ratu',
#   'Pamelingan',
#   ',',
#   'Evan',
#   'Dimas',
#   'dkk',
#   'kalah',
#   'telak',
#   'dengan',
#   'skor',
#   '1-4',
#   'dari',
#   'Madura',
#   'United',
#   '.'],
#  ['Namun',
#   'yang',
#   'jelas',
#   ',',
#   'Persija',
#   'mesti',
#   'memperlihatkan',
#   'performa',
#   'apik',
#   'menjelang',
#   'laga',
#   'melawan',
#   'Borneo',
#   'pada',
#   '12',
#   'September',
#   '.'],
#  ['Kami', 'tahu', 'lawan', 'Madura', 'United', 'punya', 'kualitas', '.'],
#  ['Yang',
#   'kedua',
#   'saya',
#   'pernah',
#   'bekerja',
#   'di',
#   'Malaysia',
#   'mereka',
#   'tak',
#   'terbiasa',
#   'main',
#   'di',
#   'siang',
#   'hari',
#   '.'],
#  ['Mungkin',
#   'karena',
#   'panas',
#   'membuat',
#   'Selangor',
#   'FA',
#   'kesulitan',
#   ',',
#   'ujar',
#   'dia',
#   'kepada',
#   'pewarta',
#   'jelang',
#   'laga',
#   'di',
#   'Bekasi',
#   '.'],
#  ['Besok', 'kami', 'akan', 'main', 'di', 'malam', 'hari', 'jadi', 'fair', '.'],
#  ['Saya', 'yakin', 'besok', 'Selangor', 'akan', 'berubah', '.'],
#  ['Waktu',
#   'melawan',
#   'Madura',
#   'United',
#   'mereka',
#   'tidak',
#   'main',
#   'dengan',
#   'pemain',
#   'inti',
#   '.'],
#  ['Kami',
#   'punya',
#   'target',
#   '(',
#   'bermain',
#   ')',
#   'seperti',
#   'waktu',
#   'di',
#   'latihan',
#   '.'],
#  ['Kami',
#   'harus',
#   'sudah',
#   'main',
#   'lebih',
#   'bagus',
#   'melebihi',
#   'saat',
#   'laga',
#   'melawan',
#   'Bhayangkara',
#   'FC',
#   '.'],
#  ['Kami',
#   'harus',
#   'lebih',
#   'bagus',
#   'dari',
#   'fisik',
#   ',',
#   'taktik',
#   ',',
#   'dan',
#   'teknik',
#   '.'],
#  ['Untuk', 'berapa', 'gol', ',', 'kami', 'tidak', 'bisa', 'bicara', '.'],
#  ['Kami', 'harus', 'respek', 'sama', 'lawan', '.'],
#  ['Kami',
#   'sudah',
#   'main',
#   'lawan',
#   'Kelantan',
#   ',',
#   'dan',
#   'Johor',
#   'Darul',
#   'Takzim',
#   ',',
#   'lalu',
#   'sekarang',
#   'Selangor',
#   ',',
#   'jadi',
#   'kami',
#   'respek',
#   '.'],
#  ['Ilham', 'Udin', 'Armayn', 'juga', 'menjadi', 'sosok', 'berbahaya', '.'],
#  ['Wilian', 'sangat', 'bagus', 'waktu', 'bola', 'atas', '.'],
#  ['Dia', 'tinggi', 'dan', 'punya', 'timing', 'bagus', '.'],
#  ['Kami', 'senang', 'lawan', 'dia', 'lagi', '.'],
#  ['Kami',
#   'lihat',
#   'situasi',
#   'dalam',
#   'pertandingan',
#   ',',
#   'bisa',
#   'bola',
#   'atas',
#   'atau',
#   'bola',
#   'bawah',
#   '.'],
#  ['Dia',
#   'juga',
#   'tidak',
#   'sendiri',
#   'dan',
#   'ada',
#   'temannya',
#   'di',
#   'belakang',
#   '.'],
#  ['Kami', 'harus', 'lihat', 'siapa', 'temannya', 'di', 'belakang', '.'],
#  ['Ada', 'juga', 'Ilham', 'Udin', '.'],
#  ['Dia',
#   'pemain',
#   'bagus',
#   'seperti',
#   'yang',
#   'saya',
#   'lihat',
#   'saat',
#   'masih',
#   'membela',
#   'Bhayangkara',
#   'musim',
#   'lalu',
#   ',',
#   'dia',
#   'menambahkan',
#   '.'],
#  ['Pelatih', 'timnas', 'Indonesia', 'U-16', '.'],
#  ['Tapi',
#   ',',
#   'Fakhri',
#   'menyebut',
#   'timnya',
#   'sebenarnya',
#   'bisa',
#   'menang',
#   'dengan',
#   'skor',
#   'lebih',
#   'besar',
#   '.'],
#  ['Timnas',
#   'Indonesia',
#   'U-16',
#   'mencukur',
#   'Filipina',
#   'dengan',
#   'skor',
#   '8-0',
#   'pada',
#   'laga',
#   'pertamanya',
#   'di',
#   'ajang',
#   'Piala',
#   'AFF',
#   'U-16',
#   '.'],
#  ['Gol-gol',
#   'Garuda',
#   'Asia',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Delta',
#   ',',
#   'Sidoarjo',
#   ',',
#   'Jawa',
#   'Timur',
#   ',',
#   'dicetak',
#   'oleh',
#   'Mochammad',
#   'Supriadi',
#   ',',
#   'Komang',
#   'Teguh',
#   'Trisnanda',
#   ',',
#   'Muhammad',
#   'Fajar',
#   'Fathur',
#   ',',
#   'Sutan',
#   'Diego',
#   'Zico',
#   ',',
#   'Rendy',
#   'Juliansyah',
#   ',',
#   'David',
#   'Maulana',
#   ',',
#   'dan',
#   'pemain',
#   'pengganti',
#   'Bagus',
#   'Kahfi',
#   '(',
#   'dua',
#   'gol',
#   ')',
#   '.'],
#  ['Indonesia',
#   'unggul',
#   'selisih',
#   'gol',
#   'atas',
#   'Myanmar',
#   'dan',
#   'Vietnam',
#   'yang',
#   'punya',
#   'poin',
#   'sama',
#   '.'],
#  ['Kami',
#   'bersyukur',
#   'karena',
#   'kemenangan',
#   'ini',
#   'berkat',
#   'doa',
#   'masyarakat',
#   'Indonesia',
#   'dan',
#   'selain',
#   'itu',
#   'kami',
#   'bangga',
#   'terhadap',
#   'para',
#   'pemain',
#   '.'],
#  ['Dan',
#   'kami',
#   'bangga',
#   'dengan',
#   'permainan',
#   'mereka',
#   'karena',
#   'mampu',
#   'menjalankan',
#   'tugas',
#   'dengan',
#   'baik',
#   ',',
#   'kata',
#   'Fakhri',
#   'seusai',
#   'pertandingan',
#   '.'],
#  ['Seharusnya',
#   'timnas',
#   'U-16',
#   'ini',
#   'bisa',
#   'menang',
#   'lebih',
#   'dari',
#   'delapan',
#   'gol',
#   '.'],
#  ['Masih',
#   'banyak',
#   'peluang',
#   'yang',
#   'seharusnya',
#   'gol',
#   ',',
#   'namun',
#   'tidak',
#   'membuahkan',
#   'gol',
#   '.'],
#  ['Tapi',
#   'kami',
#   'menyadari',
#   'bahwa',
#   'permainan',
#   'bola',
#   'seperti',
#   'itu',
#   ',',
#   'tambah',
#   'Fakhri',
#   '.'],
#  ['Indonesia',
#   'selanjutnya',
#   'akan',
#   'berhadapan',
#   'dengan',
#   'Myanmar',
#   'pada',
#   'pertandingan',
#   'kedua',
#   'yang',
#   'akan',
#   'digelar',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Delta',
#   '.'],
#  ['Kami',
#   'tetap',
#   'akan',
#   'melakukan',
#   'rotasi',
#   'para',
#   'pemain',
#   'karena',
#   'kompetisi',
#   'ini',
#   'recovery',
#   'hanya',
#   'satu',
#   'hari',
#   '.'],
#  ['Untuk',
#   'menjaga',
#   'kondisi',
#   'para',
#   'pemain',
#   'harus',
#   'dirotasi',
#   ',',
#   'kata',
#   'Fakhri',
#   '.'],
#  ['Kami',
#   'akan',
#   'terus',
#   'bermain',
#   'secara',
#   'maksimal',
#   'dengan',
#   'harapan',
#   'agar',
#   'memenuhi',
#   'target',
#   'ke',
#   'final',
#   'Piala',
#   'AFF',
#   'ini',
#   '.'],
#  ['Kemenangan',
#   'ini',
#   'berkat',
#   'kerja',
#   'sama',
#   'yang',
#   'kompak',
#   'dan',
#   'komunikasi',
#   'yang',
#   'baik',
#   'antarpemain',
#   ',',
#   'ujarnya',
#   '.'],
#  ['Berkat',
#   'dukungan',
#   'ribuan',
#   'suporter',
#   'di',
#   'Stadion',
#   'Delta',
#   'Sidoarjo',
#   'ini',
#   'teman-teman',
#   'bermain',
#   'dengan',
#   'penuh',
#   'semangat',
#   '.'],
#  ['Kemenangan',
#   'ini',
#   'untuk',
#   'masyarakat',
#   'Indonesia',
#   ',',
#   'tutur',
#   'David',
#   '.'],
#  ['PT.Liga',
#   'Indonesia',
#   'Baru',
#   'akan',
#   'kembali',
#   'memberikan',
#   'dana',
#   'distribusi',
#   'dengan',
#   'total',
#   'Rp',
#   '7,5',
#   'miliar',
#   'ke',
#   'peserta',
#   'Liga',
#   '1',
#   ',',
#   'sama',
#   'sepeti',
#   'musim',
#   'lalu',
#   '.'],
#  ['Tapi', ',', 'kali', 'ini', 'dibagi', 'menjadi', 'dua', 'bagian', '.'],
#  ['Hal',
#   'tersebut',
#   'dibahas',
#   'dalam',
#   'manajer',
#   'meeting',
#   'yang',
#   'digelar',
#   'PT.LIB',
#   'bersama',
#   'perwakilan',
#   '18',
#   'klub',
#   'peserta',
#   'Liga',
#   '1',
#   'di',
#   'Hotel',
#   'Sultan',
#   '.'],
#  ['Berlinton',
#   'Siahaan',
#   'menjelaskan',
#   'bahwa',
#   'setiap',
#   'klub',
#   'akan',
#   'mendapat',
#   'Rp',
#   '5',
#   'miliar',
#   'secara',
#   'langsung',
#   '.'],
#  ['Jumlah',
#   'uang',
#   'tersebut',
#   'nantinya',
#   'dialokasikan',
#   'dengan',
#   'rentan',
#   'waktu',
#   'delapan',
#   'bulan',
#   'terhitung',
#   'sejak',
#   'April',
#   'mendatang',
#   '.'],
#  ['Cara', 'pembayarannya', 'beda', 'dari', 'tahun', 'sebelumnya', '.'],
#  ['Yang', 'kami', 'bagikan', 'langsung', 'itu', 'Rp', '5', 'miliar', '.'],
#  ['Sementara',
#   'Rp',
#   '2,5',
#   'miliar',
#   'itu',
#   'berdasarkan',
#   'dengan',
#   'penyempurnaan',
#   'dari',
#   'PSSI',
#   ',',
#   'mengenai',
#   'pengembangan',
#   'usia',
#   'muda',
#   ',',
#   'juga',
#   'masalah',
#   'lisensi',
#   ',',
#   'kata',
#   'Berlinton',
#   '.'],
#  ['Sementara',
#   'itu',
#   ',',
#   'Rp2,5',
#   'miliar',
#   'pembagiannya',
#   'disesuaikan',
#   'kebutuhan',
#   'klub',
#   '.'],
#  ['Setiap',
#   'klub',
#   'akan',
#   'menyetorkan',
#   'rincian',
#   'data',
#   'kegiatan',
#   'untuk',
#   'pengembangan',
#   'usia',
#   'muda',
#   'dan',
#   'lisensi',
#   'mereka',
#   'ke',
#   'PSSI',
#   '.'],
#  ['Nantinya',
#   ',',
#   'PSSI',
#   'akan',
#   'menyerahkan',
#   'ke',
#   'PT',
#   'LIB',
#   ',',
#   'yang',
#   'akan',
#   'memberi',
#   'dana',
#   'tersebut',
#   'kepada',
#   'setiap',
#   'klub',
#   '.'],
#  ['Bisa',
#   'saja',
#   'pembagiannya',
#   'tidak',
#   'sama',
#   'dengan',
#   'klub',
#   'satu',
#   'dengan',
#   'lainnya',
#   '.'],
#  ['Kalau',
#   'satu',
#   'klub',
#   'kegiatannya',
#   'lebih',
#   'banyak',
#   ',',
#   'bisa',
#   'saja',
#   'di',
#   'awal',
#   'pertama',
#   'dia',
#   'akan',
#   'lebih',
#   'banyak',
#   '.'],
#  ['Namun',
#   'totalnya',
#   'tetap',
#   'Rp',
#   '2,5',
#   'miliar',
#   ',',
#   'Berlinton',
#   'menambahkan',
#   '.'],
#  ['Viking', 'merayakan', 'ulang', 'tahun', 'yang', 'ke', '25', '.'],
#  ['Mereka', 'diselamati', 'oleh', 'LA', 'Mania', '.'],
#  ['Dari',
#   'pantauan',
#   'detikSport',
#   ',',
#   'seratusan',
#   'pendukung',
#   'Persela',
#   'Lamongan',
#   'lengkap',
#   'dengan',
#   'atribut',
#   'serba',
#   'berwarna',
#   'biru',
#   'muda',
#   'memenuhi',
#   'tribune',
#   'barat',
#   'samping',
#   ',',
#   'Stadion',
#   'Gelora',
#   'Bandung',
#   'Lautan',
#   'Api',
#   '(',
#   'GBLA',
#   ')',
#   ',',
#   'Kota',
#   'Bandung',
#   ',',
#   'Jawa',
#   'Barat',
#   ',',
#   'saat',
#   'laga',
#   'melawan',
#   'Persib',
#   'di',
#   'lanjutan',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Karena',
#   'Viking',
#   'Club',
#   'atau',
#   'pendukung',
#   'Persib',
#   'berulang',
#   'tahun',
#   'yang',
#   'ke',
#   '25',
#   'Tahun',
#   ',',
#   'para',
#   'pendukung',
#   'Persela',
#   'mengucapkan',
#   'selamat',
#   'dengan',
#   'menyanyikan',
#   'lagu',
#   "'selamat",
#   'ulang',
#   'tahun',
#   "'",
#   'yang',
#   'diiringi',
#   'dengan',
#   'tabuhan',
#   'alat',
#   'musik',
#   'drumband',
#   '.'],
#  ['Nyanyian',
#   'itu',
#   'nyaring',
#   'terdengar',
#   'sebelum',
#   'para',
#   'pemain',
#   'dari',
#   'ke',
#   'dua',
#   'tim',
#   'masuk',
#   'ke',
#   'lapangan',
#   'hijau',
#   '.'],
#  ['Selamat', 'ulang', 'tahun', 'Viking', 'Persib', '.'],
#  ['Sukses', 'selalu', ',', 'teriak', 'pendukung', 'LA', 'Mania', '.'],
#  ['Selain',
#   'di',
#   'tribune',
#   'barat',
#   ',',
#   'nyanyian',
#   "'Selamat",
#   'Ulang',
#   'tahun',
#   "'",
#   'juga',
#   'terdengar',
#   'di',
#   'tribun',
#   'lainnya',
#   'yang',
#   'dinyanyikan',
#   'oleh',
#   'para',
#   'pendukung',
#   'Persib',
#   '.'],
#  ['Setelah',
#   'tim',
#   'Maung',
#   'Bandung',
#   'dan',
#   'Laskar',
#   'Joko',
#   'Tingkir',
#   'masuk',
#   'ke',
#   'lapangan',
#   ',',
#   'pendukung',
#   'Persib',
#   'yang',
#   'berada',
#   'di',
#   'tribune',
#   'timur',
#   'melakukan',
#   'koreografi',
#   '.'],
#  ['Selain',
#   'itu',
#   ',',
#   'kata',
#   "'Anniversary",
#   'Viking',
#   'Persib',
#   'Club',
#   "'",
#   'dan',
#   "'25",
#   'Tahun',
#   'Tetap',
#   'Bersama',
#   "'",
#   'yang',
#   'ditulis',
#   'menggunakan',
#   'cat',
#   'berwarna',
#   'putih',
#   'di',
#   'kain',
#   'berwarna',
#   'hitam',
#   'turut',
#   'di',
#   'bentangkan',
#   'di',
#   'atas',
#   'dan',
#   'bawah',
#   'gambar',
#   'manusia',
#   'Viking',
#   '.'],
#  ['Salah',
#   'satu',
#   'pentolan',
#   'Viking',
#   ',',
#   'Agus',
#   'Ompong',
#   'berharap',
#   'dengan',
#   'bertambah',
#   'usia',
#   'pendukung',
#   'Persib',
#   'terbesar',
#   'di',
#   'Jawa',
#   'Barat',
#   'ini',
#   ',',
#   'semoga',
#   'para',
#   'pendukung',
#   'semakin',
#   'dewasa',
#   '.'],
#  ['Harapannya',
#   'semakin',
#   'bertambah',
#   'dewasa',
#   ',',
#   'dalam',
#   'menyikapi',
#   'segala',
#   'hal',
#   '.'],
#  ['Pokoknya',
#   'dukung',
#   'terus',
#   'Persib',
#   ',',
#   'ujar',
#   'Agus',
#   'di',
#   'Stadion',
#   'GBLA',
#   'Bandung',
#   '.'],
#  ['Persib',
#   'bisa',
#   'memetik',
#   'hasil',
#   'positif',
#   'di',
#   'laga',
#   'semalam',
#   '.'],
#  ['Mereka',
#   'menang',
#   '1-0',
#   'atas',
#   'Persela',
#   'berkat',
#   'gol',
#   'Jonathan',
#   'Bauman',
#   '.'],
#  ['Tim', 'nasional', 'Indonesia', 'U-16', '.'],
#  ['Garuda', 'Muda', 'kalah', 'tipis', 'dengan', 'skor', '1-2', '.'],
#  ['PT',
#   'Liga',
#   'Indonesia',
#   'Baru',
#   '(',
#   'LIB',
#   ')',
#   'memastikan',
#   'utang',
#   'dana',
#   'kontribusi',
#   'ke',
#   'peserta',
#   'Liga',
#   '1',
#   '2017',
#   'sudah',
#   'dibayar',
#   '.'],
#  ['Hari',
#   'Selasa',
#   'tunggakan',
#   'senilai',
#   'Rp',
#   '38',
#   'miliar',
#   'dilunasi',
#   '.'],
#  ['Kompetisi',
#   'Liga',
#   '1',
#   '2017',
#   'sudah',
#   'berakhir',
#   'sejak',
#   'November',
#   'lalu',
#   ',',
#   'di',
#   'mana',
#   'Bhayangkara',
#   'FC',
#   'menjadi',
#   'juara',
#   '.'],
#  ['Tapi',
#   ',',
#   'dana',
#   'kontribusi',
#   'komersial',
#   'senilai',
#   'Rp',
#   '7,5',
#   'miliar',
#   'per',
#   'klub',
#   'belum',
#   'dilunasi',
#   '.'],
#  ['Total',
#   'utang',
#   'yang',
#   'mesti',
#   'dibayar',
#   'mencapai',
#   'Rp',
#   '38.050.414.993',
#   '.'],
#  ['Hal',
#   'itu',
#   'membuat',
#   'penyelenggaraan',
#   'kick-off',
#   'Liga',
#   '1',
#   '2018',
#   'sempat',
#   'tertunda',
#   '.'],
#  ['Sampai',
#   'akhirnya',
#   ',',
#   'PT',
#   'LIB',
#   'memastikan',
#   'utang',
#   'tersebut',
#   'sudah',
#   'dilunasi',
#   '.'],
#  ['Siang',
#   'tadi',
#   ',',
#   'semua',
#   'pembayaran',
#   'untuk',
#   'pelunasan',
#   'dana',
#   'kontribusi',
#   'tersebut',
#   'sudah',
#   'kami',
#   'lunasi',
#   '.'],
#  ['Totalnya',
#   'kami',
#   'telah',
#   'mentransfer',
#   'sejumlah',
#   'Rp',
#   '38.050.414.993',
#   ',',
#   'Direktur',
#   'PT',
#   'LIB',
#   'Berlinton',
#   'Siahaan',
#   'mengatakan',
#   'dalam',
#   'rilis',
#   'yang',
#   'diterima',
#   'detikSport',
#   ',',
#   'Selasa',
#   'malam',
#   '.'],
#  ['Konferensi',
#   'pers',
#   'PT',
#   'Liga',
#   'Indonesia',
#   'Baru',
#   '(',
#   'LIB',
#   ')',
#   'soal',
#   'pelunasan',
#   'utang',
#   'dana',
#   'kontribusi',
#   'Liga',
#   '1',
#   '2017',
#   'di',
#   'Kantor',
#   'LIB',
#   '.'],
#  ['Usai',
#   'utang',
#   'dilunasi',
#   ',',
#   'PT',
#   'LIB',
#   'akan',
#   'menggelar',
#   'rapat',
#   'Rencana',
#   'Umum',
#   'Pemegang',
#   'Saham',
#   '(',
#   'RUPS',
#   ')',
#   '.'],
#  ['Rencananya',
#   'RUPS',
#   'akan',
#   'digelar',
#   'pada',
#   'Kamis',
#   ',',
#   '8',
#   'Maret',
#   '2018',
#   '.'],
#  ['Setelah',
#   'RUPS',
#   'kami',
#   'akan',
#   'mengumumkan',
#   'beberapa',
#   'poin',
#   'penting',
#   'tentang',
#   'kompetisi',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Di',
#   'antaranya',
#   'tentang',
#   'jadwal',
#   'kick',
#   'off',
#   'kompetisi',
#   'dan',
#   'juga',
#   'hak',
#   'siar',
#   'televisi',
#   '.'],
#  ['Jadi', ',', 'mohon', 'ditunggu', ',', 'Berlinton', 'menambahkan', '.'],
#  ['Adapun',
#   'Tigor',
#   'Shalom',
#   'Boboy',
#   ',',
#   'COO',
#   'PT',
#   'LIB',
#   ',',
#   'menjelaskan',
#   ',',
#   'sejauh',
#   'ini',
#   'jadwal',
#   'kompetisi',
#   'sudah',
#   'disusun',
#   'dan',
#   'menyesuaikan',
#   'dengan',
#   'agenda',
#   'penting',
#   'pada',
#   '2018',
#   'seperti',
#   'Asian',
#   'Games',
#   '2018',
#   'dan',
#   'Piala',
#   'AFF',
#   '.'],
#  ['Draft',
#   'jadwal',
#   'akan',
#   'disampaikan',
#   'kepada',
#   'klub',
#   'usai',
#   'RUPS',
#   '.'],
#  ['Untuk',
#   'membuat',
#   'jadwal',
#   ',',
#   'kami',
#   'telah',
#   'mempertimbangkan',
#   'banyak',
#   'hal',
#   '.'],
#  ['Pada',
#   'intinya',
#   ',',
#   'kami',
#   'jelas',
#   'memprioritaskan',
#   'kepentingan',
#   'klub',
#   ',',
#   'Tigor',
#   'mengatakan',
#   '.'],
#  ['Terakhir',
#   ',',
#   'Tigor',
#   'mengatakan',
#   'kompetisi',
#   'Liga',
#   '1',
#   '2018',
#   'berpeluang',
#   'digelar',
#   'pada',
#   'tanggal',
#   '18',
#   'atau',
#   '25',
#   'Maret',
#   '.'],
#  ['Setelah',
#   'kekalahan',
#   'Qatar',
#   'dari',
#   'Bangladesh',
#   ',',
#   'Indonesia',
#   'sebenarnya',
#   'baru',
#   'melakoni',
#   'laga',
#   'penentuan',
#   'kontra',
#   'Hong',
#   'Kong',
#   'di',
#   'Stadion',
#   'Patriot',
#   'Candrabhaga',
#   'malam',
#   'besok',
#   '.'],
#  ['Skuat',
#   'Garuda',
#   'saat',
#   'ini',
#   'ada',
#   'di',
#   'posisi',
#   'ketiga',
#   'grup',
#   'dengan',
#   'enam',
#   'poin',
#   'dari',
#   'tiga',
#   'laga',
#   ',',
#   'selisih',
#   'satu',
#   'angka',
#   'dari',
#   'Hong',
#   'Kong',
#   'di',
#   'posisi',
#   'kedua',
#   'dan',
#   'dua',
#   'poin',
#   'dari',
#   'Palestina',
#   'di',
#   'puncak',
#   '.'],
#  ['Palestina',
#   'dan',
#   'Hong',
#   'Kong',
#   'sudah',
#   'memastikan',
#   'lolos',
#   'lebih',
#   'dulu',
#   ',',
#   'sementara',
#   'Indonesia',
#   'harus',
#   'melakoni',
#   'laga',
#   'penentuan',
#   '.'],
#  ['Namun',
#   ',',
#   'angin',
#   'segar',
#   'mendatangi',
#   'kubu',
#   'Merah',
#   'Putih',
#   'menyusul',
#   'hasil',
#   'matchday',
#   'ketiga',
#   'Grup',
#   'B',
#   '.'],
#  ['Bangladesh',
#   'menang',
#   '1-0',
#   'atas',
#   'Qatar',
#   'yang',
#   'tersingkir',
#   'sebagai',
#   'juru',
#   'kunci',
#   ',',
#   'sementara',
#   'Uzbekistan',
#   'menang',
#   '1-0',
#   'atas',
#   'Thailand',
#   '.'],
#  ['Bangladesh',
#   'lolos',
#   'sebagai',
#   'runner-up',
#   'dengan',
#   'empat',
#   'poin',
#   ',',
#   'di',
#   'bawah',
#   'Uzbekistan',
#   'yang',
#   'jadi',
#   'juara',
#   'grup',
#   'dengan',
#   'poin',
#   'sempurna',
#   '.'],
#  ['Hanya',
#   'ada',
#   'empat',
#   'peringkat',
#   'ketiga',
#   'terbaik',
#   'yang',
#   'lolos',
#   ',',
#   'sementara',
#   'Indonesia',
#   'ada',
#   'di',
#   'posisi',
#   'teratas',
#   'dalam',
#   'klasemen',
#   'tim-tim',
#   'tersebut',
#   '.'],
#  ['Bangladesh',
#   'menang',
#   'atas',
#   'Qatar',
#   'di',
#   'laga',
#   'sepakbola',
#   'Asian',
#   'Games',
#   '2018',
#   ',',
#   'pasalnya',
#   ',',
#   'hanya',
#   'Indonesia',
#   '(',
#   '3',
#   'poin',
#   ')',
#   'yang',
#   'baru',
#   'bermain',
#   'dua',
#   'kali',
#   'dan',
#   'punya',
#   'selisih',
#   'gol',
#   'lebih',
#   'gol',
#   'yakni',
#   '+3',
#   '.'],
#  ['Sementara',
#   'tiga',
#   'tim',
#   'lainnya',
#   ',',
#   'Uni',
#   'Emirat',
#   'Arab',
#   'dan',
#   'Pakistan',
#   '(',
#   '3',
#   'poin',
#   ')',
#   'selisih',
#   'golnya',
#   'lebih',
#   'buruk',
#   ',',
#   'sementara',
#   'Thailand',
#   'hanya',
#   'punya',
#   'dua',
#   'poin',
#   '.'],
#  ['Klasemen',
#   'Peringkat',
#   'ketiga',
#   'cabor',
#   'sepakbola',
#   'putra',
#   'Asian',
#   'Games',
#   '2018Memang',
#   'masih',
#   'ada',
#   'Kirgistan',
#   ',',
#   'Myanmar',
#   ',',
#   'dan',
#   'Korea',
#   'Utara',
#   ',',
#   'yang',
#   'bisa',
#   'menggeser',
#   'posisi',
#   'Indonesia',
#   'besok',
#   'dari',
#   'pucuk',
#   'klasemen',
#   'peringkat',
#   'ketiga',
#   'terbaik',
#   '.'],
#  ['Tapi',
#   ',',
#   'Indonesia',
#   'menang',
#   'dari',
#   'sisi',
#   'produktivitas',
#   'sehingga',
#   'mampu',
#   'menyegel',
#   'tiket',
#   '16',
#   'besar',
#   '.'],
#  ['Barito',
#   'Putera',
#   'kembali',
#   'merekrut',
#   'pemain',
#   'baru',
#   'jelang',
#   'penutupan',
#   'bursa',
#   'transfer',
#   'putaran',
#   'kedua',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ["'Laskar", 'Antasari', "'", 'resmi', 'mengontrak', 'Jajang', 'Sukmara', '.'],
#  ['Barito',
#   'secara',
#   'resmi',
#   'mengontrak',
#   'pemain',
#   'berposisi',
#   'bek',
#   'kiri',
#   'itu',
#   'di',
#   'kediaman',
#   'manajer',
#   'tim',
#   ',',
#   'Hasnuryadi',
#   ',',
#   'di',
#   'kawasan',
#   'Jakarta',
#   'Selatan',
#   '.'],
#  ['Jajang',
#   'dikontrak',
#   'enam',
#   'bulan',
#   'dengan',
#   'opsi',
#   'perpanjangan',
#   '.'],
#  ['Barito',
#   'memang',
#   'minim',
#   'stok',
#   'bek',
#   'kiri',
#   'dengan',
#   'hanya',
#   'memiliki',
#   'Rony',
#   'Beroperay',
#   'di',
#   'area',
#   'tersebut',
#   '.'],
#  ['Kami',
#   'memang',
#   'menginginkan',
#   'pemain',
#   'di',
#   'posisi',
#   'bek',
#   'dan',
#   'pemain',
#   'inti',
#   'karena',
#   'ini',
#   'sudah',
#   'putaran',
#   'kedua',
#   'kami',
#   'tidak',
#   'mau',
#   'main-main',
#   '.'],
#  ['Jajang',
#   'kami',
#   'datangkan',
#   'sesuai',
#   'keinginan',
#   'coach',
#   'Jacksen',
#   ',',
#   'ujar',
#   'Hasnuryadi',
#   '.'],
#  ['Namun',
#   'kalau',
#   'di',
#   'pertengahan',
#   'jalan',
#   'dia',
#   'bermain',
#   'bagus',
#   ',',
#   'kami',
#   'bisa',
#   'memperpanjang',
#   'kontraknya',
#   ',',
#   'katanya',
#   '.'],
#  ['Bisa',
#   'bergabung',
#   'bersama',
#   'Barito',
#   'menjadi',
#   'kebanggaan',
#   'bagi',
#   'Jajang',
#   '.'],
#  ['Pemain',
#   '29',
#   'tahun',
#   'itu',
#   'mengaku',
#   'termotivasi',
#   'memberikan',
#   'kontribusinya',
#   'dan',
#   'meneruskan',
#   'perjuangan',
#   'Barito',
#   'di',
#   'papan',
#   'atas',
#   '.'],
#  ['Saya', 'senang', 'bisa', 'bergabung', 'di', 'sini', '.'],
#  ['Barito', 'adalah', 'klub', 'besar', '.'],
#  ['Mereka',
#   'main',
#   'bola',
#   'dari',
#   'kaki',
#   'ke',
#   'kaki',
#   'dan',
#   'punya',
#   'pemain',
#   'bagus',
#   '.'],
#  ['Semoga',
#   'saya',
#   'bisa',
#   'memberikan',
#   'yang',
#   'terbaik',
#   ',',
#   'kata',
#   'eks',
#   'Persib',
#   'Bandung',
#   'ini',
#   '.'],
#  ['Bersama',
#   'Ayam',
#   'Kinantan',
#   ',',
#   'pemain',
#   'kelahiran',
#   'Bandung',
#   'itu',
#   'tampil',
#   'sebanyak',
#   '15',
#   'kali',
#   'dalam',
#   '17',
#   'laga',
#   '.'],
#  ['Barito',
#   'saat',
#   'ini',
#   'berada',
#   'di',
#   'posisi',
#   'dua',
#   'klasemen',
#   'Liga',
#   '1',
#   'dengan',
#   'nilai',
#   '29',
#   'dari',
#   '18',
#   'pertandingan',
#   '.'],
#  ['Mereka',
#   'tiga',
#   'poin',
#   'tertinggal',
#   'dari',
#   'Persib',
#   'Bandung',
#   'yang',
#   'memimpin',
#   '.'],
#  ['Stadion',
#   'Gelora',
#   'Sriwijawa',
#   'di',
#   'Jakabaring',
#   'Sports',
#   'City',
#   'dirusak',
#   'oleh',
#   'oknum',
#   'suporter',
#   '.'],
#  ['Aksi',
#   'itu',
#   'terjadi',
#   'usai',
#   'Sriwijaya',
#   'FC',
#   'ditaklukkan',
#   'oleh',
#   'Arema',
#   'FC',
#   '.'],
#  ['Sriwijaya', 'FC', 'saat', 'ini', 'tengah', 'dilanda', 'krisis', '.'],
#  ['Mereka',
#   'ditinggal',
#   'oleh',
#   'beberapa',
#   'pemain',
#   'bintangnya',
#   ',',
#   'juga',
#   'tim',
#   'pelatih',
#   'karena',
#   'permasalahan',
#   'dana',
#   '.'],
#  ['Akibat',
#   'masalah',
#   'di',
#   'tubuh',
#   'manajemen',
#   'itu',
#   ',',
#   'Sriwijaya',
#   'FC',
#   'menuai',
#   'hasil',
#   'buruk',
#   '.'],
#  ['Yang',
#   'paling',
#   'anyar',
#   ',',
#   'Laskar',
#   'Wong',
#   'Kito',
#   'dilumat',
#   'Singo',
#   'Edan',
#   'tiga',
#   'gol',
#   'dalam',
#   'lanjutan',
#   'Liga',
#   '1',
#   '2018',
#   'dengan',
#   'skor',
#   'akhir',
#   '0-3',
#   '.'],
#  ['Kerusuhan',
#   'itu',
#   'terjadi',
#   'pada',
#   'menit',
#   'ke-76',
#   'pertandingan',
#   ',',
#   'saat',
#   'Arema',
#   'FC',
#   'mencetak',
#   'gol',
#   'ketiga',
#   '.'],
#  ['Ada',
#   'sebanyak',
#   '335',
#   'kursi',
#   'yang',
#   'rusak',
#   ',',
#   'dengan',
#   'rincian',
#   '231',
#   'di',
#   'tribune',
#   'utara',
#   'dan',
#   '104',
#   'di',
#   'tribune',
#   'selatan',
#   '.'],
#  ['Sebelum',
#   'pengrusakan',
#   ',',
#   'Jakabaring',
#   'Sport',
#   'City',
#   'disebut',
#   'sudah',
#   'siap',
#   '99',
#   'persen',
#   'untuk',
#   'menggelar',
#   'Asian',
#   'Games',
#   '2018',
#   '.'],
#  ['Ada',
#   '11',
#   'cabang',
#   'olahraga',
#   'yang',
#   'dipertandingankan',
#   'di',
#   'Palembang',
#   '.'],
#  ['Gelora',
#   'Sriwijaya',
#   'digunakan',
#   'untuk',
#   'menggelar',
#   'cabang',
#   'sepakbola',
#   'putri',
#   '.'],
#  ['Tim',
#   'sepakbola',
#   'putra',
#   'Laos',
#   'bakal',
#   'menghadapi',
#   'laga',
#   'hidup',
#   'dan',
#   'mati',
#   'melawan',
#   'Indonesia',
#   '.'],
#  ['Pelatih', 'Mike', 'Wong', 'ingin', 'pemainnya', 'tetap', 'enjoy', '.'],
#  ['Laos', 'sudah', 'menjalani', 'laga', 'sebanyak', 'dua', 'kali', '.'],
#  ['Seluruh',
#   'laga',
#   'tersebut',
#   'berakhir',
#   'dengan',
#   'kekalahan',
#   ',',
#   'yakni',
#   'dari',
#   'Hong',
#   'Kong',
#   '1-3',
#   'dan',
#   'Palestina',
#   '1-2',
#   '.'],
#  ['Hasil',
#   'itu',
#   'membuat',
#   'Laos',
#   'duduk',
#   'di',
#   'posisi',
#   'buncit',
#   'Grup',
#   'A',
#   'cabor',
#   'sepakbola',
#   'Asian',
#   'Games',
#   '2018',
#   'dengan',
#   'nol',
#   'poin',
#   '.'],
#  ['Setidaknya',
#   'mengincar',
#   'posisi',
#   'tiga',
#   'terbaik',
#   'untuk',
#   'lolos',
#   'ke',
#   'babak',
#   '16',
#   'besar',
#   '.'],
#  ['Indonesia',
#   'menjadi',
#   'lawan',
#   'untuk',
#   'Laos',
#   'di',
#   'laga',
#   'selanjutnya',
#   '.'],
#  ['Kedua',
#   'tim',
#   'bermain',
#   'di',
#   'Stadion',
#   'Patriot',
#   'Candrabhaga',
#   'pada',
#   'jumat',
#   'malam',
#   '.'],
#  ['Laga',
#   'ini',
#   'juga',
#   'sangat',
#   'penting',
#   'untuk',
#   'Indonesia',
#   'mengingat',
#   'pada',
#   'laga',
#   'sebelumnya',
#   'kalah',
#   'dari',
#   '1-2',
#   'dari',
#   'Palestina',
#   '.'],
#  ['Indonesia',
#   'kalah',
#   'di',
#   'pertandingan',
#   'terakhir',
#   ',',
#   'jadi',
#   'mereka',
#   'harus',
#   'memenangkan',
#   'pertandingan',
#   'besok',
#   '.'],
#  ['Saya',
#   'kira',
#   'Indonesia',
#   'saat',
#   'ini',
#   'lebih',
#   'kuat',
#   'dari',
#   'sebelumnya',
#   ',',
#   'kata',
#   'Mike',
#   'di',
#   'Lapangan',
#   'ABC',
#   'Senayan',
#   ',',
#   'kamis',
#   'sore',
#   '.'],
#  ['Kami',
#   'harus',
#   'menghilangkan',
#   'kesalahan-kesalahan',
#   'di',
#   'dua',
#   'pertandingan',
#   'sebelumnya',
#   '.'],
#  ['Pemain',
#   'juga',
#   'harus',
#   'bisa',
#   'enjoy',
#   'di',
#   'pertandingan',
#   ',',
#   'sambungnya',
#   '.'],
#  ['Wong',
#   'tak',
#   'menutup',
#   'kemungkinan',
#   'bakal',
#   'melakukan',
#   'perubahan',
#   'starting',
#   'XI',
#   'saat',
#   'melawan',
#   'Indonesia',
#   '.'],
#  ['Hal',
#   'itu',
#   'guna',
#   'menyiasati',
#   'padatnya',
#   'jadwal',
#   'di',
#   'Asian',
#   'Games',
#   '.'],
#  ['Bisa', 'saja', 'ada', 'pergantian', '1-2', 'pemain', '.'],
#  ['Kami',
#   'sudah',
#   'dapat',
#   'istirahat',
#   'karena',
#   'kemarin',
#   'tidak',
#   'bermain',
#   '.'],
#  ['Berbeda',
#   'dengan',
#   'dua',
#   'pertandingan',
#   'sebelumnya',
#   ',',
#   'tutupnya',
#   '.'],
#  ['Garuda',
#   'Asia',
#   ',',
#   'julukan',
#   'timnas',
#   'U-16',
#   ',',
#   'menggunduli',
#   'Filipina',
#   '8-0',
#   '.'],
#  ['Komite',
#   'Olimpiade',
#   'Indonesia',
#   '(',
#   'KOI',
#   ')',
#   'melalui',
#   'surat',
#   'resminya',
#   'sudah',
#   'memberikan',
#   'desain',
#   'jersey',
#   'tanding',
#   'kepada',
#   'PSSI',
#   '.'],
#  ['Masalah',
#   'jersey',
#   'yang',
#   'akan',
#   'dikenakan',
#   'timnas',
#   'U-23',
#   'sempat',
#   'menjadi',
#   'perdebatan',
#   '.'],
#  ['PSSI',
#   'telah',
#   'lebih',
#   'dulu',
#   'menggandeng',
#   'Nike',
#   'sebagai',
#   'sponsor',
#   'utama',
#   ',',
#   'tapi',
#   'di',
#   'satu',
#   'sisi',
#   'Panitia',
#   'Pelaksana',
#   'Asian',
#   'Games',
#   '2018',
#   '(',
#   'INASGOC',
#   ')',
#   'dan',
#   'KOI',
#   'menugaskan',
#   'seluruh',
#   'kontingen',
#   'Indonesia',
#   'memakai',
#   'jersey',
#   'dari',
#   'apparel',
#   'yang',
#   'sama',
#   ',',
#   'Li-Ning',
#   '.'],
#  ['Dalam',
#   'suratnya',
#   ',',
#   'KOI',
#   'melampirkan',
#   'gambar',
#   'desain',
#   'jersey',
#   'timnas',
#   'U-23',
#   'di',
#   'Asian',
#   'Games',
#   '.'],
#  ['Sehubungan',
#   'dengan',
#   'penyediaan',
#   'baju',
#   'tanding',
#   'oleh',
#   'sponsor',
#   'Tim',
#   'Indonesia',
#   'yaitu',
#   'Li-Ning',
#   ',',
#   'maka',
#   'bersama',
#   'ini',
#   'kami',
#   'Komite',
#   'Olimpiade',
#   'Indonesia',
#   '(',
#   'KOI',
#   ')',
#   'mengirimkan',
#   'desain',
#   'baju',
#   'tanding',
#   'untuk',
#   'sepakbola',
#   ',',
#   'tulis',
#   'KOI',
#   '.'],
#  ['Jersey',
#   'yang',
#   'pertama',
#   'adalah',
#   'dominasi',
#   'berwarna',
#   'merah',
#   'yang',
#   'dikombinasikan',
#   'dengan',
#   'garis',
#   'bergelombang',
#   'hitam-merah',
#   'di',
#   'bagian',
#   'bawahnya',
#   '.'],
#  ['Pada',
#   'bagian',
#   'leher',
#   'terdapat',
#   'garis',
#   'putih',
#   'kotak-kotak',
#   'dan',
#   'ditambah',
#   'sebelah',
#   'kiri',
#   'terdapat',
#   'lambang',
#   'garuda',
#   'dan',
#   'sebelahnya',
#   'logo',
#   'Li-Ning',
#   '.'],
#  ['Lalu',
#   'jersey',
#   'kedua',
#   'desainnya',
#   'sama',
#   'persis',
#   'dengan',
#   'jersey',
#   'pertama',
#   '.'],
#  ['Warna',
#   'putih',
#   'menjadi',
#   'dominasi',
#   'yang',
#   'diberikan',
#   'garis',
#   'warna',
#   'merah-putih',
#   'di',
#   'bawahnya',
#   '.'],
#  ['Menpora',
#   'Imam',
#   'Nahrawi',
#   'resmi',
#   'melaporkan',
#   'kasus',
#   'kekerasan',
#   'yang',
#   'dialami',
#   'putranya',
#   'kepada',
#   'pihak',
#   'kepolisian',
#   '.'],
#  ['Laporan', 'tersebut', 'masuk', 'pada', 'Jumat', '.'],
#  ['Seperti',
#   'diketahui',
#   ',',
#   'putra',
#   'Imam',
#   'Nahrawi',
#   'mengalami',
#   'kekerasan',
#   'dalam',
#   'bentuk',
#   'pemukulan',
#   'yang',
#   'dilakukan',
#   'oleh',
#   'suporter',
#   'berbaju',
#   'Jakmania',
#   '.'],
#  ['Peristiwa',
#   'itu',
#   'terjadi',
#   'saat',
#   'putra',
#   'Imam',
#   'menyaksikan',
#   'laga',
#   'antara',
#   'Persija',
#   'Jakarta',
#   'melawan',
#   'Persebaya',
#   'Surabaya',
#   'sebagai',
#   'tamu',
#   'undangan',
#   'di',
#   'Stadion',
#   'PTIK',
#   '.'],
#  ['Topi', 'yang', 'dipakainya', 'pun', 'sampai', 'terjatuh', '.'],
#  ['Imam',
#   'secara',
#   'resmi',
#   'melaporkan',
#   'kejadian',
#   'itu',
#   'ke',
#   'Polres',
#   'Jakarta',
#   'Selatan',
#   'lewat',
#   'stafnya',
#   '.'],
#  ['Dalam',
#   'surat',
#   'laporannya',
#   ',',
#   'kasus',
#   'tersebut',
#   'masuk',
#   'dalam',
#   'perkara',
#   'penganiayaan',
#   'dan',
#   'kekerasan',
#   '.'],
#  ['Lihat', 'videonya', ',', 'topinya', 'lepas', 'gitu', 'kok', '.'],
#  ['Pokoknya',
#   'proses',
#   'hukum',
#   ',',
#   'harus',
#   'dikejar',
#   'terus',
#   'pelakunya',
#   ',',
#   'tegas',
#   'Imam',
#   '.'],
#  ['Menteri',
#   'Pemuda',
#   'dan',
#   'Olahraga',
#   '(',
#   'Menpora',
#   ')',
#   'Imam',
#   'Nahrawi',
#   'menggelar',
#   'pertemuan',
#   'dengan',
#   'PT.Liga',
#   'Indonesia',
#   'Baru',
#   '(',
#   'LIB',
#   ')',
#   '.'],
#  ['Menpora',
#   'meminta',
#   'agar',
#   'kondisi',
#   'kondusif',
#   'kompetisi',
#   'bisa',
#   'terjaga',
#   'dengan',
#   'baik',
#   '.'],
#  ['Menpora',
#   'melakukan',
#   'audiensi',
#   'dengan',
#   'jajaran',
#   'PT',
#   'LIB',
#   'di',
#   'Kantor',
#   'Kemenpora',
#   ',',
#   'Senayan',
#   ',',
#   'Jakarta',
#   '.'],
#  ['Dalam',
#   'pertemuan',
#   'itu',
#   ',',
#   'PT.LIB',
#   'diwakili',
#   'oleh',
#   'Direktur',
#   'Utama',
#   'Berlinton',
#   'Siahaan',
#   ',',
#   'CEO',
#   'Risha',
#   'Adiwijaya',
#   ',',
#   'dan',
#   'COO',
#   'Tigorshalom',
#   'Boboy',
#   '.'],
#  ['Pada',
#   'kesempatan',
#   'itu',
#   ',',
#   'PT.LIB',
#   'menyampaikan',
#   'undangan',
#   'kepada',
#   'Menpora',
#   'untuk',
#   'menyaksikan',
#   'kickoff',
#   'Liga',
#   '1',
#   '2018',
#   'yang',
#   'mempertemukan',
#   'Bhayangkara',
#   'FC',
#   'dan',
#   'Persija',
#   'Jakarta',
#   'di',
#   'Stadion',
#   'Utama',
#   'Gelora',
#   'Bung',
#   'Karno',
#   '(',
#   'SUGBK',
#   ')',
#   'pada',
#   'Jumat',
#   '.'],
#  ['Tak',
#   'hanya',
#   'itu',
#   ',',
#   'PT.LIB',
#   'juga',
#   'melaporkan',
#   'soal',
#   'kompetisi',
#   'Liga',
#   '1',
#   '.'],
#  ['Yang',
#   'kedua',
#   ',',
#   'PT',
#   'LIB',
#   'menyampaikan',
#   'bahwa',
#   'untuk',
#   'kepentingan',
#   'Asian',
#   'Games',
#   'nanti',
#   ',',
#   'kompetisi',
#   'akan',
#   'diliburkan',
#   'sementara',
#   '.'],
#  ['Itu', 'kabar', 'baik', 'untuk', 'kami', 'semua', '.'],
#  ['PT.LIB',
#   'telah',
#   'menyampaikan',
#   'kepada',
#   'seluruh',
#   'pemain',
#   'klub',
#   'Liga',
#   '1',
#   'yang',
#   'dipanggil',
#   'ke',
#   'timnas',
#   'agar',
#   'segera',
#   'bergabung',
#   'semata-mata',
#   'untuk',
#   'kepentingan',
#   'Asian',
#   'Games',
#   '2018',
#   '.'],
#  ['Intinya',
#   ',',
#   'pemerintah',
#   'senang',
#   'karena',
#   'PT',
#   'LIB',
#   'akan',
#   'melakukan',
#   'perbaikan-perbaikan',
#   'termasuk',
#   'soal',
#   'regulasi',
#   'tidak',
#   'akan',
#   'berubah',
#   'lagi',
#   ',',
#   'kemudian',
#   'marquee',
#   'player',
#   'ditiadakan',
#   ',',
#   'ini',
#   'hal',
#   'bagus',
#   'untuk',
#   'sepakbola',
#   'tanah',
#   'air',
#   'bisa',
#   'berbicara',
#   'lebih',
#   'banyak',
#   'lagi',
#   'di',
#   'kompetisi',
#   'lokal',
#   '.'],
#  ['Semuanya',
#   'menarik',
#   ',',
#   'termasuk',
#   'soal',
#   'hak',
#   'siar',
#   'juga',
#   'dibahas',
#   '.'],
#  ['Karena',
#   'ini',
#   'sifatnya',
#   'profesional',
#   'karenanya',
#   'merupakan',
#   'pekerjaan',
#   'bagi',
#   'PT',
#   'LIB',
#   'untuk',
#   'bisa',
#   'menyenangkan',
#   'seluruh',
#   'penyuka',
#   'sepakbola',
#   'di',
#   'Indonesia',
#   '.'],
#  ['Suasana',
#   'kondusif',
#   'yang',
#   'mulai',
#   'terlihat',
#   'diminta',
#   'agar',
#   'tetap',
#   'dijaga',
#   'dengan',
#   'baik',
#   '.'],
#  ['Yang',
#   'penting',
#   'juga',
#   'semua',
#   'harus',
#   'menjaga',
#   'atmosfer',
#   'kehidupan',
#   'bermasyarakat',
#   ',',
#   'karena',
#   'ini',
#   'tahun',
#   'politik',
#   'maka',
#   'kami',
#   'berharap',
#   'sepakbola',
#   'ini',
#   'menjadi',
#   'penyejuk',
#   'dan',
#   'perekat',
#   'bangsa',
#   '.'],
#  ['Dengan',
#   'Liga',
#   '1',
#   'ini',
#   'kami',
#   'harapkan',
#   'pesta',
#   'demokrasi',
#   'betul-betul',
#   'menjadi',
#   'pesta',
#   'yang',
#   'menyenangkan',
#   'serta',
#   'menggembirakan',
#   ',',
#   'katanya',
#   '.'],
#  ['Di',
#   'sepakbola',
#   'ini',
#   'dari',
#   'segala',
#   'macam',
#   'keberbedaannya',
#   'semua',
#   'nanti',
#   'harus',
#   'saling',
#   'menjaga',
#   'dan',
#   'mendukung',
#   'agar',
#   'kondisi',
#   'tetap',
#   'nyaman',
#   ',',
#   'tenteram',
#   '.'],
#  ['Saya',
#   'bersyukur',
#   'kondisi',
#   'suporter',
#   'dari',
#   'musim',
#   '2017',
#   'sudah',
#   'rukun',
#   'bahkan',
#   'sejuk',
#   '.'],
#  ['Nah',
#   ',',
#   'tolong',
#   'kondisi',
#   'seperti',
#   'ini',
#   'dijaga',
#   'oleh',
#   'kami',
#   'semua',
#   ',',
#   'termasuk',
#   'menjaga',
#   'fasilitas',
#   'negara',
#   '.'],
#  ['Tidak',
#   'boleh',
#   'ada',
#   'lagi',
#   'yang',
#   'merusak',
#   ',',
#   'tegas',
#   'Imam',
#   '.'],
#  ['Persib',
#   'Bandung',
#   'mengajukan',
#   'penundaan',
#   'laga',
#   'melawan',
#   'Persija',
#   'Jakarta',
#   'di',
#   'lanjutan',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Faktor', 'keamanan', 'menjadi', 'alasan', 'utamanya', '.'],
#  ['Persib',
#   'dijadwalkan',
#   'menjamu',
#   'Persija',
#   'pada',
#   '23',
#   'September',
#   '2018',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Bandung',
#   'Lautan',
#   'Api',
#   '(',
#   'GBLA',
#   ')',
#   '.'],
#  ['Akan',
#   'tetapi',
#   'Persib',
#   'meminta',
#   'diundur',
#   'dua',
#   'hari',
#   'karena',
#   'faktor',
#   'keamanan',
#   '.'],
#  ['Melalui',
#   'surat',
#   'bernomor',
#   '115/PANPEL-L1/IX-2018',
#   ',',
#   'Persib',
#   'meminta',
#   'agar',
#   'laga',
#   'yang',
#   'sejatinya',
#   'dihelat',
#   'pada',
#   '23',
#   'September',
#   ',',
#   'pukul',
#   '18.30',
#   'tersebut',
#   'diundur',
#   'menjadi',
#   '25',
#   'September',
#   '2018',
#   ',',
#   'pukul',
#   '15.30',
#   'WIB',
#   '.'],
#  ['Alasannya',
#   'panpel',
#   'Persib',
#   'menilai',
#   'jika',
#   'pertandingan',
#   'digelar',
#   'di',
#   'tanggal',
#   'tersebut',
#   'berpotensi',
#   'kerawanan',
#   'karena',
#   'bersamaan',
#   'dengan',
#   'jadwal',
#   'dari',
#   'KPU',
#   'untuk',
#   'kampanye',
#   'Pileg',
#   'dan',
#   'Pilpres',
#   '.'],
#  ['Perlu',
#   'diketahui',
#   ',',
#   'banyak',
#   'hal',
#   'yang',
#   'harus',
#   'dipikirkan',
#   'untuk',
#   'mengubah',
#   'jadwal',
#   'pertandingan',
#   ',',
#   'buka',
#   'Tigorshalom',
#   'Boboy',
#   ',',
#   'selaku',
#   'COO',
#   'dari',
#   'PT',
#   'Liga',
#   'Indonesia',
#   'Baru',
#   '(',
#   'LIB',
#   ')',
#   '.'],
#  ['Bukan',
#   'melulu',
#   'pada',
#   'kondisi',
#   'atau',
#   'situasi',
#   'kedua',
#   'tim',
#   'yang',
#   'bertanding',
#   '.'],
#  ['Kami',
#   'harus',
#   'mempertimbangkan',
#   'aspek',
#   'lain',
#   'yang',
#   'tak',
#   'kalah',
#   'penting',
#   ',',
#   'dia',
#   'menambahkan',
#   '.'],
#  ['Tigor',
#   'menjelaskan',
#   'dia',
#   'tak',
#   'bisa',
#   'terburu-buru',
#   'mengambil',
#   'keputusan',
#   'terkait',
#   'permintaan',
#   'tersebut',
#   '.'],
#  ['PT.LIB',
#   'masih',
#   'harus',
#   'berkoordinasi',
#   'dengan',
#   'pihak-pihak',
#   'lainnya',
#   '.'],
#  ['Perkembangan',
#   'tentang',
#   'status',
#   'laga',
#   'itu',
#   ',',
#   'akan',
#   'kami',
#   'umumkan',
#   'secepatnya',
#   ',',
#   'kata',
#   'Tigor',
#   '.'],
#  ['Meski',
#   'begitu',
#   ',',
#   'pelatih',
#   'Indra',
#   'Sjafri',
#   'tetap',
#   'mengapresiasi',
#   'perjuangan',
#   'para',
#   'pemainnya',
#   '.'],
#  ['Indonesia',
#   'disingkirkan',
#   'Malaysia',
#   'dalam',
#   'laga',
#   'semifinal',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Delta',
#   ',',
#   'Sidoarjo',
#   '.'],
#  ['Garuda',
#   'Nusantara',
#   'kalah',
#   'adu',
#   'penalti',
#   'setelah',
#   'skor',
#   '1-1',
#   'bertahan',
#   'hingga',
#   '90',
#   'menit',
#   '.'],
#  ['Saya',
#   'berterima',
#   'kasih',
#   'kepada',
#   'seluruh',
#   'pemain',
#   'yang',
#   'sudah',
#   'bertanding',
#   '2x45',
#   'menit',
#   '.'],
#  ['Sebenarnya',
#   'kami',
#   'dapat',
#   'angin',
#   'segar',
#   'saat',
#   'unggul',
#   'cepat',
#   'di',
#   'babak',
#   'pertama',
#   '.'],
#  ['Tapi',
#   ',',
#   'yang',
#   'kami',
#   'persiapkan',
#   'saat',
#   'latihan',
#   'benar-benar',
#   'terjadi',
#   'yakni',
#   'umpan',
#   'silang',
#   ',',
#   'kata',
#   'Indra',
#   '.'],
#  ['Sebenarnya',
#   'di',
#   'babak',
#   'kedua',
#   'kami',
#   'mampu',
#   'menguasai',
#   'permainan',
#   'dan',
#   'menciptakan',
#   'beberapa',
#   'peluang',
#   '.'],
#  ['Namun',
#   ',',
#   'kami',
#   'tidak',
#   'bisa',
#   'cetak',
#   'gol',
#   ',',
#   'tambahnya',
#   '.'],
#  ['Saya', 'mohon', 'maaf', 'mewakili', 'para', 'pemain', '.'],
#  ['Dalam',
#   'pertandingan',
#   'malam',
#   'ini',
#   'kami',
#   'sudah',
#   'berusaha',
#   'memberikan',
#   'permainan',
#   'yang',
#   'maksimal',
#   '.'],
#  ['Mungkin',
#   'atas',
#   'izin',
#   'Tuhan',
#   'kami',
#   'belum',
#   'bisa',
#   'lolos',
#   'ke',
#   'final',
#   ',',
#   'kata',
#   'Asnawi',
#   '.'],
#  ['Stadion',
#   'Gelora',
#   'Sriwijaya',
#   ',',
#   'Jakabaring',
#   ',',
#   'Palembang',
#   ',',
#   'dirusak',
#   'suporter',
#   'satu',
#   'bulan',
#   'jelang',
#   'dipakai',
#   'untuk',
#   'Asian',
#   'Games',
#   '2018',
#   '.'],
#  ['Begini', 'rekaman', 'video', 'peristiwa', 'tersebut', '.'],
#  ['Peristiwa',
#   'perusakan',
#   'Stadion',
#   'Jakabaring',
#   'terjadi',
#   'di',
#   'pertandingan',
#   'antara',
#   'Sriwijaya',
#   'FC',
#   'dan',
#   'Arema',
#   'FC',
#   'dalam',
#   'lanjutan',
#   'Liga',
#   '1',
#   '.'],
#  ['Suporter',
#   'mengungkapkan',
#   'kekecewaannya',
#   'setelah',
#   'Sriwijaya',
#   'kalah',
#   '0-3',
#   'dari',
#   'Arema',
#   '.'],
#  ['Para',
#   'pendukung',
#   'Sriwijaya',
#   'FC',
#   'melampiaskan',
#   'kekecewaannya',
#   'dengan',
#   'merusak',
#   'kursi',
#   'stadion',
#   '.'],
#  ['Dalam',
#   'beberapa',
#   'video',
#   'yang',
#   'diunggah',
#   'di',
#   'media',
#   'sosial',
#   ',',
#   'suporter',
#   'terlihat',
#   'melempar',
#   'kursi',
#   'ke',
#   'bawah',
#   'tribun',
#   '.'],
#  ['Perusakan',
#   'Stadion',
#   'Jakabaring',
#   'ini',
#   'jadi',
#   'pukulan',
#   'jelang',
#   'pelaksanaan',
#   'Asian',
#   'Games',
#   '2018',
#   '.'],
#  ['Sebab',
#   'stadion',
#   'tersebut',
#   'bakal',
#   'digunakan',
#   'untuk',
#   'menggelar',
#   'cabang',
#   'olahraga',
#   'sepakbola',
#   'putri',
#   '.'],
#  ['Reaksi',
#   'keheranan',
#   'muncul',
#   'dari',
#   'netizen',
#   'dengan',
#   'diizinkannya',
#   'Gelora',
#   'Sriwijawa',
#   'di',
#   'Jakabaring',
#   'Sport',
#   'Center',
#   'menggelar',
#   'laga',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Sebabnya',
#   'Asian',
#   'Games',
#   '2018',
#   'tinggal',
#   'kurang',
#   'sebulan',
#   'lagi',
#   '.'],
#  ['Kerusuhan',
#   'terjadi',
#   'pada',
#   'laga',
#   'Sriwijaya',
#   'FC',
#   'melawan',
#   'Arema',
#   'Fc',
#   '.'],
#  ['Laskar',
#   'Wong',
#   'Kito',
#   'takluk',
#   '0-3',
#   ',',
#   'hingga',
#   'oknum',
#   'suporter',
#   'di',
#   'sisi',
#   'tribune',
#   'utara',
#   'dan',
#   'tribune',
#   'selatan',
#   'melakukan',
#   'pengrusakan',
#   'stadion',
#   '.'],
#  ['Sebanyak', '335', 'lepas', 'dari', 'tempatnya', '.'],
#  ['Rinciannya',
#   '231',
#   'di',
#   'tribune',
#   'utara',
#   'dan',
#   '104',
#   'di',
#   'tribune',
#   'selatan',
#   '.'],
#  ['Venue',
#   'sepakbola',
#   'putri',
#   'untuk',
#   'Asian',
#   'Games',
#   '2018',
#   'pun',
#   'mengalami',
#   'kerusakan',
#   '27',
#   'hari',
#   'menjelang',
#   'pesta',
#   'olahraga',
#   'benua',
#   'kuning',
#   '.'],
#  ['Saat',
#   'stadion-stadion',
#   'venue',
#   'sepakbola',
#   'di',
#   'Jakarta',
#   ',',
#   'Bogor',
#   ',',
#   'Karawang',
#   ',',
#   'dan',
#   'Bekasi',
#   'sudah',
#   'steril',
#   ',',
#   'Sriwijaya',
#   'FC',
#   'masih',
#   'bisa',
#   'menjalani',
#   'pertandingan',
#   'di',
#   'venue',
#   'Asian',
#   'Games',
#   '2018',
#   '.'],
#  ['Sementara',
#   'itu',
#   ',',
#   'Persija',
#   'Jakarta',
#   'masih',
#   'harus',
#   'mengungsi',
#   'hingga',
#   'ke',
#   'Stadion',
#   'Sultan',
#   'Agung',
#   ',',
#   'Bantul',
#   ',',
#   'Daerah',
#   'Istimewa',
#   'Yogyakarta',
#   ',',
#   'untuk',
#   'menggelar',
#   'laga',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Asian',
#   'Games',
#   'tinggal',
#   'menghitung',
#   'hari',
#   'dan',
#   'salah',
#   'satu',
#   'venue',
#   'Std',
#   '.'],
#  ['Jakabaring', 'telah', 'rusak', '.'],
#  ['Persija',
#   'Jakarta',
#   'siap',
#   'tempur',
#   'menghadapi',
#   'Selangor',
#   'FA',
#   'dalam',
#   'laga',
#   'ujicoba',
#   '.'],
#  ['Persija',
#   'ingin',
#   'kembali',
#   'ke',
#   'bentuk',
#   'terbaik',
#   'sebelum',
#   'Liga',
#   '1',
#   'kembali',
#   'digulirkan',
#   '.'],
#  ['Persija',
#   'akan',
#   'melawan',
#   'Selangor',
#   'FA',
#   'di',
#   'Stadion',
#   'Patriot',
#   'Candrabhaga',
#   'malam',
#   '.'],
#  ['Bagi',
#   'Selangor',
#   ',',
#   'ini',
#   'adalah',
#   'ujicoba',
#   'keduanya',
#   'di',
#   'Indonesia',
#   'setelah',
#   'sebelumnya',
#   'menjajal',
#   'Madura',
#   'United',
#   '.'],
#  ['Pada',
#   'laga',
#   'ujicoba',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Ratu',
#   'Pamelingan',
#   ',',
#   'Evan',
#   'Dimas',
#   'dkk',
#   'kalah',
#   'telak',
#   'dengan',
#   'skor',
#   '1-4',
#   'dari',
#   'Madura',
#   'United',
#   '.'],
#  ['Namun',
#   'yang',
#   'jelas',
#   ',',
#   'Persija',
#   'mesti',
#   'memperlihatkan',
#   'performa',
#   'apik',
#   'menjelang',
#   'laga',
#   'melawan',
#   'Borneo',
#   'pada',
#   '12',
#   'September',
#   '.'],
#  ['Kami', 'tahu', 'lawan', 'Madura', 'United', 'punya', 'kualitas', '.'],
#  ['Yang',
#   'kedua',
#   'saya',
#   'pernah',
#   'bekerja',
#   'di',
#   'Malaysia',
#   'mereka',
#   'tak',
#   'terbiasa',
#   'main',
#   'di',
#   'siang',
#   'hari',
#   '.'],
#  ['Mungkin',
#   'karena',
#   'panas',
#   'membuat',
#   'Selangor',
#   'FA',
#   'kesulitan',
#   ',',
#   'ujar',
#   'dia',
#   'kepada',
#   'pewarta',
#   'jelang',
#   'laga',
#   'di',
#   'Bekasi',
#   '.'],
#  ['Besok', 'kami', 'akan', 'main', 'di', 'malam', 'hari', 'jadi', 'fair', '.'],
#  ['Saya', 'yakin', 'besok', 'Selangor', 'akan', 'berubah', '.'],
#  ['Waktu',
#   'melawan',
#   'Madura',
#   'United',
#   'mereka',
#   'tidak',
#   'main',
#   'dengan',
#   'pemain',
#   'inti',
#   '.'],
#  ['Kami',
#   'punya',
#   'target',
#   '(',
#   'bermain',
#   ')',
#   'seperti',
#   'waktu',
#   'di',
#   'latihan',
#   '.'],
#  ['Kami',
#   'harus',
#   'sudah',
#   'main',
#   'lebih',
#   'bagus',
#   'melebihi',
#   'saat',
#   'laga',
#   'melawan',
#   'Bhayangkara',
#   'FC',
#   '.'],
#  ['Kami',
#   'harus',
#   'lebih',
#   'bagus',
#   'dari',
#   'fisik',
#   ',',
#   'taktik',
#   ',',
#   'dan',
#   'teknik',
#   '.'],
#  ['Untuk', 'berapa', 'gol', ',', 'kami', 'tidak', 'bisa', 'bicara', '.'],
#  ['Kami', 'harus', 'respek', 'sama', 'lawan', '.'],
#  ['Kami',
#   'sudah',
#   'main',
#   'lawan',
#   'Kelantan',
#   ',',
#   'dan',
#   'Johor',
#   'Darul',
#   'Takzim',
#   ',',
#   'lalu',
#   'sekarang',
#   'Selangor',
#   ',',
#   'jadi',
#   'kami',
#   'respek',
#   '.'],
#  ['Ilham', 'Udin', 'Armayn', 'juga', 'menjadi', 'sosok', 'berbahaya', '.'],
#  ['Wilian', 'sangat', 'bagus', 'waktu', 'bola', 'atas', '.'],
#  ['Dia', 'tinggi', 'dan', 'punya', 'timing', 'bagus', '.'],
#  ['Kami', 'senang', 'lawan', 'dia', 'lagi', '.'],
#  ['Kami',
#   'lihat',
#   'situasi',
#   'dalam',
#   'pertandingan',
#   ',',
#   'bisa',
#   'bola',
#   'atas',
#   'atau',
#   'bola',
#   'bawah',
#   '.'],
#  ['Dia',
#   'juga',
#   'tidak',
#   'sendiri',
#   'dan',
#   'ada',
#   'temannya',
#   'di',
#   'belakang',
#   '.'],
#  ['Kami', 'harus', 'lihat', 'siapa', 'temannya', 'di', 'belakang', '.'],
#  ['Ada', 'juga', 'Ilham', 'Udin', '.'],
#  ['Dia',
#   'pemain',
#   'bagus',
#   'seperti',
#   'yang',
#   'saya',
#   'lihat',
#   'saat',
#   'masih',
#   'membela',
#   'Bhayangkara',
#   'musim',
#   'lalu',
#   ',',
#   'dia',
#   'menambahkan',
#   '.'],
#  ['Pelatih', 'timnas', 'Indonesia', 'U-16', '.'],
#  ['Tapi',
#   ',',
#   'Fakhri',
#   'menyebut',
#   'timnya',
#   'sebenarnya',
#   'bisa',
#   'menang',
#   'dengan',
#   'skor',
#   'lebih',
#   'besar',
#   '.'],
#  ['Timnas',
#   'Indonesia',
#   'U-16',
#   'mencukur',
#   'Filipina',
#   'dengan',
#   'skor',
#   '8-0',
#   'pada',
#   'laga',
#   'pertamanya',
#   'di',
#   'ajang',
#   'Piala',
#   'AFF',
#   'U-16',
#   '.'],
#  ['Gol-gol',
#   'Garuda',
#   'Asia',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Delta',
#   ',',
#   'Sidoarjo',
#   ',',
#   'Jawa',
#   'Timur',
#   ',',
#   'dicetak',
#   'oleh',
#   'Mochammad',
#   'Supriadi',
#   ',',
#   'Komang',
#   'Teguh',
#   'Trisnanda',
#   ',',
#   'Muhammad',
#   'Fajar',
#   'Fathur',
#   ',',
#   'Sutan',
#   'Diego',
#   'Zico',
#   ',',
#   'Rendy',
#   'Juliansyah',
#   ',',
#   'David',
#   'Maulana',
#   ',',
#   'dan',
#   'pemain',
#   'pengganti',
#   'Bagus',
#   'Kahfi',
#   '(',
#   'dua',
#   'gol',
#   ')',
#   '.'],
#  ['Indonesia',
#   'unggul',
#   'selisih',
#   'gol',
#   'atas',
#   'Myanmar',
#   'dan',
#   'Vietnam',
#   'yang',
#   'punya',
#   'poin',
#   'sama',
#   '.'],
#  ['Kami',
#   'bersyukur',
#   'karena',
#   'kemenangan',
#   'ini',
#   'berkat',
#   'doa',
#   'masyarakat',
#   'Indonesia',
#   'dan',
#   'selain',
#   'itu',
#   'kami',
#   'bangga',
#   'terhadap',
#   'para',
#   'pemain',
#   '.'],
#  ['Dan',
#   'kami',
#   'bangga',
#   'dengan',
#   'permainan',
#   'mereka',
#   'karena',
#   'mampu',
#   'menjalankan',
#   'tugas',
#   'dengan',
#   'baik',
#   ',',
#   'kata',
#   'Fakhri',
#   'seusai',
#   'pertandingan',
#   '.'],
#  ['Seharusnya',
#   'timnas',
#   'U-16',
#   'ini',
#   'bisa',
#   'menang',
#   'lebih',
#   'dari',
#   'delapan',
#   'gol',
#   '.'],
#  ['Masih',
#   'banyak',
#   'peluang',
#   'yang',
#   'seharusnya',
#   'gol',
#   ',',
#   'namun',
#   'tidak',
#   'membuahkan',
#   'gol',
#   '.'],
#  ['Tapi',
#   'kami',
#   'menyadari',
#   'bahwa',
#   'permainan',
#   'bola',
#   'seperti',
#   'itu',
#   ',',
#   'tambah',
#   'Fakhri',
#   '.'],
#  ['Indonesia',
#   'selanjutnya',
#   'akan',
#   'berhadapan',
#   'dengan',
#   'Myanmar',
#   'pada',
#   'pertandingan',
#   'kedua',
#   'yang',
#   'akan',
#   'digelar',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Delta',
#   '.'],
#  ['Kami',
#   'tetap',
#   'akan',
#   'melakukan',
#   'rotasi',
#   'para',
#   'pemain',
#   'karena',
#   'kompetisi',
#   'ini',
#   'recovery',
#   'hanya',
#   'satu',
#   'hari',
#   '.'],
#  ['Untuk',
#   'menjaga',
#   'kondisi',
#   'para',
#   'pemain',
#   'harus',
#   'dirotasi',
#   ',',
#   'kata',
#   'Fakhri',
#   '.'],
#  ['Kami',
#   'akan',
#   'terus',
#   'bermain',
#   'secara',
#   'maksimal',
#   'dengan',
#   'harapan',
#   'agar',
#   'memenuhi',
#   'target',
#   'ke',
#   'final',
#   'Piala',
#   'AFF',
#   'ini',
#   '.'],
#  ['Kemenangan',
#   'ini',
#   'berkat',
#   'kerja',
#   'sama',
#   'yang',
#   'kompak',
#   'dan',
#   'komunikasi',
#   'yang',
#   'baik',
#   'antarpemain',
#   ',',
#   'ujarnya',
#   '.'],
#  ['Berkat',
#   'dukungan',
#   'ribuan',
#   'suporter',
#   'di',
#   'Stadion',
#   'Delta',
#   'Sidoarjo',
#   'ini',
#   'teman-teman',
#   'bermain',
#   'dengan',
#   'penuh',
#   'semangat',
#   '.'],
#  ['Kemenangan',
#   'ini',
#   'untuk',
#   'masyarakat',
#   'Indonesia',
#   ',',
#   'tutur',
#   'David',
#   '.'],
#  ['PT.Liga',
#   'Indonesia',
#   'Baru',
#   'akan',
#   'kembali',
#   'memberikan',
#   'dana',
#   'distribusi',
#   'dengan',
#   'total',
#   'Rp',
#   '7,5',
#   'miliar',
#   'ke',
#   'peserta',
#   'Liga',
#   '1',
#   ',',
#   'sama',
#   'sepeti',
#   'musim',
#   'lalu',
#   '.'],
#  ['Tapi', ',', 'kali', 'ini', 'dibagi', 'menjadi', 'dua', 'bagian', '.'],
#  ['Hal',
#   'tersebut',
#   'dibahas',
#   'dalam',
#   'manajer',
#   'meeting',
#   'yang',
#   'digelar',
#   'PT.LIB',
#   'bersama',
#   'perwakilan',
#   '18',
#   'klub',
#   'peserta',
#   'Liga',
#   '1',
#   'di',
#   'Hotel',
#   'Sultan',
#   '.'],
#  ['Berlinton',
#   'Siahaan',
#   'menjelaskan',
#   'bahwa',
#   'setiap',
#   'klub',
#   'akan',
#   'mendapat',
#   'Rp',
#   '5',
#   'miliar',
#   'secara',
#   'langsung',
#   '.'],
#  ['Jumlah',
#   'uang',
#   'tersebut',
#   'nantinya',
#   'dialokasikan',
#   'dengan',
#   'rentan',
#   'waktu',
#   'delapan',
#   'bulan',
#   'terhitung',
#   'sejak',
#   'April',
#   'mendatang',
#   '.'],
#  ['Cara', 'pembayarannya', 'beda', 'dari', 'tahun', 'sebelumnya', '.'],
#  ['Yang', 'kami', 'bagikan', 'langsung', 'itu', 'Rp', '5', 'miliar', '.'],
#  ['Sementara',
#   'Rp',
#   '2,5',
#   'miliar',
#   'itu',
#   'berdasarkan',
#   'dengan',
#   'penyempurnaan',
#   'dari',
#   'PSSI',
#   ',',
#   'mengenai',
#   'pengembangan',
#   'usia',
#   'muda',
#   ',',
#   'juga',
#   'masalah',
#   'lisensi',
#   ',',
#   'kata',
#   'Berlinton',
#   '.'],
#  ['Sementara',
#   'itu',
#   ',',
#   'Rp2,5',
#   'miliar',
#   'pembagiannya',
#   'disesuaikan',
#   'kebutuhan',
#   'klub',
#   '.'],
#  ['Setiap',
#   'klub',
#   'akan',
#   'menyetorkan',
#   'rincian',
#   'data',
#   'kegiatan',
#   'untuk',
#   'pengembangan',
#   'usia',
#   'muda',
#   'dan',
#   'lisensi',
#   'mereka',
#   'ke',
#   'PSSI',
#   '.'],
#  ['Nantinya',
#   ',',
#   'PSSI',
#   'akan',
#   'menyerahkan',
#   'ke',
#   'PT',
#   'LIB',
#   ',',
#   'yang',
#   'akan',
#   'memberi',
#   'dana',
#   'tersebut',
#   'kepada',
#   'setiap',
#   'klub',
#   '.'],
#  ['Bisa',
#   'saja',
#   'pembagiannya',
#   'tidak',
#   'sama',
#   'dengan',
#   'klub',
#   'satu',
#   'dengan',
#   'lainnya',
#   '.'],
#  ['Kalau',
#   'satu',
#   'klub',
#   'kegiatannya',
#   'lebih',
#   'banyak',
#   ',',
#   'bisa',
#   'saja',
#   'di',
#   'awal',
#   'pertama',
#   'dia',
#   'akan',
#   'lebih',
#   'banyak',
#   '.'],
#  ['Namun',
#   'totalnya',
#   'tetap',
#   'Rp',
#   '2,5',
#   'miliar',
#   ',',
#   'Berlinton',
#   'menambahkan',
#   '.'],
#  ['Viking', 'merayakan', 'ulang', 'tahun', 'yang', 'ke', '25', '.'],
#  ['Mereka', 'diselamati', 'oleh', 'LA', 'Mania', '.'],
#  ['Dari',
#   'pantauan',
#   'detikSport',
#   ',',
#   'seratusan',
#   'pendukung',
#   'Persela',
#   'Lamongan',
#   'lengkap',
#   'dengan',
#   'atribut',
#   'serba',
#   'berwarna',
#   'biru',
#   'muda',
#   'memenuhi',
#   'tribune',
#   'barat',
#   'samping',
#   ',',
#   'Stadion',
#   'Gelora',
#   'Bandung',
#   'Lautan',
#   'Api',
#   '(',
#   'GBLA',
#   ')',
#   ',',
#   'Kota',
#   'Bandung',
#   ',',
#   'Jawa',
#   'Barat',
#   ',',
#   'saat',
#   'laga',
#   'melawan',
#   'Persib',
#   'di',
#   'lanjutan',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Karena',
#   'Viking',
#   'Club',
#   'atau',
#   'pendukung',
#   'Persib',
#   'berulang',
#   'tahun',
#   'yang',
#   'ke',
#   '25',
#   'Tahun',
#   ',',
#   'para',
#   'pendukung',
#   'Persela',
#   'mengucapkan',
#   'selamat',
#   'dengan',
#   'menyanyikan',
#   'lagu',
#   "'selamat",
#   'ulang',
#   'tahun',
#   "'",
#   'yang',
#   'diiringi',
#   'dengan',
#   'tabuhan',
#   'alat',
#   'musik',
#   'drumband',
#   '.'],
#  ['Nyanyian',
#   'itu',
#   'nyaring',
#   'terdengar',
#   'sebelum',
#   'para',
#   'pemain',
#   'dari',
#   'ke',
#   'dua',
#   'tim',
#   'masuk',
#   'ke',
#   'lapangan',
#   'hijau',
#   '.'],
#  ['Selamat', 'ulang', 'tahun', 'Viking', 'Persib', '.'],
#  ['Sukses', 'selalu', ',', 'teriak', 'pendukung', 'LA', 'Mania', '.'],
#  ['Selain',
#   'di',
#   'tribune',
#   'barat',
#   ',',
#   'nyanyian',
#   "'Selamat",
#   'Ulang',
#   'tahun',
#   "'",
#   'juga',
#   'terdengar',
#   'di',
#   'tribun',
#   'lainnya',
#   'yang',
#   'dinyanyikan',
#   'oleh',
#   'para',
#   'pendukung',
#   'Persib',
#   '.'],
#  ['Setelah',
#   'tim',
#   'Maung',
#   'Bandung',
#   'dan',
#   'Laskar',
#   'Joko',
#   'Tingkir',
#   'masuk',
#   'ke',
#   'lapangan',
#   ',',
#   'pendukung',
#   'Persib',
#   'yang',
#   'berada',
#   'di',
#   'tribune',
#   'timur',
#   'melakukan',
#   'koreografi',
#   '.'],
#  ['Selain',
#   'itu',
#   ',',
#   'kata',
#   "'Anniversary",
# ...
#   'Putera',
#   'resmi',
#   'mendatangkan',
#   'pemain',
#   'baru',
#   'untuk',
#   'mengarungi',
#   'putaran',
#   'kedua',
#   'Liga',
#   '1',
#   '2018',
#   '.'],
#  ['Dia',
#   'adalah',
#   'Marcel',
#   'Sacramento',
#   'yang',
#   'dikontrak',
#   'sampai',
#   'akhir',
#   'musim',
#   '.'],
#  ['Barito',
#   'melakukan',
#   'penandatanganan',
#   'kontrak',
#   'dengan',
#   'Sacramento',
#   'pada',
#   'Sabtu',
#   '.'],
#  ['Pemain',
#   'asal',
#   'Brasil',
#   'itu',
#   'dikontrak',
#   'enam',
#   'bulan',
#   'dengan',
#   'opsi',
#   'perpanjangan',
#   'jika',
#   'penampilannya',
#   'memuaskan',
#   '.'],
#  ['Presiden',
#   'Klub',
#   'Barito',
#   'Hasnuryadi',
#   'Sulaiman',
#   'menyebut',
#   'alasan',
#   'merekrut',
#   'Sacramento',
#   'adalah',
#   'karena',
#   'keinginan',
#   'pelatih',
#   'Jacksen',
#   'F',
#   'Thiago',
#   '.'],
#  ['Kehadirannya',
#   'diharapkan',
#   'bisa',
#   'menambah',
#   'daya',
#   'gedor',
#   'Laskar',
#   'Antasari',
#   'Kami',
#   'memang',
#   'tertarik',
#   'dengan',
#   'Sacramento',
#   'sejak',
#   'awal',
#   'musim',
#   '.'],
#  ['Tapi', 'kami', 'baru', 'berjodoh', 'sekarang', '.'],
#  ['Harapan',
#   'kami',
#   'tentunya',
#   'Sacramento',
#   'bisa',
#   'berkontribusi',
#   'untuk',
#   'tim',
#   'terutama',
#   'di',
#   'lini',
#   'depan',
#   ',',
#   'kata',
#   'Hasnuryadi',
#   '.'],
#  ['Hasnur',
#   'menyebut',
#   'Barito',
#   'memilih',
#   'melepas',
#   'Juan',
#   'Pablo',
#   'Pino',
#   'berdasarkan',
#   'evaluasi',
#   'tim',
#   '.'],
#  ['Pino',
#   'kami',
#   'lepas',
#   'karena',
#   'kurang',
#   'berkontribusi',
#   'untuk',
#   'tim',
#   ',',
#   'katanya',
#   '.'],
#  ['Sacramento',
#   'pun',
#   'mengaku',
#   'sangat',
#   'senang',
#   'bisa',
#   'bergabung',
#   'dengan',
#   'Barito',
#   '.'],
#  ['Dia', 'bertekad', 'untuk', 'memberikan', 'kemampuan', 'terbaiknya', '.'],
#  ['Saya', 'tidak', 'menargetkan', 'gol', 'dengan', 'Barito', 'Putera', '.'],
#  ['Terpenting',
#   'buat',
#   'saya',
#   ',',
#   'bisa',
#   'memberikan',
#   'kemenangan',
#   'dalam',
#   'setiap',
#   'pertandingan',
#   'yang',
#   'dimainkan',
#   ',',
#   'kata',
#   'Sacramento',
#   '.'],
#  ['Di',
#   'Barito',
#   ',',
#   'eks',
#   'pemain',
#   'Semen',
#   'Padang',
#   'itu',
#   'memilih',
#   'angka',
#   'delapan',
#   'sebagai',
#   'nomor',
#   'punggungnya',
#   '.'],
#  ['Angka', 'itu', 'dianggap', 'membawa', 'keberuntungan', 'baginya', '.'],
#  ['Ayah',
#   'saya',
#   'suka',
#   'sekali',
#   'angka',
#   'delapan',
#   'dan',
#   'waktu',
#   'di',
#   'Semen',
#   'Padang',
#   'saya',
#   'menggunakan',
#   'nomor',
#   'ini',
#   'saat',
#   'saya',
#   'menjadi',
#   'topskorer',
#   ',',
#   'katanya',
#   '.'],
#  ['Sebelum',
#   'bergabung',
#   'dengan',
#   'Barito',
#   ',',
#   'Sacramento',
#   'pernah',
#   'membela',
#   'tiga',
#   'klub',
#   'Indonesia',
#   ':',
#   'Semen',
#   'Padang',
#   ',',
#   'Madura',
#   'United',
#   ',',
#   'dan',
#   'Persipura',
#   'Jayapura',
#   '.'],
#  ['Seorang',
#   'suporter',
#   'Persija',
#   'Jakarta',
#   'tewas',
#   'dihajar',
#   'oleh',
#   'sekumpulan',
#   'oknum',
#   'pendukung',
#   'Persib',
#   'Bandung',
#   '.'],
#  ['Persija',
#   'berharap',
#   'ke',
#   'depannya',
#   'ada',
#   'hukuman',
#   'yang',
#   'benar-benar',
#   'keras',
#   '.'],
#  ['Haringga',
#   'Sirila',
#   ',',
#   'anggota',
#   'The',
#   'Jakmania',
#   ',',
#   'meninggal',
#   'usai',
#   'dikeroyok',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Bandung',
#   'Lautan',
#   'Api',
#   'jelang',
#   'laga',
#   'Persija',
#   'vs',
#   'Persib',
#   ',',
#   'Minggu',
#   'kemarin',
#   '.'],
#  ['Ini',
#   'adalah',
#   'korban',
#   'ketujuh',
#   'sejak',
#   '2012',
#   ',',
#   'dari',
#   'rivalitas',
#   'Persija',
#   '-',
#   'Persib',
#   '.'],
#  ['Sebelumnya',
#   'Badan',
#   'Olahraga',
#   'Profesional',
#   'Indonesia',
#   '(',
#   'BOPI',
#   ')',
#   ',',
#   'Menteri',
#   'Pemuda',
#   'dan',
#   'Olahraga',
#   'Imam',
#   'Nahrawi',
#   ',',
#   'dan',
#   'Asosiasi',
#   'Pesepakbola',
#   'Profesional',
#   'Indonesia',
#   '(',
#   'APPI',
#   ')',
#   'memang',
#   'mengusulkan',
#   'liga',
#   'dihentikan',
#   'sementara',
#   '.'],
#  ['Direktur',
#   'Utama',
#   'Persija',
#   'Gede',
#   'Widiade',
#   'sangat',
#   'menyayangkan',
#   'kejadian',
#   'suporter',
#   'tewas',
#   'terus',
#   'berulang',
#   '.'],
#  ['Berkaca',
#   'dari',
#   'rentetan',
#   'yang',
#   'tak',
#   'kunjung',
#   'berhenti',
#   'ini',
#   ',',
#   'Gede',
#   'berharap',
#   'ke',
#   'depannya',
#   'ada',
#   'hukuman',
#   'yang',
#   'benar-benar',
#   'membuat',
#   'jera',
#   'suporter',
#   'dan',
#   'klub',
#   '.'],
#  ['Gede',
#   'menilai',
#   'selama',
#   'ini',
#   'sanksi-sanksi',
#   'atas',
#   'kejadian',
#   'serupa',
#   'tak',
#   'pernah',
#   'benar-benar',
#   'bikin',
#   'kapok',
#   ',',
#   'semisal',
#   'denda',
#   'yang',
#   'relatif',
#   'mudah',
#   'dibayar',
#   'tim-tim',
#   'besar',
#   'macam',
#   'Persija',
#   ',',
#   'Persib',
#   ',',
#   'Persebaya',
#   'Surabaya',
#   ',',
#   'atau',
#   'Arema',
#   'FC',
#   '.'],
#  ['Sementara',
#   'suporter',
#   'hampir',
#   'tak',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'sanksi',
#   'tersebut',
#   '.'],
#  ['Mungkin',
#   'kemarin',
#   'dari',
#   'BOPI',
#   'merasa',
#   'sakit',
#   'dengan',
#   'kejadian',
#   'ini',
#   ',',
#   'lalu',
#   'seminggu',
#   '(',
#   'liga',
#   ')',
#   'tidak',
#   'boleh',
#   'main',
#   '.'],
#  ['Itu', 'kalau', 'sekadar', 'shock', 'therapy', ',', 'boleh', '.'],
#  ['Dari', 'pak', 'menteri', 'usul', 'dua', 'minggu', '.'],
#  ['Dari', 'APPI', 'usul', 'sebulan-dua', 'bulan', '.'],
#  ['Tapi',
#   'memangnya',
#   'mudah',
#   '?',
#   'Efek',
#   'pemberhentian',
#   'tidak',
#   'semudah',
#   'itu',
#   ',',
#   'jangan',
#   'putuskan',
#   'karena',
#   'emosional',
#   ',',
#   'kata',
#   'Gede',
#   'dalam',
#   'talkshow',
#   'Indonesia',
#   'Lawyers',
#   'Clus',
#   '(',
#   'ILC',
#   ')',
#   ',',
#   'Selasa',
#   'malam',
#   '.'],
#  ['Yang',
#   'paling',
#   'penting',
#   'dirumuskan',
#   ',',
#   'kalau',
#   'sampai',
#   'terjadi',
#   'lagi',
#   ',',
#   'hukumannya',
#   'tak',
#   'bisa',
#   'ditolerir',
#   'lagi',
#   '.'],
#  ['Downgrade',
#   '(',
#   'degradasi',
#   ')',
#   'atau',
#   'satu',
#   'tahun',
#   'tidak',
#   'boleh',
#   'main',
#   'di',
#   'kandang',
#   'dan',
#   'tanpa',
#   'penonton',
#   '.'],
#  ['Jelas',
#   'menurut',
#   'saya',
#   ',',
#   'kalau',
#   'sampai',
#   'suporter',
#   'tidak',
#   'diizinkan',
#   'menonton',
#   'setahun',
#   ',',
#   'baik',
#   'Persib',
#   ',',
#   'Persija',
#   ',',
#   'atau',
#   'mungkin',
#   'Persebaya',
#   ',',
#   'sama',
#   'saja',
#   'dengan',
#   'dia',
#   'tidak',
#   'salat',
#   'setahun',
#   '.'],
#  ['Bayangin', ',', 'masuk', 'neraka', 'dia', ',', 'imbuhnya', '.'],
#  ['Gede',
#   'juga',
#   'berharap',
#   'ada',
#   'evaluasi',
#   'nyata',
#   'terhadap',
#   'regulasi',
#   'saat',
#   'ini',
#   '.'],
#  ['Sebab',
#   'belum',
#   'ada',
#   'aturan',
#   'tegas',
#   'soal',
#   'klub-klub',
#   'dan',
#   'suporternya',
#   'yang',
#   'terlibat',
#   'kekerasan',
#   'yang',
#   'berujung',
#   'kematian',
#   '.'],
#  ['Perlu',
#   'ada',
#   'tindakan',
#   'konkret',
#   'untuk',
#   'mengevaluasi',
#   'regulasi',
#   'yang',
#   'ada',
#   '.'],
#  ['Kalau',
#   'dari',
#   'polisi',
#   'jelas',
#   ':',
#   'membunuh',
#   'dihukum',
#   '17',
#   'tahun',
#   '.'],
#  ['Efek', 'jeranya', 'ada', '.'],
#  ['Tapi', 'kalau', 'klub', ',', 'tidak', 'ada', '.'],
#  ['Ini', 'mohon', 'dipikirkan', ',', 'sambungnya', '.'],
#  ['Hukuman',
#   'apapun',
#   ',',
#   'dari',
#   'institusi',
#   'apapun',
#   ',',
#   'kalau',
#   'tidak',
#   'memberikan',
#   'efek',
#   'jera',
#   'ke',
#   'klub',
#   'dan',
#   'suporter',
#   'ya',
#   'tidak',
#   'signifikan',
#   '.'],
#  ['Coba',
#   'hukuman',
#   'ini',
#   'jangan',
#   'diputuskan',
#   'searah',
#   ',',
#   'ajak',
#   'kami',
#   ',',
#   'ajak',
#   'semua',
#   'bicara',
#   '.'],
#  ['Cari',
#   'tahu',
#   'apa',
#   'yang',
#   'ditakutkan',
#   'suporter',
#   'dan',
#   'klub',
#   ',',
#   'tandas',
#   'Gede',
#   '.'],
#  ['Duel',
#   'itu',
#   'akan',
#   'menjadi',
#   'yang',
#   'keenam',
#   'antara',
#   'Garuda',
#   'Muda',
#   'dengan',
#   'Gajah',
#   'Putih',
#   '.'],
#  ['Pertandingan',
#   'Thailand',
#   'melawan',
#   'Indonesia',
#   'akan',
#   'berlangsung',
#   'di',
#   'Stadion',
#   'Gelora',
#   'Delta',
#   ',',
#   'Sidoarjo',
#   ',',
#   'Sabtu',
#   'malam',
#   'pukul',
#   '19.00',
#   'WIB',
#   '.'],
#  ['Kedua',
#   'tim',
#   'sama-sama',
#   'belum',
#   'terkalahkan',
#   'di',
#   'ajang',
#   'Piala',
#   'AFF',
#   'U-16',
#   'tahun',
#   'ini',
#   '.'],
#  ['Indonesia',
#   'masih',
#   'sempurna',
#   'dengan',
#   'catatan',
#   'enam',
#   'kemenangan',
#   '.'],
#  ['Sementara',
#   'itu',
#   ',',
#   'Thailand',
#   'bisa',
#   'membukukan',
#   'empat',
#   'kemenangan',
#   'dan',
#   'sekali',
#   'hasil',
#   'imbang',
#   '.'],
#  ['Selalu', 'ada', 'pemenang', 'dalam', 'laga', 'itu', '.'],
#  ['Thailand',
#   'masih',
#   'unggul',
#   'rekor',
#   'pertemuan',
#   'dengan',
#   'catatan',
#   'tiga',
#   'kemenangan',
#   '.'],
#  ['Sementara',
#   'itu',
#   ',',
#   'Indonesia',
#   'dua',
#   'kali',
#   'menaklukkan',
#   'Thailand',
#   '.'],
#  ['Skor',
#   'terbesar',
#   'duel',
#   'Indonesia',
#   'melawan',
#   'Thailand',
#   'di',
#   'ajang',
#   'Piala',
#   'AFF',
#   'U-16',
#   'terjadi',
#   'di',
#   'tahun',
#   '2005',
#   '.'],
#  ['Saat',
#   'itu',
#   ',',
#   'Thailand',
#   'memetik',
#   'kemenangan',
#   'dengan',
#   'skor',
#   '3-2',
#   '.'],
#  ['Selain',
#   'masih',
#   'memegang',
#   'rekor',
#   'sempurna',
#   ',',
#   'tim',
#   'asuhan',
#   'Fakhri',
#   'Husaini',
#   'mempunyai',
#   'modal',
#   'bagus',
#   'lain',
#   'menatap',
#   'pertandingan',
#   'melawan',
#   'Thailand',
#   '.'],
#  ['Mocahmmad',
#   'Supriadi',
#   'cs',
#   'memetik',
#   'kemenangan',
#   '1-0',
#   'atas',
#   'Thailand',
#   'saat',
#   'menjalani',
#   'kualifikasi',
#   'Piala',
#   'Asia',
#   '2018',
#   '.'],
#  ['Timnas', 'Indonesia', 'U', '.'],
#  ['Ketua',
#   'Umum',
#   'PSSI',
#   ',',
#   'Edy',
#   'Rahmayadi',
#   ',',
#   'berharap',
#   'hasil',
#   'ini',
#   'memotivasi',
#   'atlet',
#   'cabang',
#   'olahraga',
#   'lain',
#   'di',
#   'Asian',
#   'Games',
#   '2018',
#   '.'],
#  ['Indonesia',
#   'memulai',
#   'perjalanannya',
#   'di',
#   'Grup',
#   'A',
#   'Asian',
#   'Games',
#   '2018',
#   'cabor',
#   'sepakbola',
#   'dengan',
#   'kemenangan',
#   'telak',
#   '4-0',
#   'atas',
#   'Taiwan',
#   '.'],
#  ['Hasil',
#   'itu',
#   'membuat',
#   'Garuda',
#   'Muda',
#   'untuk',
#   'sementara',
#   'duduk',
#   'di',
#   'posisi',
#   'kedua',
#   'Grup',
#   'A',
#   'dengan',
#   'tiga',
#   'poin',
#   ',',
#   'di',
#   'bawah',
#   'Palestina',
#   'yang',
#   'punya',
#   'empat',
#   'poin',
#   'dari',
#   'dua',
#   'laga',
#   '.'],
#  ['Edy',
#   'menyampaikan',
#   'apa',
#   'yang',
#   'dikatakan',
#   'oleh',
#   'Chief',
#   'de',
#   'Mission',
#   '(',
#   'CdM',
#   ')',
#   'Asian',
#   'Games',
#   '2018',
#   ',',
#   'Komjen',
#   'Pol',
#   '.'],
#  ['Syafruddin',
#   'Prawiranegara',
#   ',',
#   'bahwa',
#   'hasil',
#   'ini',
#   'bisa',
#   'jadi',
#   'motivasi',
#   'untuk',
#   'atlet',
#   'Indonesia',
#   'lainnya',
#   '.'],
#  ['Terlebih',
#   ',',
#   'Presiden',
#   'Indonesia',
#   ',',
#   'Joko',
#   'Widodo',
#   ',',
#   'sudah',
#   'memasang',
#   'target',
#   'agar',
#   'kontingen',
#   'Indonesia',
#   'finis',
#   'di',
#   'posisi',
#   'ke-10',
#   'dalam',
#   'daftar',
#   'perolehan',
#   'medali',
#   '.'],
#  ['Presiden',
#   'menyampaikan',
#   'Insya',
#   'Allah',
#   'kita',
#   'di',
#   '10',
#   'besar',
#   '.'],
#  ['Dengan',
#   'motivasi',
#   'ini',
#   'kita',
#   'diperintahkan',
#   'oleh',
#   'presiden',
#   'untuk',
#   'punya',
#   'motivasi',
#   'besar',
#   ',',
#   "''",
#   'kata',
#   'Edy',
#   'di',
#   'Stadion',
#   'Patriot',
#   'Candrabhaga',
#   ',',
#   'Minggu',
#   '(',
#   '12/8/2018',
#   ')',
#   'malam',
#   'WIB',
#   '.'],
#  ['Edy',
#   'juga',
#   'menyebut',
#   'bahwa',
#   'kemenangan',
#   '4-0',
#   'atas',
#   'Taiwan',
#   'adalah',
#   'hasil',
#   'yang',
#   'hebat',
#   '.'],
#  ['Itu',
#   'tak',
#   'lepas',
#   'dari',
#   'level',
#   'pertandingannya',
#   'yang',
#   'sudah',
#   'lebih',
#   'di',
#   'atas',
#   'dari',
#   'turnamen',
#   'di',
#   'Asia',
#   'Tenggara',
#   '.'],
#  ['``', 'Ini', 'hasil', 'yang', 'hebat', '.'],
#  ['Ini', 'kelasnya', 'di', 'atas', 'ASEAN', '.'],
#  ['Tadi',
#   'saja',
#   'Palestina',
#   'lawan',
#   'Laos',
#   '(',
#   'cuma',
#   'menang',
#   ')',
#   '2-1',
#   'dan',
#   'kita',
#   'menang',
#   '4-0',
#   '.'],
#  ['Saya',
#   'berharap',
#   'kita',
#   'lawan',
#   'Palestina',
#   'nanti',
#   'bisa',
#   'menang',
#   '2-0',
#   ',',
#   "''",
#   'kata',
#   'Edy',
#   'lagi',
#   '.'],
#  ['Stefano',
#   'Lilipaly',
#   'tampil',
#   'bagus',
#   'di',
#   'Liga',
#   '1',
#   'musim',
#   'ini',
#   ',',
#   'namun',
#   'tak',
#   'dipanggil',
#   'memperkuat',
#   'tim',
#   'nasional',
#   'Indonesia',
#   'U-23',
#   '.'],
#  ['Luis', 'Milla', 'mengungkapkan', 'alasannya', '.'],
#  ['Tidak',
#   'ada',
#   'nama',
#   'Lilipaly',
#   'dalam',
#   'daftar',
#   'skuat',
#   'pemain',
#   'senior',
#   'yang',
#   'dipangggil',
#   'oleh',
#   'Luis',
#   'Milla',
#   'untuk',
#   'membantul',
#   'timnas',
#   'U-23',
#   '.'],
#  ['Pelatih',
#   'asal',
#   'Spanyol',
#   'itu',
#   'memilih',
#   'memanggil',
#   'beberapa',
#   'pemain',
#   'senior',
#   'baru',
#   'seperti',
#   'Riko',
#   'Simanjuntak',
#   'dan',
#   'Alberto',
#   'Goncalves',
#   '.'],
#  ['Milla',
#   'menyebut',
#   'timnas',
#   'U-23',
#   'sudah',
#   'punya',
#   'pemain-pemain',
#   'berkarakter',
#   'seperti',
#   'Lilipaly',
#   'dengan',
#   'kualitas',
#   'yang',
#   'tak',
#   'kalah',
#   'bagus',
#   '.'],
#  ['Oleh',
#   'karena',
#   'itu',
#   ',',
#   'dia',
#   'menggunakan',
#   'jatah',
#   'pemain',
#   'senior',
#   'untuk',
#   'mengisi',
#   'posisi',
#   'lain',
#   'yang',
#   'masih',
#   'perlu',
#   'ditambal',
#   'secara',
#   'kualitas',
#   '.'],
#  ['Di',
#   'posisi',
#   'Lilipaly',
#   ',',
#   'timnas',
#   'U-23',
#   'punya',
#   'nama-nama',
#   'seperti',
#   'Evan',
#   'Dimas',
#   ',',
#   'Septian',
#   'David',
#   'Maulana',
#   ',',
#   'dan',
#   'Saddil',
#   'Ramdani',
#   '.'],
#  ['Spekulasi', 'yang', 'sangat', 'baik', '.'],
#  ['Lilipaly', 'adalah', 'pemain', 'bagus', '.'],
#  ['Namun',
#   'perlu',
#   'diingat',
#   ',',
#   'kami',
#   'hanya',
#   'bisa',
#   'bawa',
#   '3',
#   'pemain',
#   'senior',
#   '.'],
#  ['Lilipaly', 'pemain', 'bagus', '.'],
#  ['Tak', 'ada', 'keraguan', 'soal', 'itu', ',', 'kata', 'Luis', 'Milla', '.'],
#  ['Kami',
#   'juga',
#   'perlu',
#   'kiper',
#   'berpengalaman',
#   'dan',
#   'juga',
#   'fokus',
#   'untuk',
#   'bek',
#   'tengah',
#   ',',
#   'Tapi',
#   'paling',
#   'penting',
#   'kepribadian',
#   'yang',
#   'bagus',
#   ',',
#   'anak',
#   'muda',
#   'punya',
#   'harmoni',
#   'filosofi',
#   'gaya',
#   'bermain',
#   'dan',
#   'di',
#   'luar',
#   'gaya',
#   'hidup',
#   'yang',
#   'baik',
#   '.'],
#  ['Pemain',
#   'senior',
#   'jadi',
#   'contoh',
#   'di',
#   'luar',
#   'dan',
#   'dalam',
#   ',',
#   'saya',
#   'analisis',
#   'di',
#   'luar',
#   'sepakbola',
#   'pemain',
#   'senior',
#   'bisa',
#   'apa',
#   'tidak',
#   'jadi',
#   'contoh',
#   ',',
#   'paparnya',
#   '.'],
#  ['Selama',
#   'membentuk',
#   'timnas',
#   'U-23',
#   ',',
#   'Milla',
#   'telah',
#   'memanggil',
#   'sejumlah',
#   'pemain',
#   'senior',
#   '.'],
#  ['Antara',
#   'lain',
#   'Ilija',
#   'Spasojevic',
#   ',',
#   'Andritany',
#   'Ardhiyasa',
#   ',',
#   'Lerby',
#   'Eliandry',
#   ',',
#   'Riko',
#   'Simanjuntak',
#   ',',
#   'Victor',
#   'Igbonefo',
#   ',',
#   'Alberto',
#   'Goncalves',
#   ',',
#   'Teja',
#   'Paku',
#   'Alam',
#   ',',
#   'dan',
#   'M',
#   'Ridho',
#   '.'],
#  ['Persija',
#   'Jakarta',
#   'sukses',
#   'meredam',
#   'lini',
#   'depan',
#   'Persib',
#   'Bandung',
#   '.'],
#  ['Pelatih',
#   'Stefano',
#   'Cugurra',
#   'Teco',
#   'menyebut',
#   'adanya',
#   'Maman',
#   'Abdurrahman',
#   'dan',
#   'Sandi',
#   'Sute',
#   'membuat',
#   'pertahanannya',
#   'terjamin',
#   '.'],
#  ['Persija',
#   'mengamankan',
#   'tiga',
#   'poin',
#   'dalam',
#   'laga',
#   'melawan',
#   'Persib',
#   'di',
#   'Stadion',
#   'PTIK',
#   ',',
#   'pada',
#   'partai',
#   'tunda',
#   'Liga',
#   '1',
#   '2018',
#   'pekan',
#   'keenam',
#   ',',
#   'Sabtu',
#   'malam',
#   '.'],
#  ['Kemenangan',
#   'tersebut',
#   'dipersembahkan',
#   'oleh',
#   'gol',
#   'semata',
#   'wayang',
#   'Jaimerson',
#   'Xavier',
#   'di',
#   'menit',
#   'ke-16',
#   '.'],
#  ['Namun',
#   'Maman',
#   'dan',
#   'Sute',
#   'menjalankan',
#   'tugasnya',
#   'dengan',
#   'baik',
#   'sehingga',
#   'gawang',
#   'Persija',
#   'lebih',
#   'aman',
#   'dari',
#   'gempuran',
#   'pemain',
#   'depan',
#   'Persib',
#   'Ezechiel',
#   "N'Douassel",
#   'dan',
#   'Jontahan',
#   'Bauman',
#   ',',
#   'yang',
#   'sejauh',
#   'ini',
#   'sudah',
#   'mencetak',
#   '16',
#   'gol',
#   '.'],
#  ['Kami',
#   'punya',
#   'waktu',
#   'sedikit',
#   'buat',
#   'persiapan',
#   'lawan',
#   'Persib',
#   ',',
#   'kami',
#   'punya',
#   'waktu',
#   'hanya',
#   'untuk',
#   'latihan',
#   'satu',
#   'taktik',
#   '.'],
#  ['Tapi',
#   'Maman',
#   'sama',
#   'Sandi',
#   'harus',
#   'siap',
#   'untuk',
#   'duel',
#   ',',
#   'dan',
#   'mereka',
#   'fight',
#   'untuk',
#   'main',
#   'keras',
#   'sama',
#   'Bandung',
#   'untuk',
#   'bantu',
#   'kami',
#   'menang',
#   ',',
#   'ucap',
#   'Teco',
#   '.'],
#  ['Perhatian', 'utama', 'Teco', 'adalah', 'recovery', 'pemain', '.'],
#  ['Kami',
#   'harus',
#   'lihat',
#   'siapa',
#   'pemain',
#   'yang',
#   'cedera',
#   ',',
#   'baru',
#   'kami',
#   'buat',
#   'plan',
#   'siapa',
#   'yang',
#   'berangkat',
#   'ke',
#   'Serui',
#   '.'],
#  ...]

# %% [markdown]
# ### Train the corpus

# %%
print('Training Word2Vec Model...')
start_time = time.time()

wv = Word2Vec(sentences=korpus, size=100, alpha=0.025, window=5, min_count=5,
                 max_vocab_size=None, sample=1e-3, seed=1, workers=3, min_alpha=0.0001,
                 sg=0, hs=0, negative=5, cbow_mean=1)
wv.save('word2vec.model')

finish_time = time.time()
print('Finished. Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# Training Word2Vec Model...
# Finished. Elapsed time: 0:00:27.856682

# %%
# most similar to 'yg' based on corpus
wv.wv.most_similar("yg")
# Out:
# [('anda', 0.6072468757629395),
#  ('kalian', 0.541106104850769),
#  ('kamu', 0.5317510962486267),
#  ('Harus', 0.5300275087356567),
#  ('Yang', 0.5289517045021057),
#  ('baiknya', 0.526628851890564),
#  ('yang', 0.521325945854187),
#  ('tdk', 0.5197136998176575),
#  ('Semuanya', 0.5016289949417114),
#  ('toh', 0.4994879961013794)]

# %%
# most similar to 'gak' based on corpus
wv.wv.most_similar("gak")
# Out:
# [('enggak', 0.8394542336463928),
#  ('ndak', 0.8165795207023621),
#  ('ga', 0.7791200876235962),
#  ('Nggak', 0.7657572031021118),
#  ('emang', 0.7528153657913208),
#  ('nggak', 0.7525509595870972),
#  ('tuh', 0.7350001335144043),
#  ('kulitnya', 0.7234979867935181),
#  ('banget', 0.7208560109138489),
#  ('gitu', 0.7177690267562866)]

# %% [markdown]
# ### Slang corpus

# %%
korpus_slang = pd.read_csv("colloquial-indonesian-lexicon.csv")

# %%
korpus_slang
# Out:
#           slang         formal  In-dictionary  \
# 0          woww            wow              1
# 1         aminn           amin              1
# 2           met        selamat              1
# 3        netaas        menetas              1
# 4       keberpa       keberapa              0
# ...         ...            ...            ...
# 15001  gataunya  enggak taunya              0
# 15002      gtau     enggak tau              0
# 15003     gatau     enggak tau              0
# 15004     fans2        fan-fan              0
# 15005   gaharus   enggak harus              0
#
#                                                  context    category1  \
# 0                                                    wow     elongasi
# 1      Selamat ulang tahun kakak tulus semoga panjang...     elongasi
# 2      Met hari netaas kak!? Wish you all the best @t...    abreviasi
# 3      Met hari netaas kak!? Wish you all the best @t...     afiksasi
# 4                               Birthday yg keberpa kak?    abreviasi
# ...                                                  ...          ...
# 15001  Ini kaya nenek2 ya beb gataunya agnezz @yugime...      akronim
# 15002  Stidaknya mrka may berkarya Dan berusaha yg tr...      akronim
# 15003                                      Ih gatau malu      akronim
# 15004  Jkt48 adalah tempat di mana sesama fans saling...  reduplikasi
# 15005  belajar tuh bisa dimana aja gaharus belajar di...      akronim
#
#           category2 category3
# 0                 0         0
# 1                 0         0
# 2                 0         0
# 3          elongasi         0
# 4                 0         0
# ...             ...       ...
# 15001             0         0
# 15002     abreviasi         0
# 15003             0         0
# 15004  naturalisasi         0
# 15005             0         0
#
# [15006 rows x 7 columns]

# %%
#Filter data slang
korpus_slang = korpus_slang[korpus_slang.columns[0:2]]

# %%
korpus_slang
# Out:
#           slang         formal
# 0          woww            wow
# 1         aminn           amin
# 2           met        selamat
# 3        netaas        menetas
# 4       keberpa       keberapa
# ...         ...            ...
# 15001  gataunya  enggak taunya
# 15002      gtau     enggak tau
# 15003     gatau     enggak tau
# 15004     fans2        fan-fan
# 15005   gaharus   enggak harus
#
# [15006 rows x 2 columns]

# %%
#Menggunakan perbandingan dengan word2vec yang ada dan edit distance untuk membuat kata menjadi kata formal
print("Processing data...")
start_time = time.time()

corr_comments = []
slang_words = []
reco_words = []
corr_word = 0
tot_word = 0
for comment in tok_comments:
    corr_comment = []
    slang_word = []
    for sub_comment in comment:
        if sub_comment in wv.wv.vocab:
            sim_slang = korpus_slang[korpus_slang['slang'] == sub_comment]
            if len(sim_slang) != 0:
                mode_word = sim_slang.formal.mode()[0]
                corr_word = corr_word + 1
                corr_comment.append(mode_word)
            else:
                corr_word = corr_word + 1
                corr_comment.append(sub_comment)
        else:
            comment_found = False
            sim_slang = korpus_slang[korpus_slang['slang'] == sub_comment]
            if len(sim_slang) != 0:
                mode_word = sim_slang.formal.mode()[0]
                corr_word = corr_word + 1
                corr_comment.append(mode_word)
                comment_found = True
            else:
                rat_words = []
                for slang in korpus_slang['slang']:
                    rat_word = nltk.edit_distance(sub_comment, slang)
                    rat_words.append(rat_word)
                min_rat = rat_words.index(min(rat_words))
                value = str(korpus_slang.formal.loc[min_rat])
                corr_words = corr_word + 1
                corr_comment.append(value)
                slang_words.append(sub_comment + " = " + value)
                comment_found = True
            if comment_found ==  False:
                corr_comment.append(sub_comment)
                slang_words.append(sub_comment + " = " + "Not Found")
        tot_word = tot_word + 1
    corr_comments.append(corr_comment)
print("Total kata yang diperbaiki : " + str(corr_word) + " dari total semua kata : " + str(tot_word))
finish_time = time.time()
print('Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# Processing data...
# Total kata yang diperbaiki : 13855 dari total semua kata : 15675
# Elapsed time: 0:12:54.299179

# %%
corr_comments
# Out:
# [['wow',
#   'enggak',
#   'sekalian',
#   'pak',
#   'selawat',
#   'ke',
#   'dari',
#   'kan',
#   'banyak',
#   'koruptor',
#   'disana'],
#  ['mantab',
#   'ini',
#   'baru',
#   'dakwah',
#   'yang',
#   'sejati',
#   'kalo',
#   'di',
#   'tempat',
#   'umum',
#   'mah',
#   'dah',
#   'biasa',
#   'ini',
#   'luar',
#   'biasa'],
#  ['salut', 'buat', 'gus', 'meminta'],
#  ['yang',
#   'nyinyir',
#   'enggak',
#   'pernah',
#   'lihat',
#   'dan',
#   'baca',
#   'atau',
#   'mengetahui',
#   'sejarah',
#   'dakwah',
#   'maling',
#   'ulang',
#   'kali',
#   'bagaimana',
#   'ada',
#   'cara',
#   'demi',
#   'kebaikan',
#   'asal',
#   'jangan',
#   'saja',
#   'dengan',
#   'cara',
#   'berzina',
#   'lakukan',
#   'dengan',
#   'porsi',
#   'dan',
#   'semakin',
#   'yang',
#   'tepat'],
#  ['ada',
#   'apa-apanya',
#   'sholawat',
#   'lebih',
#   'baik',
#   'ajak',
#   'ke',
#   'majelis',
#   'ilmu'],
#  ['setiap',
#   'ulama',
#   'punya',
#   'jalan',
#   'dan',
#   'cara',
#   'dakwah',
#   'masing-masing',
#   'jika',
#   'kamu',
#   'melihat',
#   'terbuka',
#   'lawan',
#   'dengan',
#   'ambekan',
#   'jika',
#   'tidak',
#   'mampu',
#   'lawan',
#   'dengan',
#   'mulut-mulut',
#   'jika',
#   'tidak',
#   'mampu',
#   'juga',
#   'dengan',
#   'hati-hati',
#   'itulah',
#   'salihah',
#   'lemahnya',
#   'iman',
#   'itu',
#   'sudah',
#   'menjadi',
#   'kewajiban',
#   'para',
#   'ulama',
#   'kalo',
#   'yang',
#   'komen',
#   'masih',
#   'ada',
#   'yang',
#   'nyinyir',
#   'ulama',
#   'berarti',
#   'otaknya',
#   'sudah',
#   'disini',
#   'politik'],
#  ['menyarankan', 'menontonnya', 'ya'],
#  ['itulah', 'ceramah', 'yang', 'sebenarnya'],
#  ['besok', 'bugil', 'saja', 'selawat'],
#  ['bedanya',
#   'gus',
#   'meminta',
#   'dengan',
#   'tapi',
#   'hati',
#   'bagaikan',
#   'surga',
#   'dan',
#   'neraka',
#   'di',
#   'surga',
#   'penuh',
#   'kasih',
#   'di',
#   'neraka',
#   'penuh',
#   'penghancuran'],
#  ['kenapa',
#   'di',
#   'tempat',
#   'kerjanya',
#   'mending',
#   'diundang',
#   'ke',
#   'masjid',
#   'ponpes',
#   'aula',
#   'supaya',
#   'berbusana',
#   'yang',
#   'sopan'],
#  ['nah',
#   'ini',
#   'ulama',
#   'benaran',
#   'di',
#   'semua',
#   'jangan',
#   'kak',
#   'malah',
#   'diblokir',
#   'sana',
#   'sini'],
#  ['keren',
#   'saya',
#   'pernah',
#   'dapat',
#   'info',
#   'seperti',
#   'ini',
#   'dari',
#   'keyakinan',
#   'yang',
#   'lain',
#   'tapi',
#   'tujuan',
#   'utama',
#   'kurang',
#   'lebih',
#   'sama',
#   'lah',
#   'kita',
#   'ambil',
#   'sisi',
#   'positifnya',
#   'saja',
#   'terimakasih',
#   'atas',
#   'niat',
#   'baiknya',
#   'saya',
#   'yakin',
#   'pasti',
#   'bermanfaat'],
#  ['hebat',
#   'lanjutkan',
#   'makna',
#   'dakwah',
#   'sebenarnya',
#   'sampaikan',
#   'marwah',
#   'islam',
#   'dengan',
#   'penuh',
#   'kedamaian',
#   'dan',
#   'berikan',
#   'pemahaman',
#   'bukan',
#   'dengan',
#   'kebencian',
#   'dan',
#   'pemaksaan'],
#  ['diskotik', 'syariah', 'jaman dulunya', 'nih', 'mantap'],
#  ['niat',
#   'dan',
#   'tujuan',
#   'yang',
#   'baik',
#   'pasti',
#   'mendapat',
#   'berkah',
#   'dari',
#   'allah',
#   'buat'],
#  ['mantap', 'di', 'gedung', 'dari', 'perlu', 'juga', 'kayanya', 'gus'],
#  ['salut', 'buat', 'owner', 'klub', 'ini'],
#  ['loh', 'ini', 'baru', 'luar', 'biasa'],
#  ['dapat', 'gratis', 'karena', 'sudah', 'punya', 'apa'],
#  ['sebaiknya',
#   'dimanapun',
#   'dilakukan',
#   'bahas-bahas',
#   'kesopanan',
#   'tetap',
#   'harus',
#   'dijaga'],
#  ['pemandu',
#   'lagi',
#   'yang',
#   'di',
#   'manga',
#   'besar',
#   'kayaknya',
#   'perlu',
#   'juga',
#   'diajak',
#   'mengaji',
#   'bos'],
#  ['jujur',
#   'ini',
#   'keren',
#   'cara',
#   'menyebarkan',
#   'agama',
#   'yang',
#   'baik',
#   'dan',
#   'ingat',
#   'simpatik',
#   'semoga',
#   'sukses'],
#  ['kembang',
#   'alim',
#   'kemudian',
#   'jadi',
#   'maling',
#   'menurut',
#   'saya',
#   'lebih',
#   'baik',
#   'maling',
#   'kemudian',
#   'jadi',
#   'alim'],
#  ['sekadar',
#   'ulama',
#   'mengajak',
#   'mereka',
#   'yang',
#   'masih',
#   'tersesat',
#   'untuk',
#   'kembali',
#   'bukan',
#   'menjelekkan',
#   'orang',
#   'lain',
#   'tapi',
#   'merangkul',
#   'mereka'],
#  ['ini', 'namanya', 'apa', 'ya'],
#  ['selamat',
#   'berjuang',
#   'justru',
#   'tempat',
#   'seperti',
#   'itu',
#   'yang',
#   'butuh',
#   'lebih',
#   'banyak',
#   'perhatian',
#   'dari',
#   'ulama'],
#  ['semoga', 'diberikan', 'hidayah'],
#  ['hati',
#   'hati',
#   'memviralkan',
#   'berita',
#   'yang',
#   'mengandung',
#   'isu',
#   'agama',
#   'bisa',
#   'menjadi',
#   'sumber',
#   'fitnah',
#   'dan',
#   'lahan',
#   'para',
#   'benaran',
#   'yang',
#   'kerjanya',
#   'mengadu',
#   'domba',
#   'anak',
#   'bangsa',
#   'dan',
#   'rakyat',
#   'indonesia',
#   'hendak',
#   'sudah',
#   'jadi',
#   'korbannya'],
#  ['subhanallah',
#   'semoga',
#   'mendapatkan',
#   'hidayah',
#   'dari',
#   'allah',
#   'buat',
#   'amin'],
#  ['ulama', 'mengurus', 'umat', 'berarti', 'senangi', 'gus'],
#  ['luar',
#   'biasa',
#   'terharu',
#   'mengajak',
#   'orang',
#   'lain',
#   'yang',
#   'dianggap',
#   'salah',
#   'dengan',
#   'cara',
#   'yang',
#   'baik',
#   'bukan',
#   'dengan',
#   'caranya',
#   'biasa'],
#  ['atas', 'up', 'boleh'],
#  ['loh',
#   'jadi',
#   'ketahuan',
#   'dong',
#   'isinya',
#   'boleh',
#   'bali',
#   'bukan',
#   'orang',
#   'bali',
#   'dulu'],
#  ['poligami', 'saja', 'enggak bisa'],
#  ['harusnya', 'dibakar', 'tempat', 'begituan', 'kali'],
#  ['alah',
#   'bahasa',
#   'hastag',
#   'ya',
#   'kalo',
#   'di',
#   'ledeki',
#   'jadi',
#   'ya',
#   'santri',
#   'gaul',
#   'itu',
#   'yang',
#   'suka',
#   'sholawat',
#   'dan',
#   'suka',
#   'dugem',
#   'alah',
#   'rusak',
#   'islam',
#   'di',
#   'biasa-biasa',
#   'seperti',
#   'ini',
#   'ustad',
#   'ya',
#   'datang',
#   'kak',
#   'sono',
#   'dugem',
#   'dulu',
#   'lalu',
#   'sholawat',
#   'lalu',
#   'dugem',
#   'lagi',
#   'dan',
#   'di',
#   'sebut',
#   'santri',
#   'gaul'],
#  ['kenapa',
#   'yang',
#   'kayak',
#   'begini',
#   'berita',
#   'nya',
#   'keluar',
#   'nya',
#   'pas',
#   'mau',
#   'pilpres',
#   'saja',
#   'ya'],
#  ['deh',
#   'ini',
#   'baru',
#   'benar',
#   'ceramah',
#   'atau',
#   'mengajak',
#   'orang',
#   'yang',
#   'belum',
#   'selamat',
#   'untuk',
#   'selamat',
#   'enggak',
#   'kayak',
#   'selamat',
#   'mengajak',
#   'orang',
#   'sholawat',
#   'kok',
#   'ke',
#   'orang',
#   'yang',
#   'sudah',
#   'selamat',
#   'ya',
#   'selamat'],
#  ['gila',
#   'nekat',
#   'juga',
#   'ulamanya',
#   'enggak',
#   'tau',
#   'di',
#   'usir',
#   'begitu',
#   'tapi',
#   'bagus',
#   'lah',
#   'ada',
#   'keberanian',
#   'dan',
#   'semuanya',
#   'juga',
#   'mendengarkan',
#   'semoga',
#   'banyak',
#   'ustad',
#   'lainnya',
#   'yang',
#   'meniru',
#   'hal',
#   'ini'],
#  ['tambah',
#   'tempat',
#   'mantap',
#   'enggak',
#   'cewek',
#   'seksi',
#   'menyadari',
#   'yang',
#   'paling',
#   'penting',
#   'boleh',
#   'yang',
#   'enggak',
#   'setuju',
#   'pasti',
#   'mengiri'],
#  ['mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'ibadah',
#   'ya',
#   'sudah',
#   'pasti',
#   'mudah',
#   'tapi',
#   'mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'dugem',
#   'yang',
#   'penuh',
#   'cobaan',
#   'itu',
#   'sudah',
#   'jelas',
#   'pahala',
#   'nya',
#   'jauh',
#   'lebih',
#   'besar'],
#  ['apa',
#   'sih',
#   'yang',
#   'enggak',
#   'bisa',
#   'di',
#   'negeri',
#   'ini',
#   'semua',
#   'pada',
#   'bisa',
#   'sekarang'],
#  ['boleh', 'ya', 'menyebarkan', 'agama', 'seperti', 'ini'],
#  ['alah', 'lucu', 'lucu', 'biar', 'masuk', 'tapi', 'dah', 'hahaha'],
#  ['coba',
#   'lah',
#   'ustad',
#   'yang',
#   'lain',
#   'dakwah',
#   'di',
#   'kita',
#   'club',
#   'seperti',
#   'itu'],
#  ['yang',
#   'ini',
#   'malah',
#   'di',
#   'dukung',
#   'yang',
#   'di',
#   'sana',
#   'di',
#   'menjaga',
#   'supaya',
#   'enggak',
#   'ceramah',
#   'apalagi',
#   'ini'],
#  ['ah',
#   'entah',
#   'satu',
#   'kau',
#   'maklumi',
#   'yang',
#   'lain',
#   'mengikuti',
#   'tinggal',
#   'tunggu',
#   'saja'],
#  ['mau', 'mengakak', 'takut', 'dosa'],
#  ['kalau',
#   'mau',
#   'melakukan',
#   'ibadah',
#   'perbaiki',
#   'dulu',
#   'penampilan',
#   'jauhi',
#   'miras',
#   'cari',
#   'tempat',
#   'yang',
#   'lebih',
#   'baik',
#   'lebih',
#   'baik',
#   'gus',
#   'kamu',
#   'mengajak',
#   'para',
#   'wanita',
#   'itu',
#   'menutupi',
#   'syaratnya'],
#  ['lokalisasi', 'harapan', 'sadar'],
#  ['setelah', 'selawat', 'selesai', 'acara', 'selanjutnya'],
#  ['bagus', 'lanjutkan'],
#  ['bagus',
#   'itu',
#   'biar',
#   'sadar',
#   'islam',
#   'tidak',
#   'mengajari',
#   'kaumnya',
#   'buka',
#   'aurat',
#   'bagus',
#   'lanjut'],
#  ['banget', 'aneh-aneh', 'mana', 'suaranya', 'liberal'],
#  ['fan',
#   'itu',
#   'ketika',
#   'bertambah',
#   'yang',
#   'bicara',
#   'selalu',
#   'dibully',
#   'karena',
#   'kata',
#   'katanya',
#   'terkesan',
#   'emosional',
#   'nantang',
#   'nantang',
#   'padahal',
#   'ketika',
#   'tantangan',
#   'bisa',
#   'di',
#   'buktikan',
#   'oleh',
#   'yang',
#   'di',
#   'tantang',
#   'terus',
#   'diam',
#   'tidak',
#   'ksatria',
#   'mengaku',
#   'dan',
#   'sering',
#   'menjelekkan',
#   'menjelek-jelekkan',
#   'orang',
#   'lain',
#   'inilah',
#   'yang',
#   'jadi',
#   'penyebab',
#   'sering',
#   'di',
#   'bully',
#   'dan',
#   'orang',
#   'lain',
#   'jadi',
#   'enggak',
#   'simpati',
#   'mungkin',
#   'dia',
#   'dengan',
#   'berkata',
#   'seperti',
#   'itu',
#   'merasa',
#   'hebat',
#   'dia',
#   'tidak',
#   'sadar',
#   'saat',
#   'nyapres',
#   'pun',
#   'rontok',
#   'saat',
#   'tahun',
#   '2014',
#   'pun',
#   'keok',
#   'artinya',
#   'rakyat',
#   'enggak',
#   'permasalahkan',
#   'bicara',
#   'dulu',
#   'urusan',
#   'belakang',
#   'seperti',
#   'janji',
#   'jalan',
#   'kaki',
#   'juga',
#   'jakarta',
#   'terbukti',
#   'enggak',
#   'kan',
#   'ini',
#   'mungkin',
#   'hal',
#   'sepele',
#   'bagi',
#   'dia',
#   'tapi',
#   'itu',
#   'tertanam',
#   'di',
#   'ingatan',
#   'pangling',
#   'kesampaian',
#   'kalo',
#   'hanya',
#   'bisa',
#   'mengomong',
#   'tok',
#   'berlakon',
#   'ora',
#   'sok'],
#  ['karena', 'mendukung', 'jokowi', 'jadi', 'tidak', 'dicopot'],
#  ['banyak', 'orang', 'pengin', 'yang', 'termakan', 'hoax'],
#  ['kapan',
#   'hancur',
#   'lebur',
#   'gara-gara',
#   'sih',
#   'amin',
#   'rasis',
#   'terima kasih',
#   'amin',
#   'lanjutkan',
#   'enggak bakal'],
#  ['padahal',
#   'suaminya',
#   'menaksir',
#   'ini',
#   'dulunya',
#   'merupakan',
#   'penyandang',
#   'dana',
#   'pak',
#   'amin',
#   'atas',
#   'saat',
#   'awal',
#   'reformasi',
#   'akhirnya',
#   'berjalan',
#   'sendiri'],
#  ['orang',
#   'benar',
#   'malah',
#   'tidak',
#   'dipakai',
#   'di',
#   'menghancurkan',
#   'itu',
#   'sudah',
#   'habis-habis',
#   'demi',
#   'kapan',
#   'tapi',
#   'tetap',
#   'tidak',
#   'berdaya',
#   'melawan',
#   'amin',
#   'kasihan',
#   'cahayanya',
#   'semakin',
#   'tidak',
#   'bersinar',
#   'sejak',
#   'amin',
#   'makin',
#   'suami'],
#  ['lagu', 'lama'],
#  ['kapan', 'sekarang', 'bulat', 'karena', 'ibu-ibu', 'sih', 'amin'],
#  ['karena', 'mendukung', 'jadi', 'tidak', 'dicopot'],
#  ['masak',
#   'sih',
#   'dari',
#   'beberapa',
#   'ex',
#   'pemimpin',
#   'kapan',
#   'yang',
#   'punya',
#   'pikiran',
#   'sehat',
#   'cuma',
#   'pak',
#   'suaminya'],
#  ['tolong',
#   'dikoreksi',
#   'untuk',
#   'jabatan',
#   'pak',
#   'promo',
#   'itu',
#   'membelah',
#   'bukan',
#   'senang',
#   'terima',
#   'kasih'],
#  ['mantap',
#   'bukti',
#   'orang',
#   'baik',
#   'pasti',
#   'banyak',
#   'yang',
#   'mendukung',
#   'salam',
#   '2',
#   'periode'],
#  ['kasih', 'bukan', 'buaya', 'saja', 'orang', 'kayak', 'begini'],
#  ['mantab',
#   'penyebar',
#   'fitnah',
#   'bisa',
#   'tidur',
#   'di',
#   'bui',
#   'juga',
#   'akhirnya'],
#  ['allah',
#   'alhamdulillah',
#   'akhirnya',
#   'para',
#   'aku',
#   'fitnah',
#   'benaran',
#   'kebencian',
#   'tersebut',
#   'dipenjara',
#   'juga',
#   'sudah',
#   'cukup',
#   'lama',
#   'mereka',
#   'menunggu',
#   'lihatnya',
#   'lagi',
#   'hilang'],
#  ['selamat',
#   'menikmati',
#   'hukuman',
#   'dunia',
#   'atas',
#   'prilaku',
#   'fitnah',
#   'menebar',
#   'kebencian',
#   'hukuman',
#   'akhirat',
#   'yang',
#   'lebih',
#   'berat',
#   'menunggu',
#   'anda',
#   'para',
#   'aku',
#   'fitnah',
#   'benaran',
#   'kebencian'],
#  ['dasar',
#   'preman',
#   'enggak',
#   'tanggung',
#   'jawab',
#   'kok',
#   'malah',
#   'buron',
#   'katanya',
#   'lu',
#   'anak',
#   'buah',
#   'wow',
#   'yang',
#   'bocor',
#   'bocor',
#   'itu',
#   'sih'],
#  ['orang',
#   'ganteng',
#   'enggak',
#   'akan',
#   'mengomentari',
#   'berita',
#   'ini',
#   'karena',
#   'sebagian',
#   'tabir',
#   'obor',
#   'rakyat',
#   'sudah',
#   'dibuka',
#   'sebagian',
#   'oleh',
#   'memang'],
#  ['ayo',
#   'komentarnya',
#   'kok',
#   'enggak',
#   'ada',
#   'yang',
#   'komentar',
#   'nih',
#   'biasanya',
#   'doa-doa',
#   'bilang',
#   'pelanggaran',
#   'hai',
#   'seperti',
#   'menangkap',
#   'teroris',
#   'pakai',
#   'senjata',
#   'lengkap',
#   'tersebut'],
#  ['sih',
#   'asik',
#   'selamat',
#   'menikmati',
#   'hotel',
#   'prodeo',
#   'kawan',
#   'siapa',
#   'menebar',
#   'angin',
#   'dia',
#   'menuai',
#   'badai'],
#  ['begini', 'lagi', 'dimana', 'anda', 'terjawab'],
#  ['wow', 'enggak', 'sekalian'],
#  ['jangan',
#   'tangkap',
#   'pacarnya',
#   'doang',
#   'tangkap',
#   'pandang',
#   'dana',
#   'dan',
#   'hubungan',
#   'mereka',
#   'dengan',
#   'kandidat',
#   'capres',
#   'yang',
#   'diusung'],
#  ['walaupun',
#   'cuma',
#   '1',
#   'tahun',
#   'ente',
#   'sudah',
#   'dapat',
#   'gelar',
#   'mantan',
#   'narapidana',
#   'menjelang',
#   'pemilu',
#   'buat',
#   'lagi',
#   'biar',
#   'dikurung',
#   'tahun',
#   'makan',
#   'gratis'],
#  ['gantung', 'aku'],
#  ['sekalian', 'begini', 'sayang', 'biar', 'adil'],
#  ['kirim', 'ke', 'kamar', 'berita', 'berita', 'itu', 'nama', 'macan'],
#  ['gua',
#   'paling',
#   'senang',
#   'lihat',
#   'beginian',
#   'buronan',
#   'sebenarnya',
#   'kayak',
#   'di',
#   'film',
#   'halo'],
#  ['menunggu',
#   'saja',
#   'nih',
#   'bentar',
#   'lagi',
#   'kubu',
#   'promo',
#   'terutama',
#   'dong',
#   'bakalan',
#   'komen',
#   'lihat',
#   'saja'],
#  ['karena', 'kabur', 'tambahkan', 'ya', 'hukuman', 'nya'],
#  ['ini', 'kabar', 'terbaik', 'yang', 'boleh', 'adegan', 'hari', 'ini'],
#  ['telat', 'kabur', 'menongol'],
#  ['mencari',
#   'duit',
#   'dari',
#   'mencebur',
#   'mengeditnya',
#   'buat',
#   'makan',
#   'anak',
#   'terima',
#   'jadi',
#   'apa',
#   'anak-anakmu',
#   'makan',
#   'duit',
#   'begituan'],
#  ['semoga', 'bahagia', 'di', 'rumah', 'yang', 'baru'],
#  ['periksa',
#   'bank',
#   'account',
#   'nya',
#   'atau',
#   'bank',
#   'account',
#   'keluarga',
#   'ada',
#   'transferan',
#   'enggak',
#   'dari',
#   'wow'],
#  ['semoga',
#   'bisa',
#   'belajar',
#   'untuk',
#   'tidak',
#   'mencari',
#   'nafkah',
#   'dari',
#   'uang',
#   'hitam',
#   'dengan',
#   'cara',
#   'yang',
#   'hitam'],
#  ['suntik', 'mati'],
#  ['sikat',
#   'semua',
#   'orang',
#   'orang',
#   'pengacau',
#   'negeri',
#   'demi',
#   'uang',
#   'apalagi',
#   'mau',
#   'pilpres',
#   'malah',
#   'bikin',
#   'kacau',
#   'negara',
#   'kalo',
#   'enggak',
#   'segera',
#   'ditayangkan'],
#  ['hapuskan',
#   'saja',
#   'jok',
#   'orang',
#   'yang',
#   'enggak',
#   'lu',
#   'jadi',
#   'presiden',
#   'lagi'],
#  ['menunggu',
#   'begini',
#   'sayang',
#   'kapan',
#   'ditangkapnya',
#   'padahal',
#   'sudah',
#   'ada',
#   'putusan',
#   'pengadilan',
#   'juga'],
#  ['kok', 'cuma', 'setahun'],
#  ['ah',
#   'bukannya',
#   'kata',
#   'menyambung',
#   'sempat',
#   'obor',
#   'rakyat',
#   'diangkat',
#   'jadi',
#   'neko-neko',
#   'banget',
#   'fitnah',
#   'lagi',
#   'dong'],
#  ['kapan', 'begini', 'sayang'],
#  ['sip',
#   'tinggal',
#   'yang',
#   'kabur',
#   'umroh',
#   'enggak',
#   'baik-baik',
#   'segera',
#   'dieksekusi',
#   'pak',
#   'pol'],
#  ['yang',
#   'model',
#   'beginian',
#   'main',
#   'fitnah',
#   'sih',
#   'mesti',
#   'di',
#   'menantang'],
#  ['mantap'],
#  ['sip'],
#  ['semoga', 'pas', 'di', 'dalam', 'penasaran', 'gantung', 'diri'],
#  ['terbukti',
#   'memfitnah',
#   'bukan',
#   'menghina',
#   'dan',
#   'ingat',
#   'fitnah',
#   'lebih',
#   'kejam',
#   'dari',
#   'pembunuhan',
#   'bro'],
#  ['hukuman', 'mati'],
#  ['alhamdulillah', 'sih', 'benaran', 'dosa', 'sudah', 'tertangkap'],
#  ['jokowi',
#   'sudah',
#   'memaafkan',
#   'tapi',
#   'proses',
#   'hukum',
#   'tetap',
#   'berlaku',
#   'bos'],
#  ['hmm'],
#  ['siapa-siapa', 'buat', 'gerombolan', 'admin', 'sama', 'nasi', 'bungkus'],
#  ['tambah', 'hukumannya', 'karena', 'mau', 'kabur'],
#  ['lho', 'kok', 'cuma', '1', 'tahun', '5', 'tahun', 'pantas', 'kok'],
#  ['yang',
#   'menjamin',
#   'mau',
#   'mem',
#   'back',
#   'up',
#   'mereka',
#   'pada',
#   'kemana',
#   'mau',
#   'menemani',
#   'mereka',
#   'hidup',
#   'bersama',
#   'di',
#   'lagi',
#   'hilang',
#   'jangan',
#   'macam',
#   'ayam',
#   'sayur',
#   'lari',
#   'ganteng',
#   'pusing',
#   'meninggalkan',
#   'kawan'],
#  ['gagah',
#   'saat',
#   'bikin',
#   'obor',
#   'rakyat',
#   'dek',
#   'dan',
#   'buron',
#   'saat',
#   'diproses',
#   'hukum',
#   'dasar',
#   'preman',
#   'mengomong',
#   'kalau',
#   'begini',
#   'apakah',
#   'orang',
#   'yang',
#   'anda',
#   'junjung',
#   'akan',
#   'gantian',
#   'membela',
#   'anda'],
#  ['2019gantipresiden',
#   'kelihatan',
#   'banget',
#   'tebang',
#   'pilihnya',
#   'hukum',
#   'tajam',
#   'ke',
#   'lawan',
#   'politik',
#   'tumpul',
#   'ke',
#   'repot'],
#  ['orangnya',
#   'tambah',
#   'gemuk',
#   'makan',
#   'uang',
#   'sisa',
#   'anggaran',
#   'obor',
#   'rakyat'],
#  ['bulat', 'jaman-jamannya', 'tetangga', 'sebelah', 'rumahnya', 'sendiri'],
#  ['bisa', 'jadi', '2019', 'muncul', 'trauma', 'rakyat'],
#  ['kalau',
#   'sudah',
#   'dieksekusi',
#   'enggak',
#   'lagi',
#   'dilindungi',
#   'kan',
#   'sama',
#   'janji',
#   'back',
#   'up',
#   'kalo',
#   'kena',
#   'masalah',
#   'hehehe',
#   'makan',
#   'tuh',
#   'janji',
#   'saat',
#   'kampanye'],
#  ['makan', 'pencarian', 'lu', 'duh'],
#  ['selamat', 'ya'],
#  ['masih', 'kelahirannya', 'mendukung', 'presiden', 'generasi', 'murah'],
#  ['ya',
#   'tidur',
#   'deh',
#   'biar',
#   'cepat',
#   'besok',
#   'ada',
#   'yang',
#   'berani',
#   'taruhan',
#   'siapa',
#   'yang',
#   'membela',
#   'mereka'],
#  ['tukang', 'fitnah', 'hukum', 'sebelum-sebelumnya'],
#  ['harusnya', 'min', 'tahun', 'di', 'sel'],
#  ['nah',
#   'ini',
#   'dia',
#   'paling',
#   'kelahirannya',
#   'ajib',
#   'menongol',
#   'nasi',
#   'bungkus',
#   'admin',
#   'hitungan'],
#  ['cuma', '1', 'tahun', 'enak', 'benar'],
#  ['ini',
#   'bodoh',
#   'amat',
#   'cuma',
#   '8',
#   'bulan',
#   'seharusnya',
#   'jangan',
#   'banding',
#   'malah',
#   'jadi',
#   '2',
#   'tahun'],
#  ['bos', 'nya', 'sikat'],
#  ['mari',
#   'kita',
#   'tunggu',
#   'siapa',
#   'saja',
#   'yang',
#   'nyinyir',
#   'atas',
#   'penangkapan',
#   'ini'],
#  ['muka-muka', 'tegar', 'menjalani', 'hukuman'],
#  ['bosnya', 'deh', 'ketangkap', 'belum'],
#  ['wow', 'cs', 'banyak', 'mudarat', 'nya'],
#  ['berani', 'kejaksaan', 'selamat', 'bertugas'],
#  ['hukum', 'sebenarnya'],
#  ['kalo',
#   'repot',
#   'mah',
#   'enggak',
#   'di',
#   'tangkap',
#   'kebal',
#   'hukum',
#   'seperti',
#   'pintar',
#   'lihat',
#   'adek',
#   'amat',
#   'menahan',
#   'anaknya',
#   'sekarang',
#   'dll',
#   '2019gantipresiden'],
#  ['good',
#   'job',
#   'jangan',
#   'lupa',
#   'gerombolan',
#   'suer',
#   'ingat',
#   'juga',
#   'harus',
#   'diawasi',
#   'dari',
#   'pada',
#   'menyebarkan',
#   'hasil',
#   'survey',
#   'abal-abal',
#   'abal-abal',
#   'apalagi',
#   'mau',
#   'pilpres',
#   'malah',
#   'bikin',
#   'perpecahan'],
#  ['sudah',
#   'dibongkar',
#   'kan',
#   'sama',
#   'pak',
#   'kami',
#   'pasti',
#   'ada',
#   'memandanginya',
#   'sih',
#   'kejar',
#   'juga',
#   'pak',
#   'justru',
#   'pak',
#   'berjuang',
#   'demi',
#   'bersihnya',
#   'negara',
#   'ini',
#   'dari',
#   'tukang',
#   'fitnah'],
#  ['usut', 'dana', 'nya', 'dari', 'mana', 'itu', 'baru', 'hebat'],
#  ['silakan',
#   'bernyanyi',
#   'denga',
#   'bebas',
#   'walaupun',
#   'semangat',
#   'telah',
#   'gila'],
#  ['kok', 'cuma', 'setahun'],
#  ['ayo',
#   'dong',
#   'polisi',
#   'kalo',
#   'tangkap',
#   'kayak',
#   'begini',
#   'dicari',
#   'tahu',
#   'bosnya',
#   'siapa',
#   'siapa',
#   'yang',
#   'memberi',
#   'dana',
#   'terus',
#   'kalo',
#   'sudah',
#   'tau',
#   'tangkap',
#   'lansung'],
#  ['dipakai', 'saja', 'pak', 'jaksa'],
#  ['tembak', 'jidat', 'nya'],
#  ['tangkap',
#   'bandar',
#   'dan',
#   'pemimpin',
#   'gembong',
#   'kayanya',
#   'biar',
#   'jelas'],
#  ['tukang', 'fitnah', 'plus', 'jaman-jamannya', 'wajib', 'dihukum'],
#  ['sudah',
#   'terbukti',
#   'komplotan',
#   'sana',
#   'cuma',
#   'bisa',
#   'fitnah',
#   'hoax',
#   'pakai',
#   'kerjanya',
#   'enggak',
#   'ada'],
#  ['mendingan', 'ditenggelamkan', 'saja'],
#  ['aktor',
#   'intelektual',
#   'yang',
#   'mendanai',
#   'kerja',
#   'obor',
#   'rakyat',
#   'untuk',
#   'kepentingan',
#   'politik',
#   'sang',
#   'aktor',
#   'intelektual',
#   'juga',
#   'harus',
#   'di',
#   'tangkap',
#   'dan',
#   'ditenggelamkan'],
#  ['mau',
#   'bagus',
#   'atau',
#   'garami',
#   'itu',
#   'kepala',
#   'negara',
#   'yang',
#   'harus',
#   'dihargai',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'masuk',
#   'bui'],
#  ['mau',
#   'bagus',
#   'atau',
#   'garami',
#   'itu',
#   'kepala',
#   'negara',
#   'yang',
#   'harus',
#   'dihargai',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'masuk',
#   'bui'],
#  ['mau',
#   'bagus',
#   'atau',
#   'garami',
#   'itu',
#   'kepala',
#   'negara',
#   'yang',
#   'harus',
#   'dihargai',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'masuk',
#   'bui'],
#  ['tukang', 'fitnah', 'dan', 'penyebar', 'hoax', 'tenggelamkan'],
#  ['alah',
#   'ya',
#   'jelas',
#   'sudah',
#   'kembar',
#   'negeri',
#   'dagelan',
#   'yang',
#   'komen',
#   'juga',
#   'lah',
#   'ya',
#   'gila',
#   'lanjutkan',
#   'saja'],
#  ['terima', 'kasih', 'kejaksaan'],
#  ['pak',
#   'jaksa',
#   'yang',
#   'hina',
#   'pak',
#   'jokowi',
#   'sekali-kali',
#   'pasti',
#   'pak',
#   'jaksa',
#   'tau',
#   'mencolong',
#   'di',
#   'seret',
#   'ke',
#   'penjara',
#   'tahan'],
#  ['sekalipun',
#   'benci',
#   'dengan',
#   'jokowi',
#   'bukan',
#   'berarti',
#   'menebar',
#   'fitnah',
#   'biar',
#   'bagaimanapun',
#   'jokowi',
#   'itu',
#   'presiden',
#   'pilihan',
#   'rakyat',
#   'memfitnah',
#   'presiden',
#   'memfitnah',
#   'rakyat'],
#  ['buron', 'wow'],
#  ['kalo',
#   'di',
#   'untuk',
#   'ini',
#   'orang',
#   'sudah',
#   'diciduk',
#   'langsung',
#   'oleh',
#   'edan',
#   'presiden',
#   'idaman',
#   'nya',
#   'pakai',
#   'untung',
#   'lah',
#   'di',
#   'indonesia',
#   'ini',
#   'presiden',
#   'nya',
#   'jokowi',
#   'yang',
#   'orang',
#   'nya',
#   'lembut',
#   'dan',
#   'kalem'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['bos', 'nya', 'juga', 'sekalian', 'dilihat', 'toilet'],
#  ['bos', 'nya', 'juga', 'sekalian', 'dilihat', 'toilet'],
#  ['jadi', 'ingat', 'jaman', 'siapa', 'ya'],
#  ['orang', 'bikin', 'rusak', 'harus', 'mudah-mudahan'],
#  ['super', 'mantap'],
#  ['baguslah',
#   'diciduk',
#   'sebelum',
#   'dikontrak',
#   'lagi',
#   'sama',
#   'tukang',
#   'fitnah'],
#  ['menjelekkan',
#   'presiden',
#   'sama',
#   'saja',
#   'menghina',
#   'lambang',
#   'negara',
#   'harusnya',
#   'berpikir',
#   'apalagi',
#   'seorang',
#   'redaksi',
#   'berita',
#   'yang',
#   'seharusnya',
#   'menjadi',
#   'panutan',
#   'beritanya'],
#  ['semoga', 'betah', 'di', 'hotel', 'prodeo', 'ya', 'bro'],
#  ['sebaiknya', 'orang', 'seperti', 'ini', 'dilenyapkan', 'saja'],
#  ['sikat', 'ikat', 'berkas'],
#  ['fitnah', 'karena', 'duit'],
#  ['tolong', 'dikubur', 'dalam-dalam', 'orang', 'begini'],
#  ['langsung', 'buang', 'saja', 'kalau'],
#  ['tunggu', 'siapa', 'yang', 'komen', 'membelah', 'itu', 'menontonnya'],
#  ['punya', 'bagaimana'],
#  ['kak',
#   'lama',
#   'sekali',
#   'pelaku',
#   'kejahatan',
#   'hoax',
#   'ini',
#   'baru',
#   'dijebloskan',
#   'ke',
#   'bui',
#   'sekarang',
#   'usut',
#   'dan',
#   'tangkap',
#   'segera',
#   'pelaku',
#   'hoax',
#   'lainnya'],
#  ['obor', 'hoax'],
#  ['berani', 'kebayanya', 'ada', 'kerjanya'],
#  ['mantap', 'saja', 'penyebar', 'hoax'],
#  ['yang', 'di', 'negeri', 'sekarang', 'bagaimana'],
#  ['4', 'tahun', 'pantas', '40', 'tahun'],
#  ['itu', 'dulu', 'timses', 'siapa', 'ya'],
#  ['masih', 'bisa', 'gaya', 'gaya', 'an', 'lihat', 'baju', 'mereka', 'seperti'],
#  ['mudah', '2', 'an', 'di', 'bukan', 'lebih', 'berat', 'lagi'],
#  ['wow',
#   'sukur-sukur',
#   'kalian',
#   'banding',
#   'soalnya',
#   'hukuman',
#   'kalian',
#   'bakal',
#   'di',
#   'tambah',
#   'jadi',
#   '10',
#   'tahun',
#   'nyungsep',
#   'kalian'],
#  ['sakit', 'jiwa', 'lucu'],
#  ['sakit', 'jiwa', 'lu'],
#  ['kasihan', 'benar', 'mas', 'eko', 'semoga', 'dapat', 'jalan', 'keluarnya'],
#  ['jahat', 'sekali', 'yang', 'nipu'],
#  ['menyembuhkan', 'saja', 'pengacaranya'],
#  ['nah',
#   'mulai',
#   'terkuak',
#   'biang',
#   'kebayanya',
#   'siapkan',
#   'bukti-bukti',
#   'penyerahan',
#   'sehat-sehat',
#   'dan',
#   'tanda',
#   'terima',
#   'uang',
#   'dikasih',
#   'enggak',
#   'waktu',
#   'bantu',
#   'kalo',
#   'enggak',
#   'ada',
#   'bukti',
#   'jangan',
#   'kau',
#   'harap',
#   'bisa',
#   'gugat',
#   'pengacara',
#   'ya'],
#  ['semoga',
#   'dapat',
#   'pengganti',
#   'pengacara',
#   'kondang',
#   'mas',
#   'yang',
#   'kemarin',
#   'itu',
#   'abal-abal',
#   'abal-abal',
#   'punya'],
#  ['kasihan',
#   'mas',
#   'eko',
#   'ini',
#   'biasa-biasa',
#   'dituduh',
#   'lagi',
#   'sama',
#   'repot',
#   'sebagai',
#   'sebar',
#   'hoax',
#   'karena',
#   'tidak',
#   'ada',
#   'buktinya'],
#  ['yang',
#   'komentar',
#   'pada',
#   'enggak',
#   'tahu',
#   'tentang',
#   'bagaimana',
#   'sertifikat',
#   'dibuat',
#   'sertifikat',
#   'itu',
#   'bisa',
#   'muncul',
#   'kalau',
#   'ada',
#   'akses',
#   'jalan',
#   'suruh',
#   'dia',
#   'tunjukkan',
#   'denah',
#   'sertifikatnya',
#   'kalau',
#   'dia',
#   'memang',
#   'punya',
#   'itu',
#   'pasti',
#   'sertifikatnya',
#   'masih',
#   'gabung',
#   'sama',
#   'sebelah',
#   'kiri',
#   'atau',
#   'sebelah',
#   'kanannya',
#   'dan',
#   'itu',
#   'pasti',
#   'masih',
#   'saudara',
#   'dia',
#   'sertifikatnya',
#   'belum',
#   'dipecah',
#   'sama',
#   'mereka',
#   'berdua'],
#  ['nanti', 'pintu', 'surga', 'juga', 'diblokade', 'sama', 'tuhan'],
#  ['sudah',
#   'tapi',
#   'camat',
#   'yang',
#   'harus',
#   'menyelesaikan',
#   'biar',
#   'p',
#   'camat',
#   'dapat',
#   'pahala',
#   'membantu',
#   'yang',
#   'tertindas',
#   'toh',
#   'enggak',
#   'lama',
#   'lagi',
#   'kita',
#   'mati',
#   'dan',
#   'sudah',
#   'tanah',
#   'itu',
#   'tidak',
#   'di',
#   'bawa'],
#  ['saya',
#   'tahun',
#   'kemarin',
#   'beli',
#   'tanah',
#   '20',
#   '15',
#   'sama',
#   'tapi',
#   'saya',
#   'bikin',
#   'fondasi',
#   'pagar',
#   '19',
#   'almarhum',
#   'jadi',
#   'ada',
#   '1',
#   'meter',
#   'untuk',
#   'akses',
#   'jalan',
#   'setapak',
#   'berarti',
#   'saya',
#   'rela',
#   'tanah',
#   'saya',
#   'almarhum',
#   'untuk',
#   'kepentingan',
#   'umum',
#   'tetangga',
#   'sebelah',
#   'juga',
#   'demikian',
#   'jadi',
#   'jalan',
#   'setapak',
#   'lebarnya',
#   '2',
#   'meter',
#   'kita',
#   'kan',
#   'hidup',
#   'bertetangga',
#   'masa',
#   'tanah',
#   'satu',
#   'meter',
#   'saja',
#   'menghalangi',
#   'silaturahmi',
#   'dengan',
#   'tetangga',
#   'jadi',
#   'harus',
#   'dibicarakan',
#   'baiknya',
#   'semua',
#   'bisa',
#   'diatur',
#   'yang',
#   'penting',
#   'dengan',
#   'hati',
#   'nurani'],
#  ['lemah',
#   'mati',
#   'tidak',
#   'ada',
#   'akses',
#   'jalan',
#   'itu',
#   'murah',
#   'harganya',
#   'lah',
#   'ini',
#   'yang',
#   'punya',
#   'tanah',
#   'garuk-garuk',
#   'sudah',
#   'deal',
#   'juta',
#   'meminta',
#   'naik',
#   'juta',
#   'jengkel',
#   'di',
#   'tutup',
#   'sekalian',
#   'sama',
#   'tetangga',
#   'yakin',
#   'tuh',
#   'yang',
#   'punya',
#   'tanah',
#   'mati',
#   'pasti',
#   'kalo',
#   'jadi',
#   'dikerjai',
#   'tetangga'],
#  ['kalo',
#   'tidak',
#   'salah',
#   'ada',
#   'undangan-undangan',
#   'pertanahan',
#   'yang',
#   'mengatur',
#   'tentang',
#   'kewajiban',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'untuk',
#   'memberi',
#   'akses',
#   'jalan',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'dilihatnya',
#   'yang',
#   'tidak',
#   'memiliki',
#   'akses',
#   'jalan',
#   'dalam',
#   'sertifikat',
#   'tanahnya',
#   'istilahnya',
#   'tanah',
#   'helikopter',
#   'minimal',
#   'jalan',
#   'setapak',
#   'silakan',
#   'dicek',
#   'saya',
#   'lupa',
#   'pasalnya'],
#  ['tidak',
#   'berperikemanusiaan',
#   'yang',
#   'nutup',
#   'akses',
#   'itu',
#   'enggak usah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'tanya',
#   'ke',
#   'kucingnya',
#   'dengan',
#   'keras',
#   'enggak usah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'jika',
#   'berada',
#   'di',
#   'belakang',
#   'rumah',
#   'orang',
#   'lain'],
#  ['sepertinya',
#   'ada',
#   'yang',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'terus',
#   'lihat',
#   'kapan',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'banget',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['terasa',
#   'dulu',
#   'mbak',
#   'nya',
#   'ada',
#   'enggak',
#   'kalau',
#   'enggak',
#   'ada',
#   'suruh',
#   'sampai',
#   'yang',
#   'bongkar',
#   'jangan',
#   'korbankan',
#   'tetangga'],
#  ['sebelum',
#   'semuanya',
#   'menjadi',
#   'tanpa',
#   'bayangkan',
#   'untuk',
#   'mencari',
#   'siapa',
#   'yang',
#   'salahkan',
#   'diakui',
#   'selama',
#   'ini',
#   'sebagai',
#   'akses',
#   'jalan',
#   'pak',
#   'eko',
#   'ini',
#   'sebenarnya',
#   'memang',
#   'peruntukan',
#   'jalan',
#   'atau',
#   'menggunakan',
#   'melewati',
#   'tanah',
#   'orang',
#   'lain',
#   'memang',
#   'akses',
#   'jalan-jalannya',
#   'jelas',
#   'silakan',
#   'kalo',
#   'itu',
#   'memang',
#   'tanah',
#   'orang',
#   'lainya',
#   'memang',
#   'haknya',
#   'dia',
#   'untuk',
#   'tembok',
#   'salah',
#   'adalah',
#   'pemerintah',
#   'tempat-tempat',
#   'akses',
#   'jalan',
#   'selama',
#   'ini',
#   'yang',
#   'harusnya',
#   'ada'],
#  ['yang',
#   'punya',
#   'tanah',
#   'enggak',
#   'bisa',
#   'salahkan',
#   'segampang',
#   'itu',
#   'haknya',
#   'halo',
#   'dia',
#   'dituntut',
#   'harus',
#   'mengasih',
#   'sebagian',
#   'untuk',
#   'ganteng',
#   'kelihatan',
#   'n',
#   'belakang',
#   'pak',
#   'eko',
#   'juga',
#   'harus',
#   'dituntut',
#   'hal',
#   'yang',
#   'rupa-rupanya',
#   'dia',
#   'adalah',
#   'dia',
#   'baru',
#   'beli',
#   'n',
#   'bangun',
#   'sekarang'],
#  ['kasih', 'jalan', 'pahit', 'ladang', 'amal', 'bpk'],
#  ['kalo',
#   'sudah',
#   'deal',
#   'juta',
#   'kok',
#   'ingkar',
#   'jadi',
#   'juta',
#   'ya',
#   'harusnya',
#   'jangan',
#   'serakah',
#   'juga',
#   'ya',
#   'kalo',
#   'memang',
#   'maunya',
#   'juta',
#   'ya',
#   'jangan',
#   'buka',
#   'juta',
#   'entar',
#   'ada',
#   'yang',
#   'mau',
#   'juta',
#   'ingkar',
#   'lagi',
#   'juta'],
#  ['akar', 'masalah', 'nya', 'duit'],
#  ['ya',
#   'sudah',
#   'tapi',
#   'pak',
#   'eko',
#   'pindah',
#   'saja',
#   'rumah',
#   'lama',
#   'jadikan',
#   'kandang',
#   'ayam',
#   'atau',
#   'studio',
#   'musik',
#   'kan',
#   'haknya',
#   'pak',
#   'eko',
#   'juga',
#   'tapi',
#   'saat',
#   'ketemu',
#   'tetangga',
#   'yang',
#   'enggak',
#   'mempedulikan',
#   'ya',
#   'sudah',
#   'jadikan',
#   'kita',
#   'enggak',
#   'peduli',
#   'mengalah',
#   'terus',
#   'tidak',
#   'selamanya',
#   'baik'],
#  ['sebenarnya',
#   'siapa',
#   'sih',
#   'yang',
#   'mau',
#   'beli',
#   'siapa',
#   'yang',
#   'mau',
#   'jual',
#   'kok',
#   'keterangan',
#   'camat',
#   'beda',
#   'sama',
#   'eko',
#   'eko',
#   'bilang',
#   'dia',
#   'yang',
#   'mau',
#   'beli',
#   'tanah',
#   'tetangganya',
#   'buat',
#   'jalan',
#   'kata',
#   'camat',
#   'malah',
#   'eko',
#   'yang',
#   'mau',
#   'jual',
#   'malah',
#   'harga',
#   'naik',
#   'pula',
#   'yakin',
#   'ada',
#   'yang',
#   'enggak',
#   'beres',
#   'sama',
#   'sih',
#   'eko'],
#  ['enggak',
#   'pernah',
#   'belajar',
#   'sampai',
#   'mana',
#   'toleransi',
#   'penghargaan',
#   'mengumpat-ngumpat',
#   'dalam',
#   'bertetangga'],
#  ['dulu',
#   'sudah',
#   'mau',
#   'dibeli',
#   'juta',
#   'tapi',
#   'enggak',
#   'jadi',
#   'karena',
#   'naik',
#   'meminta',
#   'juta',
#   'giliran',
#   'dibikin',
#   'tembok',
#   'merengek',
#   'pengin',
#   'mengadu',
#   'kesana',
#   'kemarin',
#   'lebay'],
#  ['ujung', 'ujungnya', 'duit'],
#  ['sudah', 'terbaik', 'permasalah', 'nya'],
#  ['camat',
#   'kok',
#   'meminta',
#   'keluar',
#   'dari',
#   'kantor',
#   'kalian',
#   'itu',
#   'hai',
#   'camat',
#   'lurah',
#   'jangan',
#   'orang-orang',
#   'kayak',
#   'simpan',
#   'saja',
#   'lu',
#   'pakai'],
#  ['jangan',
#   'main',
#   'asal',
#   'mengomong',
#   'menuduh',
#   'salah',
#   'satu',
#   'pihak',
#   'masalah',
#   'ini',
#   'terjadi',
#   'bukan',
#   'karena',
#   'pihak',
#   'yang',
#   'bersengketa',
#   'saja',
#   'ada',
#   'peran',
#   'ribu',
#   'ribu',
#   'lurah',
#   'camat',
#   'serta',
#   'pihak',
#   'pertanahan',
#   'rencana',
#   'tata',
#   'ruangnya',
#   'mana',
#   'masing-masing',
#   'punya',
#   'andil',
#   'dalam',
#   'terjadinya',
#   'masalah',
#   'ini',
#   'bukan',
#   'serta',
#   'merta',
#   'gara-gara',
#   'pihak',
#   'pak',
#   'eko',
#   'ataupun',
#   'tetangganya'],
#  ['punya',
#   'tanah',
#   'pribadi',
#   'jangan',
#   'dibuat',
#   'jalanan',
#   'nanti',
#   'seburuk-buruk'],
#  ['jadi',
#   'sudah',
#   'jelas',
#   'tapi',
#   'akar',
#   'masalah',
#   'kembang',
#   'lain',
#   'memangnya'],
#  ['seharusnya',
#   'ke',
#   'panggilannya',
#   'saja',
#   'apapun',
#   'hasilnya',
#   'itu',
#   'yang',
#   'akan',
#   'diakui',
#   'secara',
#   'hukum',
#   'kalau',
#   'curhat',
#   'kemana-mana',
#   'pasti',
#   'hanya',
#   'dapat',
#   'lip',
#   'service',
#   'saja',
#   'karena',
#   'mereka',
#   'hanya',
#   'bisa',
#   'menghimbau'],
#  ['sudah',
#   'mau',
#   'dibeli',
#   'juta',
#   'tapi',
#   'naik',
#   'jadi',
#   'juta',
#   'lagi',
#   'sini',
#   'sudah',
#   'sedikit',
#   'jalan',
#   'akar',
#   'masalahnya'],
#  ['kok',
#   'masih',
#   'ada',
#   'ya',
#   'orang',
#   'kayak',
#   'hitungan',
#   'di',
#   'perkampungan',
#   'mending',
#   'di',
#   'kubur',
#   'saja'],
#  ['spekulasi',
#   'itu',
#   'yang',
#   'jadi',
#   'pertanyaan',
#   'ketika',
#   'jual',
#   'beli',
#   'kan',
#   'ada',
#   'form',
#   'tanda',
#   'tangan',
#   'sepengetahuan',
#   'jiran',
#   'kanan',
#   'kiri',
#   'depan',
#   'bilang',
#   'dari',
#   'situ',
#   'sudah',
#   'dapat',
#   'awal',
#   'masalahnya',
#   'kemana',
#   'itu',
#   'pak',
#   'ribu',
#   'ribu',
#   'kamu',
#   'n',
#   'kades'],
#  ['kapan',
#   'di',
#   'kasih',
#   'jalan',
#   'juga',
#   'mending',
#   'pindah',
#   'saja',
#   'enggak punya',
#   'tetangga',
#   'kayak',
#   'begitu',
#   'modelnya',
#   'susah',
#   'lihat',
#   'orang',
#   'kesenangan',
#   'lihat',
#   'orang',
#   'susah'],
#  ['kenapa',
#   'setelah',
#   'viral',
#   'di',
#   'medsos',
#   'camat',
#   'nya',
#   'baru',
#   'turun',
#   'tangan',
#   'pak',
#   'eko',
#   'bilang',
#   'sudah',
#   '3',
#   'tahun',
#   'menyarankan',
#   'untuk',
#   'cari',
#   'solusi',
#   'jadi',
#   'kalau',
#   'ada',
#   'masalah',
#   'seperti',
#   'ini',
#   'mendingan',
#   'di',
#   'viralkan',
#   'saya',
#   'cepat',
#   'ditanggapi'],
#  ['ayo', 'pak', 'eko'],
#  ['tetangga',
#   'kayak',
#   'begini',
#   'harus',
#   'buru',
#   'buru',
#   'di',
#   'memandikan',
#   'di',
#   'salahkan',
#   'di',
#   'menyarankan',
#   'dan',
#   'diputuskan',
#   'langsung',
#   'enggak',
#   'ada',
#   'apa-apanya'],
#  ['enggak bisa', 'masih', 'pak', 'lo'],
#  ['saya',
#   'enggak',
#   'menyebutkan',
#   'kronologi',
#   'karena',
#   'privacy',
#   'hmm',
#   'ada',
#   'yang',
#   'aneh'],
#  ['disini',
#   'banyak',
#   'pendukung',
#   'tetangga',
#   'pak',
#   'eko',
#   'atau',
#   'mungkin',
#   'tetangga',
#   'disitu',
#   'wow'],
#  ['dijual', 'ke', 'tetangga', 'depan', 'samping', 'saja', 'pak'],
#  ['ribu',
#   'ribu',
#   'lurah',
#   'camat',
#   'bukan',
#   'warung kopi',
#   'bupati',
#   'anjir',
#   'semuanya'],
#  ['mas', 'pak', 'lo'],
#  ['harusnya',
#   'dipikirkan',
#   'sejak',
#   'dini',
#   'kalo',
#   'sudah',
#   'begini',
#   'bingung',
#   'deh',
#   'lu',
#   'rindu',
#   'salah',
#   'lu',
#   'sendiri'],
#  ['kalau',
#   'mau',
#   'jual',
#   'ya',
#   'ke',
#   'tetangganya',
#   'enggak',
#   'usah',
#   'cari',
#   'sensasi',
#   'banyak',
#   'kok',
#   'orang',
#   'lagi',
#   'yang',
#   'rugi',
#   'lebih',
#   'banyak',
#   'untuk',
#   'mengurusi',
#   'tanah',
#   'bahkan',
#   'tanah',
#   'dengan',
#   'surat',
#   'berlapis',
#   'juga',
#   'ada',
#   'toh',
#   'yang',
#   'rugi',
#   'pemilik',
#   'orang',
#   'bukan',
#   'palingan',
#   'hanya',
#   'di',
#   'mutasi',
#   'apalagi',
#   'kalo',
#   'sudah',
#   'pensiun',
#   'enggak',
#   'ada',
#   'sangsi',
#   'apa-apa'],
#  ['ini', 'eko', 'nya', 'yang', 'loh', 'sejak', 'mau'],
#  ['pandang',
#   'sudah',
#   'mengatur',
#   'kalo',
#   'pembangunan',
#   'tiba-tiba',
#   'boleh',
#   'menutup',
#   'akses',
#   'jalan',
#   'bagi',
#   'rumah',
#   'atau',
#   'tempat',
#   'tinggal',
#   'yang',
#   'sudah',
#   'ada',
#   'sebelumnya',
#   'mohon',
#   'koreksi',
#   'kalo',
#   'salah'],
#  ['kayak',
#   'nya',
#   'sih',
#   'eko',
#   'ini',
#   'punya',
#   'kelainan',
#   'cara',
#   'bertetangga',
#   'deh'],
#  ['ayo', 'pak', 'lo'],
#  ['pak',
#   'eko',
#   'punya',
#   'mbak',
#   'kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tanpa',
#   'halaman'],
#  ['solusinya',
#   'ya',
#   'jual',
#   'ke',
#   'tetangga',
#   'depannya',
#   'itu',
#   'pak',
#   'hitung',
#   'harga',
#   'tanah',
#   'saja',
#   'karena',
#   'memang',
#   'rumah',
#   'tanah',
#   'bpk',
#   'di',
#   'block',
#   'sama',
#   'dia',
#   'banyak',
#   'yang',
#   'seperti',
#   'itu',
#   'istilahnya',
#   'cocok',
#   'land',
#   'jadi',
#   'memang',
#   'dia',
#   'beli',
#   'atau',
#   'bpk',
#   'bisa',
#   'juga',
#   'beli',
#   'tanah',
#   'didepan',
#   'untuk',
#   'akses'],
#  ['beli',
#   'saja',
#   'tanah',
#   'tetangga',
#   'atau',
#   'jual',
#   'rumahnya',
#   'ke',
#   'tetangganya'],
#  ['ya',
#   'harusnya',
#   'dari',
#   'awal',
#   'pak',
#   'eko',
#   'sudah',
#   'membuat',
#   'jalan',
#   'untuk',
#   'rumahnya',
#   'sendiri',
#   'bukan',
#   'nya',
#   'membuat',
#   'rumah',
#   'full',
#   'bangunan',
#   'tapi',
#   'disisakan',
#   'untuk',
#   'jalan',
#   'hak',
#   'tetangga',
#   'juga',
#   'membuat',
#   'rumah',
#   'di',
#   'tanahnya',
#   'sendiri',
#   'seperti',
#   'yang',
#   'dilakukan',
#   'pak',
#   'eko',
#   'kejadian',
#   'sebenarnya',
#   'masih',
#   'misteri',
#   'siapa',
#   'yang',
#   'salah',
#   'dan',
#   'yang',
#   'benar',
#   'masih',
#   'ibu-ibu'],
#  ['masuk', 'pak', 'eko'],
#  ['tata', 'ruangnya', 'amburadul'],
#  ['sebetulnya',
#   'yang',
#   'paling',
#   'salah',
#   'adalah',
#   'bukan',
#   'karena',
#   'di',
#   'peraturan',
#   'agraria',
#   'beruntung',
#   'hukum',
#   'mengenai',
#   'pemberian',
#   'jalan',
#   'kepada',
#   'tanah',
#   'yang',
#   'tidak',
#   'memiliki',
#   'jalan',
#   'tahun',
#   'tanah',
#   'yang',
#   'di',
#   'tengah',
#   'telah',
#   'dibeginikan',
#   'di',
#   'kanan',
#   'dan',
#   'dikasih',
#   'pun',
#   'telah',
#   'bersertifikat',
#   'dan',
#   'menutup',
#   'jalan',
#   'di',
#   'depannya',
#   'juga',
#   'dibuat',
#   'sertifikat',
#   'dan',
#   'menutup',
#   'akses',
#   'yang',
#   'begitu',
#   'sementara',
#   'bilang',
#   'belum',
#   'nah',
#   'ketika',
#   'belakang',
#   'membuat',
#   'sertifikat',
#   'secara',
#   'otomatis',
#   'yang',
#   'belakang',
#   'akan',
#   'dipotong',
#   'tanahnya',
#   'dan',
#   'memberikan',
#   'akses',
#   'jalan',
#   'yang',
#   'ditengah',
#   'cuma',
#   'masyarakat',
#   'banyak',
#   'yang',
#   'awam',
#   'dengan',
#   'peraturan',
#   'tersebut'],
#  ['ketua',
#   'ribu',
#   'ribu',
#   'lurah',
#   'kok',
#   'pada',
#   'diam',
#   'yuk',
#   'bantu',
#   'warganya',
#   'masa',
#   'kalah',
#   'gantian',
#   'tutup',
#   'jamnya'],
#  ['kemungkinan',
#   'besar',
#   'ada',
#   'yang',
#   'enggak',
#   'beres',
#   'dengan',
#   'proses',
#   'penerbitan',
#   'mbak'],
#  ['bisa',
#   'dirundingkan',
#   'lah',
#   'sebelumnya',
#   'ditawari',
#   'tanah',
#   'tetangganya',
#   'tidak',
#   'mau',
#   'ya',
#   'bukan',
#   'salah',
#   'yang',
#   'memblokade',
#   'makanya',
#   'harus',
#   'baik',
#   'baik',
#   'dengan',
#   'tetangga',
#   'dan',
#   'pengurus',
#   'ribu',
#   'setempat'],
#  ['tidak',
#   'diperbolehkan',
#   'perda',
#   'membangun',
#   'tapi',
#   'merugikan',
#   'tetangga',
#   'walaupun',
#   'di',
#   'lahan',
#   'sendiri',
#   'biasanya',
#   'jika',
#   'terjadi',
#   'seperti',
#   'itu',
#   'dinas',
#   'pengawasan',
#   'pembangunan',
#   'akan',
#   'bertindak'],
#  ['yuk', 'ya', 'lo'],
#  ['pastinya', 'orang', 'ini', 'bermasalah', 'dengan', 'tetangganya'],
#  ['jual', 'sama', 'yang', 'melarang'],
#  ['silaturahmi',
#   'dengan',
#   'tetangga',
#   'itu',
#   'penting',
#   'walau',
#   'akses',
#   'ditutup',
#   'kalau',
#   'tetangga',
#   'seperti',
#   'saudara',
#   'pasti',
#   'dikasih',
#   'jalan',
#   'tinggal',
#   'ketok',
#   'rumah',
#   'tetangga',
#   'terus',
#   'termasuk',
#   'pak',
#   'maksud'],
#  ['mbak', 'bisa', 'keluar'],
#  ['ya',
#   'hak',
#   'tetangga',
#   'juga',
#   'blokade',
#   'jalan',
#   'karena',
#   'mungkin',
#   'itu',
#   'tanah',
#   'tetangga',
#   'harusnya',
#   'di',
#   'musyawarahkan',
#   'baik-baik',
#   'dengan',
#   'tetangga',
#   'kalo',
#   'kita',
#   'baik',
#   'ke',
#   'tetangga',
#   'enggak',
#   'mungkin',
#   'tetangga',
#   'akan',
#   'semoga',
#   'itu',
#   'memblokade',
#   'jalan'],
#  ['waras', 'selamat', 'pak', 'eko', 'tenang', 'saja', 'pasti', 'tak', 'sare'],
#  ['mana',
#   'kades',
#   'nya',
#   'masa',
#   'ada',
#   'warganya',
#   'yang',
#   'bermasalah',
#   'begini',
#   'enggak',
#   'diselesaikan'],
#  ['surat',
#   'kok',
#   'dilempar',
#   'memangnya',
#   'koran',
#   'meskipun',
#   'benar',
#   'koran',
#   'apa',
#   'sopan',
#   'lempar',
#   'koran',
#   'ke',
#   'presiden',
#   'apa',
#   'enggak',
#   'bisa',
#   'dititipkan',
#   'suratnya',
#   'lewat',
#   'paspampres'],
#  ['ya',
#   'jelas',
#   'dikejar',
#   'hempas',
#   'menggampar',
#   'benda',
#   'seperti',
#   'itu',
#   'ke',
#   'presiden',
#   'itu',
#   'sudah',
#   'tugas',
#   'mereka',
#   'menjaga',
#   'presiden'],
#  ['silau',
#   'mungkin',
#   'juga',
#   'enggak',
#   'benar',
#   'main',
#   'lempar',
#   'surat',
#   'tanpa',
#   'pikir',
#   'kesopanan',
#   'stres',
#   'pak',
#   'eko'],
#  ['tetangga', 'masa', 'begitu'],
#  ['sepertinya',
#   'ada',
#   'yang',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'terus',
#   'lihat',
#   'kapan',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'banget',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['wah',
#   'kalo',
#   'saja',
#   'sampai',
#   'ke',
#   'telinga',
#   'jokowi',
#   'pasti',
#   'akan',
#   'buatkan',
#   'flyover'],
#  ['bandung',
#   'jawaban',
#   'ada',
#   'gubernur',
#   'baru',
#   'kalau',
#   'yang',
#   'dulu',
#   'memang',
#   'parah',
#   'sekarang',
#   'lapor',
#   'pasti',
#   'di',
#   'beresin',
#   'enggak',
#   'semua',
#   'ke',
#   'presiden',
#   'kali'],
#  ['katanya', 'pak', 'camat', 'tidak', 'tahu'],
#  ['yang',
#   'memblokade',
#   'pasti',
#   'orang',
#   'kuat',
#   'juga',
#   'orang',
#   'penting',
#   'sampai',
#   'camat',
#   'enggak',
#   'bisa',
#   'menyelesaikan'],
#  ['sudah',
#   'bodoh',
#   'mau',
#   'menang',
#   'sendiri',
#   'ini',
#   'problem',
#   'di',
#   'marah-marah',
#   'mengharapkan',
#   'tetangga',
#   'memberikan',
#   'jalan',
#   'sementara',
#   'mereka',
#   'banyak',
#   'yang',
#   'membuat',
#   'rumah',
#   'atau',
#   'pagar',
#   'melebihi',
#   'ukuran',
#   'suka',
#   'tanah',
#   'yang',
#   'dimiliki',
#   'alias',
#   'menyerobot',
#   'tanah',
#   'tetangga'],
#  ['coba', 'ke', 'kopi', 'jangan', 'lah'],
#  ['kalau',
#   'semua',
#   'ke',
#   'jokowi',
#   'ya',
#   'enggak',
#   'mungkin',
#   'ada',
#   'jutaan',
#   'masalah',
#   'di',
#   'indonesia',
#   'urutannya',
#   'itu',
#   'bisa',
#   'meminta',
#   'mediasi',
#   'didampingi',
#   'terus',
#   'ke',
#   'kelurahan',
#   'kalau',
#   'gagal',
#   'ya',
#   'ke',
#   'kecamatan',
#   'kalau',
#   'enggak',
#   'bisa',
#   'datang',
#   'mediasi',
#   'ya',
#   'tulis',
#   'surat',
#   'resmi',
#   'ke',
#   'kelurahan',
#   'kecamatan',
#   'kakaknya',
#   'kalau',
#   'tidak',
#   'ditanggapi',
#   'bisa',
#   'tulis',
#   'pengaduan',
#   'ke',
#   'mudah-mudahan',
#   'banyak',
#   'kok',
#   'permasalahan',
#   'yang',
#   'sampai',
#   'ke',
#   'mudah-mudahan',
#   'dan',
#   'langsung',
#   'di',
#   'follow',
#   'up',
#   'antara',
#   '12',
#   'bulan',
#   'enggak',
#   'usah',
#   'tunggu',
#   '3',
#   'tahun',
#   'mengajar',
#   'presiden'],
#  ['tapi', 'masih', 'bisa', 'keluar', 'rumah', 'enggak'],
#  ['inilah',
#   'contoh',
#   'manusia',
#   'indonesia',
#   'jaman',
#   'now',
#   'yang',
#   'katanya',
#   'pantas',
#   'ternyata',
#   'egois',
#   'tak',
#   'ada',
#   'toleransi',
#   'sedikitpun',
#   'kepada',
#   'sesama',
#   'pada',
#   'sesama',
#   'tetangga',
#   'ribu',
#   'ribu',
#   'lurah',
#   'nya',
#   'enggak taunya',
#   'walikota',
#   'nya',
#   'gubernur',
#   'nya',
#   'pancasila',
#   'nya',
#   'mana'],
#  ['kakaknya',
#   'saja',
#   'kurang',
#   'pintar',
#   'itu',
#   'bikin',
#   'sih',
#   'sampai',
#   'atas',
#   'genteng',
#   'kan',
#   'bisa',
#   'terus',
#   'bikin',
#   'tol',
#   'diatas',
#   'genteng',
#   'sampai',
#   'jalan',
#   'raya',
#   'hehehe'],
#  ['pertamanya',
#   'bagaimana',
#   'hubungan',
#   'barangnya',
#   'kok',
#   'sampai',
#   'tega',
#   'di',
#   'block',
#   'begitu',
#   'kita',
#   'tidak',
#   'tau',
#   'ada',
#   'permasalahan',
#   'apa',
#   'sedangkan',
#   'pak',
#   'eko',
#   'selalu',
#   'bilang',
#   'privacy',
#   'lah',
#   'kita',
#   'tapi'],
#  ['surat',
#   'rumah',
#   'pak',
#   'eko',
#   'ternyata',
#   'enggak',
#   'beres',
#   'pantas',
#   'enggak',
#   'ada',
#   'yang',
#   'bisa',
#   'membela',
#   'karena',
#   'secara',
#   'hukum',
#   'pak',
#   'eko',
#   'melakukan',
#   'pelanggaran',
#   'ternyata',
#   'pak',
#   'eko',
#   'meminta',
#   'simpati',
#   'publik',
#   'padahal',
#   'secara',
#   'hukum',
#   'dia',
#   'bersalah'],
#  ['kenapa',
#   'buat',
#   'rumah',
#   'tidak',
#   'membuat',
#   'akses',
#   'untuk',
#   'jalan',
#   'sendiri',
#   'berarti',
#   'selama',
#   'ini',
#   'mengambil',
#   'jalan',
#   'dari',
#   'tanah',
#   'orang',
#   'lain',
#   'mengambil',
#   'hak',
#   'tetangga',
#   'untuk',
#   'kepentingan',
#   'sendiri'],
#  ['mungkin',
#   'pak',
#   'eko',
#   'disuruh',
#   'bayar',
#   'akses',
#   'jalan',
#   'tapi',
#   'enggak',
#   'mau',
#   'kalo',
#   'seperti',
#   'ini',
#   'ya',
#   'enggak',
#   'akan',
#   'ada',
#   'titik',
#   'temu',
#   'karena',
#   'pemilik',
#   'jalan',
#   'mungkin',
#   'beli',
#   'keseluruhan',
#   'tapi',
#   'pak',
#   'eko',
#   'meminta',
#   'buka-buka',
#   'doang',
#   'tiap',
#   'jenderal',
#   'tanah',
#   'itu',
#   'berharga',
#   'apalagi',
#   'dikatakan'],
#  ['aneh',
#   'sih',
#   'memang',
#   'kelakuan',
#   'tetangga',
#   'seperti',
#   'ini',
#   'biasanya',
#   'sih',
#   'maaf',
#   'yang',
#   'sering',
#   'model-model',
#   'tutup',
#   'jalan',
#   'tutup',
#   'got',
#   'karena',
#   'itu',
#   'dulu',
#   'tanah',
#   'mengomong',
#   'gue',
#   'itu',
#   'dulu',
#   'punya',
#   'babak',
#   'enggak akan',
#   'bukan',
#   'orang',
#   'sunda'],
#  ['salah',
#   'sendiri',
#   'lah',
#   'kenapa',
#   'dulu',
#   'enggak',
#   'dijual',
#   'saja',
#   'tuh',
#   'rumah',
#   'jual',
#   'murah',
#   'saja',
#   'sama',
#   'tetangga',
#   'pakai',
#   'anjir',
#   'jangan',
#   'pakai',
#   'harga',
#   'pasar',
#   'dong',
#   'dipelihara'],
#  ['aparat',
#   'kecamatan',
#   'sama',
#   'desa',
#   'nya',
#   'saja',
#   'yang',
#   'enggak',
#   'becus',
#   'buat',
#   'me',
#   'mediasi',
#   'masalah',
#   'seperti',
#   'itu',
#   'ganti',
#   'langsung',
#   'camat',
#   'sama',
#   'lurah',
#   'nya',
#   'kok',
#   'ada',
#   'masyarakat',
#   'nya',
#   'susah',
#   'enggak',
#   'segera',
#   'di',
#   'bantu',
#   'penyelesaian',
#   'masalah',
#   'nya'],
#  ['mas',
#   'eko',
#   'anda',
#   'harus',
#   'info',
#   'ke',
#   'media',
#   'sewaktu',
#   'anda',
#   'sudah',
#   'melaporkan',
#   'ke',
#   'dinas',
#   'terkait',
#   'bahkan',
#   'sampai',
#   'gubernur',
#   'dan',
#   'tidak',
#   'dibangga-banggakan',
#   'harus',
#   'cerita',
#   'siapa',
#   'saja',
#   'sehingga',
#   'anda',
#   'tidak',
#   'sebar',
#   'foto bareng',
#   'ikut-ikut',
#   'ini',
#   'biar',
#   'ditindak',
#   'bila',
#   'itu',
#   'benar',
#   'tayang',
#   'pernah',
#   'takut'],
#  ['ribu', 'ribu', 'kelurahan', 'camat', 'enggak', 'becus'],
#  ['sabar',
#   'pak',
#   'eko',
#   'semua',
#   'akan',
#   'di',
#   'selesaikan',
#   'dalam',
#   'hitungan',
#   'jam',
#   'tapi',
#   'di',
#   'tahun',
#   '2019',
#   'setelah',
#   'rezim',
#   'berganti'],
#  ['ah',
#   'aneh',
#   'orang',
#   'lempar',
#   'kertas',
#   'dikejar',
#   'tapi',
#   'orang',
#   'bisa',
#   'nampak',
#   'jokowi',
#   'waktu',
#   'touring',
#   'motor',
#   'enggak',
#   'diinterogasi',
#   'atau',
#   'dilumpuhkan',
#   'sampaikan',
#   'pencitraan',
#   'atau',
#   'sampainya',
#   'yang',
#   'enggak',
#   'becus',
#   'mengkhayal',
#   'presiden'],
#  ['itu',
#   'memakai',
#   'duit',
#   'mah',
#   'rek',
#   'aya',
#   'anu',
#   'peduli',
#   'kemana',
#   'atuh',
#   'kang',
#   'sing',
#   'sadar',
#   'boleh',
#   'namanya',
#   'jarang',
#   'hari',
#   'di',
#   'namanya',
#   'kos',
#   'kemana'],
#  ['kelihatannya',
#   'semua',
#   'tanahnya',
#   'sudah',
#   'ber',
#   'sertifikat',
#   'kenapa',
#   'tidak',
#   'di',
#   'pertanyakan',
#   'ke',
#   'badan',
#   'pertanahan',
#   'seharusnya',
#   'tidak',
#   'ada',
#   'penerbitan',
#   'sertifikat',
#   'tanpa',
#   'ada',
#   'jalan',
#   'melalui',
#   'tanah',
#   'tersebut',
#   'kalo',
#   'tidak',
#   'ada',
#   'tanggapan',
#   'dari',
#   'bukan',
#   'maka',
#   'ajukan',
#   'gugatan',
#   'ke',
#   'begitu',
#   'dimana',
#   'bukan',
#   'sebagai',
#   'tergugat',
#   '1'],
#  ['harusnya',
#   'waktu',
#   'dikejar',
#   'menyarankan',
#   'diri',
#   'saja',
#   'biar',
#   'pak',
#   'jokowi',
#   'tau',
#   'masalahnya',
#   'tapi',
#   'kenapa',
#   'bapak',
#   'lari',
#   'sih',
#   'itu',
#   'kesempatan',
#   'emas',
#   'padahal',
#   'pak'],
#  ['pemerintah', 'bandung', 'enggak', 'becus', 'kerja'],
#  ['ya', 'iyalah', 'main', 'lempar', 'saja'],
#  ['sebenarnya',
#   'masalahnya',
#   'apa',
#   'kenapa',
#   'tidak',
#   'ada',
#   'penyelesaian',
#   'mana',
#   'bupati',
#   'bandung',
#   'kenapa',
#   'diam',
#   'diam',
#   'saja',
#   'meminta',
#   'dipecat'],
#  ['coba',
#   'diselesaikan',
#   'secara',
#   'kekeluargaan',
#   'dengan',
#   'hati',
#   'dingin',
#   'tanpa',
#   'erosi',
#   'insyaallah',
#   'ketemu',
#   'menjalani'],
#  ['aneh',
#   'segitu',
#   'gilanya',
#   'kah',
#   'ganteng',
#   'ribu',
#   'ribu',
#   'sama',
#   'lurah',
#   'enggak',
#   'bisa',
#   'tangani',
#   'kah',
#   'mudah-mudahan',
#   'masalah',
#   'ini',
#   'sampai',
#   'ke',
#   'jokowi',
#   'biar',
#   'masalah',
#   'selesai',
#   'sebenarnya',
#   'masalah',
#   'kayak',
#   'begini',
#   'bukan',
#   'urusan',
#   'presiden',
#   'karena',
#   'menyangka',
#   'urusan',
#   'paspampres',
#   'atau',
#   'oknum',
#   'yang',
#   'mengaku',
#   'paspampres',
#   'jadi',
#   'enggak',
#   'ada',
#   'salahnya',
#   'pak',
#   'jokowi',
#   'bantu',
#   'selesaikan',
#   'masalah'],
#  ['sepertinya',
#   'dua',
#   'pihak',
#   'awal',
#   'nya',
#   'sama-sama',
#   'kepala',
#   'batu',
#   'sehingga',
#   'kejadian',
#   'seperti',
#   'itu',
#   'akhirnya'],
#  ['kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tapi',
#   'akses',
#   'ke',
#   'jalan',
#   'nya',
#   'enggak',
#   'ada',
#   'pasti',
#   'enggak',
#   'ada',
#   'mbak',
#   'nya',
#   'ya'],
# ...
#   'pak',
#   'mau',
#   'harusnya',
#   'surabaya',
#   'mendukung',
#   'dan',
#   'mengomongnya',
#   'tapi',
#   'karena',
#   'sudah',
#   'kapan',
#   'bawa perasaan',
#   'dan',
#   'sudah',
#   'kapan',
#   'janji',
#   'sama',
#   'prabowo',
#   'walau',
#   'berat',
#   'hati',
#   'ya',
#   'mau',
#   'enggak',
#   'mau',
#   'langsung',
#   'prabowo'],
#  ['ketum', 'demokrat', 'sudah', 'kagak', 'ada', 'giginya'],
#  ['nafsu', 'berkuasa', 'ya', 'hahaha'],
#  ['jelas',
#   'bisa',
#   'dimengerti',
#   'rakyat',
#   'papua',
#   'merasakan',
#   'sekali',
#   'apa',
#   'yang',
#   'sudah',
#   'dilakukan',
#   'beres',
#   'jokowi',
#   'diantar',
#   'keadilan',
#   'nyata',
#   'dilakukan',
#   'bukan',
#   'sekedar',
#   'jargon',
#   'politik',
#   'hasilnya'],
#  ['mengomong',
#   'enggak',
#   'kuat',
#   'karena',
#   'kardus',
#   'sudah',
#   'di',
#   'banget',
#   'kelakuan',
#   'politisi',
#   'menontonnya'],
#  ['coba',
#   'pendapat',
#   'bapak',
#   'ini',
#   'disampaikan',
#   'ke',
#   'junjungan',
#   'apa',
#   'supaya',
#   'enggak',
#   'nyinyir',
#   'beliau',
#   'enggak',
#   'mungkin'],
#  ['ibarat',
#   'bangunan',
#   'mewah',
#   'koalisi',
#   'ini',
#   'sebenarnya',
#   'kepo',
#   'dan',
#   'jauhi',
#   'mau',
#   'mau',
#   'menang',
#   'ini',
#   'mengurus',
#   'intern',
#   'koalisi',
#   'sih',
#   'saja',
#   'enggak',
#   'hidup',
#   'kau',
#   '2',
#   'periode'],
#  ['anjir',
#   'mantap',
#   'masa',
#   'pakai',
#   'dan',
#   'kapan',
#   'saja',
#   'yang',
#   'dapat',
#   'lihatlah',
#   'pada',
#   'jangan',
#   'mau',
#   'dibohongi',
#   'sama',
#   'gerindra',
#   'pakai',
#   'dan',
#   'punya'],
#  ['saja',
#   'boleh',
#   'sikat',
#   'terus',
#   'masa',
#   'cuma',
#   'mereka',
#   'doang',
#   'yang',
#   'dapat',
#   'kardus',
#   'pada',
#   'enggak',
#   'ayo',
#   'jangan',
#   'mau',
#   'tuntut',
#   'juga',
#   'bagian',
#   'kamu'],
#  ['koalisi', 'enggak', 'percuma', 'lo', 'pada', 'beruntung', 'lo', 'semua'],
#  ['mau',
#   'menuding',
#   'dua',
#   'atau',
#   'tiga',
#   'kaki',
#   'juga',
#   'enggak salah',
#   'sayang',
#   'penting',
#   'pakai',
#   'sudah',
#   'dapat',
#   '500',
#   'berarti',
#   'pertahun',
#   'sebelumnya',
#   'kan',
#   'coba',
#   'kalau',
#   'gandakan',
#   'dari',
#   'hasil',
#   'korupsi',
#   'atau',
#   'pemberian',
#   'jangan-jangan',
#   'di',
#   'selamat',
#   'sama',
#   'kpk',
#   'pacarnya',
#   'gigit',
#   'jari',
#   'dong',
#   'kalau',
#   'ini',
#   'kan',
#   'barter',
#   'meskipun',
#   'nantinya',
#   'kalah',
#   'pasti',
#   'kalah',
#   'dalam',
#   'pilpres',
#   'enggak salah',
#   'yang',
#   'rugi',
#   'kan',
#   'bukan',
#   'pakai',
#   'atau',
#   'kapan',
#   'paham',
#   'kan',
#   'sekarang',
#   'penting',
#   'duitnya',
#   'gerindra',
#   'sudah',
#   'keluar',
#   'kalau',
#   'ada',
#   'bahasa',
#   'untuk',
#   'kampanye',
#   'itu',
#   'kan',
#   'cuma',
#   'alasan',
#   'saja',
#   'biar',
#   'perebut'],
#  ['ya',
#   'kenyataannya',
#   'semuanya',
#   'main',
#   '2',
#   'kaki',
#   'dan',
#   'orang tuanya',
#   'mau',
#   'apa',
#   'lagi'],
#  ['jadi',
#   'juga',
#   'aneh',
#   'pakai',
#   'mengomong',
#   'sudah',
#   'jelas',
#   'pantas',
#   'kuberikan',
#   'sejati',
#   'repot',
#   'cepat-cepat',
#   'gagal',
#   'muka',
#   'on'],
#  ['ya', 'apakah', 'masih', 'percaya', 'dengan', 'komentarnya'],
#  ['kalau', 'panas', 'dalam', 'minum', 'tuh', 'kaki', '3', 'biar', 'deh'],
#  ['ketua', 'diam', 'bisa', 'dianggap', 'seru'],
#  ['dah',
#   'mending',
#   'bubar',
#   'saja',
#   'nih',
#   'koalisi',
#   'enggak',
#   'orang tuanya',
#   'bikin',
#   'program',
#   'malah',
#   'ribut',
#   'sendiri',
#   'mending',
#   'bubar',
#   'latihan',
#   'sudah',
#   'pasti',
#   'kalah',
#   'kok',
#   'mengapai',
#   'di',
#   'lanjutkan'],
#  ['membanyaki',
#   'pedas',
#   'dan',
#   'pantas',
#   'nyungsep',
#   'suaranya',
#   'pemilu',
#   '2019'],
#  ['koalisi', 'selalu', 'kardus', 'basah'],
#  ['jadi',
#   'amin',
#   'yang',
#   'selalu',
#   'menyerang',
#   'koalisi',
#   'sendiri',
#   'ini',
#   'kenapa',
#   'tidak',
#   'ditegur',
#   'surabaya',
#   'ada',
#   'apa',
#   'di',
#   'koalisi',
#   'prabowo',
#   'anda',
#   'padahal',
#   'bersikap',
#   'pura-pura',
#   'netral',
#   'di',
#   'pilpres',
#   '2014',
#   'sama',
#   'juga',
#   'bermain',
#   '2',
#   'kaki',
#   'pak',
#   'jadi'],
#  ['dulu',
#   'mencari',
#   'makan',
#   'setelah',
#   'menjabat',
#   'jadi',
#   'kata-kata',
#   'bahkan',
#   'daging',
#   'juga',
#   'di',
#   'empat',
#   'penjara',
#   'dan',
#   'akhirnya',
#   'neraka'],
#  ['nah', 'lu', 'kena', 'deh'],
#  ['kardus', 'kardus', 'karismanya', 'bagian', 'garuk-garuk'],
#  ['politik', 'cari', 'makan', 'alias', 'parpol', 'kardus'],
#  ['dia', 'meminta', 'isi', 'kardus', 'itu'],
#  ['badut',
#   'badut',
#   'positif',
#   'pol',
#   'buat',
#   'gayanya',
#   'anjir',
#   'bocor',
#   'sabar'],
#  ['jerawat',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'semangat',
#   'nyungsep'],
#  ['jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'semangat',
#   'nyungsep'],
#  ['lebih', 'bagus', 'cap', 'kaki', 'enggak bisa', 'buat', 'kesehatan'],
#  ['kaki', 'mau'],
#  ['salam', 'dua', 'kaki', 'ya'],
#  ['pak',
#   'surabaya',
#   'itu',
#   'kalau',
#   'mengomong',
#   'selalu',
#   'pinjam',
#   'banyak',
#   'moncong',
#   'mas',
#   'kayak',
#   'ban',
#   'bocor',
#   'aku',
#   'tapi',
#   'dilindungi',
#   'baru',
#   'lahir',
#   'ya'],
#  ['kalo',
#   'sudah',
#   'berdasarkan',
#   'data',
#   'dan',
#   'fakta',
#   'ya',
#   'susah',
#   'untuk',
#   'dijawab',
#   'alah'],
#  ['sih',
#   'kok',
#   'senang',
#   'banget',
#   'ribut',
#   'sih',
#   'rebutan',
#   'apa',
#   'lagi',
#   'deh',
#   'ganteng',
#   'datang',
#   'dong',
#   'ah',
#   'enggak',
#   'papa',
#   'masih',
#   'solid',
#   'kok',
#   'itu',
#   'hanya',
#   'dinamika',
#   'positif',
#   'deh'],
#  ['sesama', 'bangunlah', 'politik', 'dilarang', 'saling', 'mendahului'],
#  ['karena',
#   'kak',
#   'pakai',
#   'data',
#   'dan',
#   'fakta',
#   'maka',
#   'tidak',
#   'bisa',
#   'berbalas',
#   'pantun'],
#  ['kapan', 'pakai', 'sebaiknya', 'diam', 'kalo', 'enggak', 'punya', 'kaca'],
#  ['koalisi',
#   'saja',
#   'ribut',
#   'bagaimana',
#   'mau',
#   'menang',
#   'jargon',
#   'doang',
#   'kencang',
#   'kualitas',
#   'nol'],
#  ['mari',
#   'kita',
#   'bertepuk',
#   'bangsat',
#   'bangunlah',
#   'sudah',
#   'mulai',
#   'ribut'],
#  ['kayaknya',
#   'benar',
#   'juga',
#   'dulu',
#   'kan',
#   'koalisi',
#   'demokrat',
#   'tapi',
#   'sering',
#   'enggak',
#   'nurut'],
#  ['diam', 'itu', 'emas'],
#  ['lah',
#   'mengapai',
#   'juga',
#   'ibu-ibu',
#   'politik',
#   'pilkada',
#   'kemarin',
#   'juga',
#   'banyak',
#   'koalisi',
#   'mengakak',
#   'politik',
#   'disini',
#   'ya',
#   'begitu',
#   'cari',
#   'sensasi',
#   'doang'],
#  ['bukan',
#   '2',
#   'kaki',
#   'itu',
#   'mah',
#   'yang',
#   'kita',
#   'tahu',
#   'tapi',
#   '4',
#   'kaki',
#   '2',
#   'kaki',
#   'yang',
#   'sah',
#   '2',
#   'kaki',
#   'yang',
#   'siri',
#   'kan'],
#  ['main',
#   'dua',
#   'kaki',
#   'saat',
#   'pemilu',
#   'sudah',
#   'usai',
#   'banggakan',
#   'dan',
#   'kompromi',
#   'lah',
#   'ini',
#   'baru',
#   'mau',
#   'mulai',
#   'kakak',
#   'cerdas',
#   'dong',
#   'kamu',
#   'dek'],
#  ['pada',
#   'kapan',
#   'pakai',
#   'semua',
#   'ahli',
#   'main',
#   '2',
#   'kaki',
#   'cuman',
#   'gerindra',
#   'yang',
#   'enggak',
#   'punya',
#   'kaki'],
#  ['jadi', 'amin', 'dicari', 'bawaslu', 'tuh'],
#  ['habis',
#   'mau',
#   'bagaimana',
#   'lagi',
#   'enggak',
#   'mau',
#   'rugi',
#   'maunya',
#   'untung',
#   'terus'],
#  ['bertiga', 'saling', 'selingkuh'],
#  ['jadi',
#   'amin',
#   'ini',
#   'awalnya',
#   'anak-anak',
#   'meriah',
#   'terkait',
#   'dana',
#   'logistik',
#   'almarhum',
#   'untuk',
#   'kubu',
#   'koalisi',
#   'prabowo',
#   'karena',
#   'demokrat',
#   'tidak',
#   'di',
#   'ajak',
#   'bicara',
#   'sekarang',
#   'diam',
#   'dia',
#   'di',
#   'amankan',
#   'oleh',
#   'sandi',
#   'wajar',
#   'jadi',
#   'amin',
#   'ini',
#   'membela',
#   'demokrat',
#   'dan',
#   'surabaya'],
#  ['tepatnya', 'kapan', 'dan', 'pakai', 'tergantung', 'bayaran'],
#  ['satu',
#   'koalisi',
#   'saja',
#   'sudah',
#   'enggak',
#   'kompak',
#   'bagaimana',
#   'mau',
#   'menang',
#   'sudah',
#   'pada',
#   'jangan',
#   'ribut',
#   'menikmati',
#   'saja',
#   'dulu',
#   'kata-katanya',
#   'mudah-mudah',
#   'allah',
#   'menghancurkan',
#   'suara',
#   'kalian',
#   'di',
#   'pemilu',
#   '2019'],
#  ['salut',
#   'buat',
#   'timses',
#   'padi',
#   'dinamika',
#   'adalah',
#   'keharusan',
#   'dalam',
#   'sebuah',
#   'perjuangan',
#   'politik',
#   'ada',
#   'perbedaan',
#   'pendapat',
#   'kritik',
#   'juga',
#   'wajar',
#   'saja',
#   'solid',
#   'enggak',
#   'perlu',
#   'harus',
#   'yes',
#   'semua',
#   'diam',
#   'seribu',
#   'bahasa',
#   'seperti',
#   'dikekang',
#   'satu',
#   'suara',
#   'seperti',
#   'koalisi',
#   'jokowi',
#   'yang',
#   'ujung-ujung',
#   'melampiaskan',
#   'aneh-aneh',
#   'dengan',
#   'menyerang',
#   'koalisi',
#   'berbeda-beda',
#   'suara',
#   'bukan',
#   'masalah',
#   'tapi',
#   'saling',
#   'menghargai',
#   'harus',
#   'dijaga',
#   'dekati',
#   'terus',
#   'rakyat',
#   'karena',
#   'rakyatlah',
#   'yang',
#   'menentukan',
#   'kemenangan',
#   'di',
#   'pilpres',
#   'nanti'],
#  ['saja'],
#  ['percaya',
#   'kalo',
#   'jokowi',
#   'menang',
#   'kapan',
#   'akan',
#   'merapat',
#   'ke',
#   'jokowi',
#   'lagi',
#   'supaya',
#   'dapat',
#   'entar',
#   'jangan',
#   'kemarin',
#   'begitu'],
#  ['pada',
#   'main',
#   'dua',
#   'kaki',
#   'di',
#   'parlemen',
#   'habis',
#   'pilpres',
#   'kayanya',
#   'netral',
#   'tapi',
#   'condong',
#   'ke',
#   'kenapa'],
#  ['kelompok', 'sebelah', 'pemain', '2', 'kaki', 'semua', 'kak'],
#  ['jadi', 'arif', 'buang', 'saja', 'bikin', 'rusuh', 'saja'],
#  ['ayo', 'bertengkar', 'lah', 'aku', 'suka', 'hahaha'],
#  ['jadi', 'arif', 'kenapa', 'ya'],
#  ['jadi', 'penonton', 'ah', 'menghibur'],
#  ['ular',
#   'beda-beda',
#   'ini',
#   'keluar',
#   'lagi',
#   'setelah',
#   'sempat',
#   'terkenal',
#   'tidak',
#   'berani',
#   'bicara',
#   'di',
#   'depan',
#   'bawaslu',
#   'duren'],
#  ['sudah',
#   'tahu',
#   'bahwa',
#   'kalau',
#   'berkata',
#   'bohong',
#   'tidak',
#   'sesuai',
#   'omongan',
#   'kalau',
#   'janji',
#   'ingkar',
#   'pengin',
#   'kalau',
#   'dipercaya',
#   'ingkar',
#   'tidak',
#   'konsisten',
#   'tahu',
#   'munafik',
#   'kok',
#   'setuju',
#   'yang',
#   'waras',
#   'siapa',
#   'ya'],
#  ['perempuan',
#   'utama',
#   'di',
#   'pilpres',
#   '2019',
#   'ialah',
#   'jawa',
#   'barat',
#   'jawa',
#   'tengah',
#   'jawa',
#   'timur',
#   'sumatera',
#   'utara',
#   'dan',
#   'selamat',
#   'selatan',
#   'jawa',
#   'tengah',
#   'jelas',
#   'sudah',
#   'dijaga',
#   'mengantar',
#   'jawa',
#   'timur',
#   'ada',
#   'mbak',
#   'salihah',
#   'jawa',
#   'barat',
#   'kemungkinan',
#   'dengan',
#   'naiknya',
#   'kakak',
#   'jokowi',
#   'bakal',
#   'menang',
#   'selamat',
#   'selatan',
#   'pasti',
#   'ada',
#   'efek',
#   'dari',
#   'jika',
#   'sebagai',
#   'timses',
#   'jokowi',
#   'hanya',
#   'sumatera',
#   'utara',
#   'yang',
#   'masih',
#   'bisa',
#   'diperebutkan',
#   'oleh',
#   'kedua',
#   'koalisi'],
#  ['doang',
#   'orang',
#   'jangan',
#   'di',
#   'pilih',
#   'biar',
#   'negeri',
#   'ini',
#   'tidak',
#   'segera',
#   'bubar'],
#  ['belah', 'sono', 'ribut', 'terus', 'ya'],
#  ['mungkin', 'sedang', 'panas', 'dalam', 'bertambah', 'satu', 'kaki', 'lagi'],
#  ['kalo',
#   'pakai',
#   'mah',
#   'memang',
#   'enggak',
#   'ada',
#   'malunya',
#   'ikut',
#   'kabinet',
#   'surabaya',
#   'tapi',
#   'mengakak',
#   'program',
#   'pasien-pasiennya',
#   'saja',
#   'sampai',
#   'makan',
#   'aspal',
#   'di',
#   'jalan',
#   'nangka',
#   'sono'],
#  ['ada', 'hubungannya', 'dengan', 'kardus', 'enggak', 'nih'],
#  ['maling',
#   'teriak',
#   'maling',
#   'koalisi',
#   'kok',
#   'saling',
#   'menjelekkan',
#   'model-model'],
#  ['bagus', 'bro', 'saja', 'terus'],
#  ['apa',
#   'yang',
#   'diungkapkan',
#   'bung',
#   'jadi',
#   'arif',
#   'benar',
#   'sekali',
#   'kita',
#   'masih',
#   'ingat',
#   'waktu',
#   'pakai',
#   'ikut',
#   'dalam',
#   'kabinet',
#   'pak',
#   'surabaya',
#   'tapi',
#   'apabila',
#   'ada',
#   'kebijakan',
#   'dari',
#   'surabaya',
#   'selalu',
#   'ditentang'],
#  ['ini',
#   'orang',
#   'dari',
#   'awal',
#   'sudah',
#   'mulai',
#   'ribet',
#   'sebaik',
#   'nya',
#   'kalo',
#   'memang',
#   'enggak',
#   'searah',
#   'pecat',
#   'ini',
#   'apa',
#   'surabaya'],
#  ['pada',
#   'bubar',
#   'ajalah',
#   'sudah',
#   'enggak',
#   'ada',
#   'wibawa',
#   'di',
#   'mata',
#   'kadernya',
#   'apa',
#   'karena',
#   'ketumnya',
#   'enggak',
#   'tegas',
#   'atau',
#   'mungkin',
#   'hal',
#   'yang',
#   'sengaja',
#   'dibuat',
#   'untuk',
#   'main',
#   'dua',
#   'kaki',
#   'alias',
#   'mempraktikkan',
#   'politik',
#   'berdua',
#   'dua'],
#  ['lo',
#   'pakai',
#   'mengomong',
#   'mengalir',
#   'mengadu',
#   'enggak',
#   'jelas',
#   'bangsa',
#   'ini',
#   'banyak',
#   'masalah',
#   'terburu-buru',
#   'ekonomi',
#   'problem',
#   'kebangsaan',
#   'benturan',
#   'umat',
#   'dll',
#   'perlu',
#   'strong',
#   'leader',
#   'pas',
#   'ok'],
#  ['kuat',
#   'harusnya',
#   'pak',
#   'prabowo',
#   'kirim',
#   'utusan',
#   'mainnya',
#   'kayak',
#   'amat',
#   'di',
#   'neko-neko',
#   'sempat',
#   'ke',
#   'papua',
#   'wow'],
#  ['kata-katanya',
#   'pada',
#   'cerdas',
#   'juga',
#   'enggak',
#   'mau',
#   'dijadikan',
#   'boneka',
#   'senang',
#   'cs'],
#  ['yang',
#   'jelas',
#   'perolehan',
#   'sekarang',
#   'jokowi',
#   'mau',
#   'amin',
#   'akan',
#   'tambahkan'],
#  ['kira-kira',
#   'kalau',
#   'di',
#   'adu',
#   'dari',
#   'sisi',
#   'intelektual',
#   'kecerdasan',
#   'kesederhanaan',
#   'kepemimpinan',
#   'kekayaan',
#   'dari',
#   '4',
#   'kandidat',
#   'capres',
#   'cawapres',
#   'siapa',
#   'yang',
#   'menang',
#   'ya',
#   'gampang',
#   'sandi',
#   'yang',
#   'menang',
#   'muda',
#   'kayak',
#   'pintar',
#   'cerdas',
#   'sederhana',
#   'dan',
#   'yang',
#   'paling',
#   'penting',
#   'setia',
#   'sama',
#   'istri',
#   'dan',
#   'sayang',
#   'anak',
#   'gila',
#   'perebut',
#   'banget',
#   'sih',
#   'lo',
#   'sandi',
#   'yang',
#   'lain',
#   'pada',
#   'main',
#   'begini',
#   'muda',
#   'sama',
#   'selingkuh',
#   'lo',
#   'yang',
#   'duitnya',
#   'banyak',
#   'kok',
#   'malah',
#   'setia',
#   'top'],
#  ['keren'],
#  ['bagi',
#   '90',
#   'pengurus',
#   'depan',
#   'demokrat',
#   'di',
#   'papua',
#   'ini',
#   'hati',
#   'nurani',
#   'mereka',
#   'lebih',
#   'punya',
#   'integritas',
#   'karena',
#   'mereka',
#   'tau',
#   'sesungguhnya',
#   'siapa',
#   'yang',
#   'selama',
#   'ini',
#   'bekerja',
#   'untuk',
#   'warganya'],
#  ['rakyat',
#   'papua',
#   'tau',
#   'mana',
#   'presiden',
#   'yang',
#   'perhatian',
#   'dengan',
#   'papua',
#   'mana',
#   'yang',
#   'pura-pura',
#   'perhatian',
#   'tau',
#   'balikin',
#   'jaman dulunya',
#   'sandi'],
#  ['jati',
#   'diri',
#   'enggak',
#   'penting',
#   'ya',
#   'penting',
#   'memegang',
#   'boleh',
#   'khayalanku'],
#  ['memang',
#   'jokowi',
#   'masih',
#   'diinginkan',
#   'sebagian',
#   'besar',
#   'rakyat',
#   'untuk',
#   'menjadi',
#   'presiden',
#   '2',
#   'periode',
#   'kok'],
#  ['masalah',
#   'papua',
#   'itu',
#   'sangat',
#   'gampang',
#   'dan',
#   'malah',
#   'terlalu',
#   'gampang',
#   'merebut',
#   'suara',
#   'orang',
#   'papua',
#   'sebab',
#   'orang',
#   'papua',
#   'enggak',
#   'dengar',
#   'gubernur',
#   'asal',
#   'di',
#   'serahkan',
#   'sama',
#   'yang',
#   'ahli',
#   'nya',
#   'di',
#   'jamin',
#   '100',
#   'beres',
#   'jelas',
#   'bukan',
#   'masalah',
#   'infra',
#   'struktur',
#   'sebab',
#   'yang',
#   'menikmati',
#   'nya',
#   'tetap',
#   'pendatang',
#   'sedangkan',
#   'orang',
#   'asli',
#   'papua',
#   'tetap',
#   'jadi',
#   'penasaran',
#   'pada',
#   'ahli',
#   'nya',
#   'papua',
#   'pasti',
#   'prabowo',
#   'sandi'],
#  ['demokrat',
#   'seharusnya',
#   'join',
#   'dengan',
#   'jokowi',
#   'saja',
#   'tim',
#   'prabowo',
#   'sandi',
#   'enggak',
#   'butuh',
#   'demokrat',
#   'cukup',
#   'merekomendasikan',
#   'saja',
#   'sudah',
#   'pasti',
#   'menang',
#   'di',
#   '2019'],
#  ['wow',
#   'kembalikan',
#   'jaman dulunya',
#   'kalo',
#   'enggak',
#   '100',
#   'dukung',
#   'wow'],
#  ['alhamdulillah', 'amin'],
#  ['sebaiknya',
#   'demokrat',
#   'ke',
#   'jokowi',
#   'saja',
#   'tidak',
#   'apa',
#   'apa',
#   'pakai',
#   'kapan',
#   'gerindra',
#   'sangat',
#   'solid'],
#  ['harus',
#   'depan',
#   'tidak',
#   'bisa',
#   'mengatur',
#   'diputuskan',
#   'depan',
#   'harus',
#   'satu',
#   'komentari',
#   'juga',
#   'ini'],
#  ['demokrat', 'pengin', 'plan'],
#  ['karena',
#   'tidak',
#   'terbendung',
#   'suara',
#   'kader',
#   'yang',
#   'terbelah',
#   'berubah',
#   'strategi',
#   'demi',
#   'menutup',
#   'muka',
#   'yang',
#   'sudah',
#   'terima kasih',
#   'demokrat'],
#  ['100', 'kakaknya', 'pokok', 'ini', 'orang', 'baik'],
#  ['rakyat',
#   'papua',
#   'merasakan',
#   'langsung',
#   'pembangunan',
#   'era',
#   'presiden',
#   'jokowi'],
#  ['hasil', 'akhirnya', 'dan', 'saya', 'yakin', 'jokowi', 'kalah', 'dia'],
#  ['bagus',
#   'jangan',
#   'ikut',
#   'orang',
#   'jahat',
#   'saudara',
#   'papua',
#   'merasakan',
#   'pembangunan'],
#  ['apa', 'kata', 'teringat', 'cs', 'ya', 'hai', 'apa'],
#  ['karena', 'apa', 'maju'],
#  ['mbah', 'main', 'langsung', 'kebanggaan'],
#  ['mereka',
#   'ini',
#   'yang',
#   'benar-benar',
#   'sudah',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'pembangunan',
#   'jalan',
#   'dan',
#   'sebagainya',
#   'di',
#   'sana',
#   'tidak',
#   'bisa',
#   'ditutupi',
#   'dan',
#   'disangkal',
#   'lagi']]

# %%
slang_words
# Out:
# ['wkwkwk = wow',
#  'dpr = dari',
#  'miftah = meminta',
#  'walisongo = maling',
#  'sunan = ulang',
#  'jagasmua = bagaimana',
#  'ajk = saja',
#  'sikon = semakin',
#  'adabnya = apa-apanya',
#  'kemunkaran = terbuka',
#  'tanganmukekuatanmu = ambekan',
#  'mulutmu = mulut-mulut',
#  'hatimu = hati-hati',
#  'selemah = salihah',
#  'disisipin = disini',
#  'umpanin = menyarankan',
#  'nocannya = menontonnya',
#  'miftah = meminta',
#  'fpi = tapi',
#  'hti = hati',
#  'beneranditerima = benaran',
#  'kalangankl = jangan',
#  'uas = kak',
#  'guslanjutkaninilah = lanjutkan',
#  'jadunya = jaman dulunya',
#  'wkwkwkmantap = mantap',
#  'swt = buat',
#  'mantaaappppbuat = mantap',
#  'dpr = dari',
#  'josshhh = loh',
#  'gratisan = gratis',
#  'nope = apa',
#  'batas2 = bahas-bahas',
#  'kereennnnnnn = keren',
#  'snagat = ingat',
#  'katimbang = kembang',
#  'sebenar = sekadar',
#  'gusjustru = justru',
#  'bedebah = benaran',
#  'ahok = hendak',
#  'subhanallah = subhanallah',
#  'swt = buat',
#  'jenengan = senangi',
#  'salutterharu = terharu',
#  'cacianluar = caranya',
#  'whats = atas',
#  'boshe = boleh',
#  'lol = loh',
#  'boshe = boleh',
#  'ud83dude02ud83dude02 = dulu',
#  'guss = enggak bisa',
#  'begituan = begituan',
#  'hahahaha = alah',
#  'plesetkan = ledeki',
#  'hahahaha = alah',
#  'biaskan = biasa-biasa',
#  'naaaah = deh',
#  'bersholawat = selamat',
#  'bersholawat = selamat',
#  'somat = selamat',
#  'bersholawat = selamat',
#  'maaaaat = ya',
#  'mat = selamat',
#  'sak = enggak',
#  'nyadan = menyadari',
#  'ngiriweek = mengiri',
#  'hahahaha = alah',
#  'lucuan = lucu',
#  'tipi = tapi',
#  'laah = dah',
#  'nite = kita',
#  'iti = itu',
#  'entahlah = entah',
#  'ngikik = mengakak',
#  'auratnya = syaratnya',
#  'banser = banget',
#  'anshor = aneh-aneh',
#  'suaranyaormas = suaranya',
#  'simbah = bertambah',
#  'ngakui = mengaku',
#  'menjelek = menjelekkan',
#  'jelekkan = menjelek-jelekkan',
#  'percayaseolah = permasalahkan',
#  'jogja = juga',
#  'oranghingga = pangling',
#  'berkesimpulan = kesampaian',
#  'nglakoni = berlakon',
#  'iso = sok',
#  'pekalongan = pengin',
#  'amien = amin',
#  'amien = amin',
#  '2019panbakalgurem = enggak bakal',
#  'sutrisno = suaminya',
#  'bakhir = menaksir',
#  'rais = atas',
#  'sendiri2 = sendiri',
#  'pansutrisno = menghancurkan',
#  'habis2an = habis-habis',
#  'amien = amin',
#  'raispan = kasihan',
#  'amien = amin',
#  'kumat = suami',
#  'butek = bulat',
#  'diobok2 = ibu-ibu',
#  'amien = amin',
#  'sutrisno = suaminya',
#  'pramono = promo',
#  'menseskab = membelah',
#  'mensesneg = senang',
#  'mkan = bukan',
#  'allahuakbar = allah',
#  'ahlul = aku',
#  'penebar = benaran',
#  'nikmatnya = lihatnya',
#  'lp = lagi',
#  'cipinang = hilang',
#  'ahlul = aku',
#  'penebar = benaran',
#  'wowo = wow',
#  'hehehhe = sih',
#  'grindong = ganteng',
#  'ngomentari = mengomentari',
#  'rommy = memang',
#  'gerombolannya = komentarnya',
#  'koar2 = doa-doa',
#  'ham = hai',
#  'dsb = tersebut',
#  'sik = sih',
#  'buni = begini',
#  'yaniiii = lagi',
#  'kejaaarr = terjawab',
#  'wowo = wow',
#  'pimrednya = pacarnya',
#  'penyadang = pandang',
#  '10tahun = tahun',
#  'az = aku',
#  'buni = begini',
#  'yani = sayang',
#  'bonita = berita',
#  'bonita = berita',
#  'sensasinya = sebenarnya',
#  'film2 = film',
#  'hollywood = halo',
#  'tungguin = menunggu',
#  'prabocor = promo',
#  'zonk = dong',
#  'terbagus = terbaik',
#  'kudengar = adegan',
#  'tongkaciann = menongol',
#  'nyebar = mencebur',
#  'fitnahduitnya = mengeditnya',
#  'istrimau = terima',
#  'anakmu = anak-anakmu',
#  'wowo = wow',
#  'dikarungin = ditayangkan',
#  'habisin = hapuskan',
#  'gangu = enggak',
#  'buni = begini',
#  'yani = sayang',
#  'laaaahhh = ah',
#  'nasbung = menyambung',
#  'pemred = sempat',
#  'prekom = neko-neko',
#  'bumnwelehwelehitu = banget',
#  'buni = begini',
#  'yani = sayang',
#  'balik2 = baik-baik',
#  'kandangin = menantang',
#  'penjarakedua2nya = penasaran',
#  'penebar = benaran',
#  'siap2 = siapa-siapa',
#  'micin = admin',
#  'lp = lagi',
#  'cipinang = hilang',
#  'lintang = ganteng',
#  'pukang = pusing',
#  'mewek = dek',
#  'gembeng = mengomong',
#  'cebong = repot',
#  'buset = bulat',
#  'dahjamintelnya = jaman-jamannya',
#  'sendirimiris = sendiri',
#  'petromak = trauma',
#  'tuhhhhh = duh',
#  'mudabuaknnya = kelahirannya',
#  'mudapayah = murah',
#  'yess = ya',
#  'aaaah = deh',
#  'seberat2nya = sebelum-sebelumnya',
#  '10thn = tahun',
#  'lawyernya = kelahirannya',
#  'habibu = ajib',
#  'getombolan = menongol',
#  'micin = admin',
#  'jantungan = hitungan',
#  'wowok = wow',
#  'bravo = berani',
#  'seberatberatnya = sebenarnya',
#  'cebong = repot',
#  'viktor = pintar',
#  'laiskodat = lihat',
#  'armando = amat',
#  'nathan = menahan',
#  'ananda = anaknya',
#  'sukarlan = sekarang',
#  'surveyor = suer',
#  'ines = ingat',
#  'abal = abal-abal',
#  'abal = abal-abal',
#  'romi = kami',
#  'pendananya = memandanginya',
#  'jaksaterus = justru',
#  'walaupum = walaupun',
#  'sumbangtempat = semangat',
#  'disediakanwkwkwkwkkw = gila',
#  'nangkep2 = tangkap',
#  'disate = dipakai',
#  'jidat = jidat',
#  'hoaxnya = kayanya',
#  'juragannya = jaman-jamannya',
#  'pki = pakai',
#  'gapresiden = garami',
#  'dihormatikl = dihargai',
#  'gapresiden = garami',
#  'dihormatikl = dihargai',
#  'gapresiden = garami',
#  'dihormatikl = dihargai',
#  'hhahahh = alah',
#  'ketebak = kembar',
#  'blaa = lah',
#  'blaaa = ya',
#  'blaaaa = gila',
#  'lanjutakan = lanjutkan',
#  'berkali2 = sekali-kali',
#  'lahtolong = mencolong',
#  'thanks = tahan',
#  'bgaimanapun = bagaimanapun',
#  'wkwk = wow',
#  'turki = untuk',
#  'erdogan = edan',
#  'pks = pakai',
#  'disikat = dilihat',
#  'disikat = dilihat',
#  'musnahkan = mudah-mudahan',
#  'muantap = mantap',
#  'dalam2 = dalam-dalam',
#  'kelaut = kalau',
#  'membelanah = membelah',
#  'donaturnya = menontonnya',
#  'buniyani = punya',
#  'kokk = kak',
#  'bravo = berani',
#  'kejaksaanlumayan = kebayanya',
#  'hajar = saja',
#  'sebrang = sekarang',
#  'pantesnya = pantas',
#  'hukun = bukan',
#  'wkwkwkwkwkw = wow',
#  'syukurlah = sukur-sukur',
#  'luuu = lucu',
#  'sebutin = menyembuhkan',
#  'keladinya = kebayanya',
#  'surat2 = sehat-sehat',
#  'dikasi = dikasih',
#  'entu = bantu',
#  'abal = abal-abal',
#  'abal = abal-abal',
#  'bisa2 = biasa-biasa',
#  'cebong = repot',
#  'surganya = surga',
#  'bp = tapi',
#  'runah = sudah',
#  'bawaq = bawa',
#  '15m = almarhum',
#  'relakan = rela',
#  '115m = almarhum',
#  'baikbaik = baiknya',
#  'maruk = garuk-garuk',
#  '100jt = juta',
#  '150jt = juta',
#  'kolot = kalo',
#  'undangundang = undangan-undangan',
#  'dibelakangnya = dilihatnya',
#  'maukah = enggak usah',
#  'kupingnya = kucingnya',
#  'maukah = enggak usah',
#  'u2063sepertinya = sepertinya',
#  'rtrw = terus',
#  'lurahcamat = lihat',
#  'bppn = kapan',
#  'batasbatas = banget',
#  'priksa = terasa',
#  'imb = mbak',
#  'suruk = suruh',
#  'satpol = sampai',
#  'menjudge = menjadi',
#  'tabayyunsimple = bayangkan',
#  'salahyg = salahkan',
#  'lainklo = lain',
#  'jalantetangganya = jalan-jalannya',
#  'salahtapi = silakan',
#  'menembokyg = tembok',
#  'setempatmana = tempat-tempat',
#  'disalahin = salahkan',
#  'jugamemang = segampang',
#  'diaklo = halo',
#  'jalantetangga = ganteng',
#  'kirikanan = kelihatan',
#  'serupaapesnya = rupa-rupanya',
#  'pakitu = pahit',
#  '100jt = juta',
#  '150jt = juta',
#  '150jt = juta',
#  '100jt = juta',
#  'donkntar = entar',
#  '150jt = juta',
#  '200jt = juta',
#  'pedulian = mempedulikan',
#  'benernya = sebenarnya',
#  'pulaini = pula',
#  'pmp = sampai',
#  'toleransisaling = toleransi',
#  'menghargaissopan = penghargaan',
#  'santunempati = mengumpat-ngumpat',
#  '100jt = juta',
#  '150jt = juta',
#  'rengek = pengin',
#  'kamari = kemarin',
#  'terbacapokok = terbaik',
#  'minta2 = meminta',
#  'hei = hai',
#  'ongkang2 = orang-orang',
#  'kumpeni = simpan',
#  'pade = pakai',
#  'rt = ribu',
#  'rw = ribu',
#  'diserobotud83dude0b = seburuk-buruk',
#  'masalahnyalain = masalah',
#  'kumbang = kembang',
#  'belangnyaud83dude02 = memangnya',
#  'pangadilan = panggilannya',
#  'kemana2 = kemana-mana',
#  '100jt = juta',
#  '150jt = juta',
#  'lgdr = lagi',
#  'jls = jalan',
#  'gitutinggal = hitungan',
#  'blkg = bilang',
#  'rt = ribu',
#  'rw = ribu',
#  'kadus = kamu',
#  'klpun = kapan',
#  'pakpunya = enggak punya',
#  'senangsenang = kesenangan',
#  'mondarmandir = menyarankan',
#  'masalh = masalah',
#  'spya = saya',
#  'masoook = ayo',
#  'solatin = salahkan',
#  'kafanin = menyarankan',
#  'dikuburin = diputuskan',
#  'adabnya = apa-apanya',
#  'masook = masih',
#  'ekooo = lo',
#  'u2063saya = saya',
#  'wkwkww = wow',
#  'rt = ribu',
#  'rw = ribu',
#  'bpn = bukan',
#  'walkot = warung kopi',
#  'tidorrrr = anjir',
#  'semuaaaaaa = semuanya',
#  'masssook = mas',
#  'ekoo = lo',
#  'ekoud83dude33ud83dude33ud83dude33 = rindu',
#  'lqin = lagi',
#  'urusan2 = mengurusi',
#  'bpn = bukan',
#  'bodohhh = loh',
#  'awalud83dude06ud83dude06ud83dude06 = mau',
#  'undang2 = pandang',
#  'tidal = tiba-tiba',
#  'masooookkkk = ayo',
#  'ekooo = lo',
#  'imb = mbak',
#  'lock = cocok',
#  'sandiri = sendiri',
#  'abu2 = ibu-ibu',
#  'bpn = bukan',
#  'terutuang = beruntung',
#  'cth = tahun',
#  'disertifikat = dibeginikan',
#  'dikiri = dikasih',
#  'ditgh = begitu',
#  'blkg = bilang',
#  'kepotong = dipotong',
#  'rt = ribu',
#  'rw = ribu',
#  'ayu = yuk',
#  'jlnnya = jamnya',
#  'imb = mbak',
#  'rt = ribu',
#  'masuuukkk = yuk',
#  'pakk = ya',
#  'ekoo = lo',
#  'ngeblokade = melarang',
#  'u201cmasuk = termasuk',
#  'ekou201d = maksud',
#  'imb = mbak',
#  'setega = semoga',
#  'jlan = jalan',
#  'gusti = pasti',
#  'pampapres = hempas',
#  'ngelempar = menggampar',
#  'sifatmu = silau',
#  'instropeksi = stres',
#  'u2063sepertinya = sepertinya',
#  'rtrw = terus',
#  'lurahcamat = lihat',
#  'bppn = kapan',
#  'batasbatas = banget',
#  'dibuatin = buatkan',
#  'jabar = jawaban',
#  'semuasemua = semua',
#  'kalees = kali',
#  'nyelesaikan = menyelesaikan',
#  'daerah2 = marah-marah',
#  'joni = jangan',
#  'rtrw = terus',
#  'kotamadya = kakaknya',
#  'ombudsman = mudah-mudahan',
#  'ombudsman = mudah-mudahan',
#  'ngejar2 = mengajar',
#  'pancasilais = pantas',
#  'rt = ribu',
#  'rw = ribu',
#  'camaunya = enggak taunya',
#  'akalnya = kakaknya',
#  'lif = sih',
#  'pertanyaanya = pertamanya',
#  'bertetangganya = barangnya',
#  'piye = kita',
#  'pantesan = pantas',
#  'knapa = kenapa',
#  'bearti = berarti',
#  'mumgkin = mungkin',
#  'cuma2 = buka-buka',
#  'jengkal = jenderal',
#  'diperkotaan = dikatakan',
#  'sihmhn = sih',
#  'engkong = mengomong',
#  'gwkan = enggak akan',
#  'njop = anjir',
#  'dungu = dong',
#  'ditanggapiada = dibangga-banggakan',
#  'fitnahbiar = foto bareng',
#  'oknum2 = ikut-ikut',
#  'adanyajgn = tayang',
#  'rt = ribu',
#  'rw = ribu',
#  'hhhh = ah',
#  'nepuk = nampak',
#  'paspampressetting = sampaikan',
#  'paspampresnya = sampainya',
#  'ngawal = mengkhayal',
#  'teu = itu',
#  'kumaha = kemana',
#  'weh = boleh',
#  'ayeunamah = namanya',
#  'urang = jarang',
#  'hirup = hari',
#  'nagara = namanya',
#  'kumaha = kemana',
#  'bpn = bukan',
#  'ptun = begitu',
#  'bpn = bukan',
#  'nyerahin = menyarankan',
#  'jalanyaud83dude0e = menjalani',
#  'egoisnya = gilanya',
#  'paravtetangga = ganteng',
#  'rt = ribu',
#  'rw = ribu',
#  'nyampr = sampai',
#  'nyangkut2 = menyangka',
#  'ngaku2 = mengaku',
#  'imb = mbak',
#  'rmhnya = jamnya',
#  'sehrsnya = harusnya',
#  'apesstressnasib = pedas',
#  'walkot = warung kopi',
#  'description = membesarkan',
#  'nyananti = menyarankan',
#  'kelurahankecwalikota = kebayanya',
#  'tahuteryata = waktunya',
#  'dilaporkanteryata = kelahirannya',
#  'megadu = memegang',
#  'wkwkwk = wow',
#  'bisa2 = biasa-biasa',
#  'secret = sempat',
#  'rw = ribu',
#  'serifikat = berpikir',
#  'anehsekali = sekali-kali',
#  'modif = modis',
#  'dinkmati = menikmati',
#  'uanganya = kakaknya',
#  'roy = ribu',
#  'suryo = suruh',
#  'u2063eko = kayak',
#  'purnomo = promo',
#  'mentri = entar',
#  'u2063semoga = semoga',
#  'ketiadilan = kelihatan',
#  'gituawalnya = tuanya',
#  'gimanabisa = bagaimana',
#  'urutkan = dapatkan',
#  'sepuruh = seluruh',
#  'hhahaha = alah',
#  'ases = habis',
#  'bukanya = bukannya',
#  'pengembangnya = mengomongnya',
#  'berbagilahtoh = berbakti',
#  'seisinyapaling = menyamakan',
#  'matipun = mati-matian',
#  'kepake = pakai',
#  '2x1 = tak',
#  'imb = mbak',
#  'segalaasal = segala-galanya',
#  'amplopnya = amplop',
#  'imbgila = sambil',
#  'bpn = bukan',
#  'tidah = sudah',
#  'kuhperd = bawa perasaan',
#  'ditutupwalaupun = ditutupi',
#  'bpn = bukan',
#  'bdg = bilang',
#  'wakafkan = kakak',
#  'pahalanya = pacarannya',
#  'keliang = kalian',
#  'masya = masih',
#  'ridwan = badan',
#  'kamil = kamu',
#  'uler = boleh',
#  'angep2 = aneh-aneh',
#  'ridwan = badan',
#  'kamil = kamu',
#  'akheratnya = syaratnya',
#  'pemdarmh = pemainnya',
#  'bakarntr = bakar-bakari',
#  'rumay = gemas',
#  'hotman = botak',
#  'paris = persis',
#  'joni = jangan',
#  'expose = apa',
#  'ituud83dude01 = itu',
#  'semenrara = sementara',
#  'siksa = dikasih',
#  'akherat = akhirat',
#  'bedoa = beda',
#  'diijabah = dah',
#  'gabener = benar',
#  'gangnya = anaknya',
#  'kosongnya = komentarnya',
#  'setapaknya = segala-galanya',
#  'imb = mbak',
#  'imb = mbak',
#  'gub = hubungi',
#  'ridwan = badan',
#  'kamil = kamu',
#  'aparat2 = parah-parah',
#  'emil = sambil',
#  'lain2 = main-main',
#  'hadewww = aduh',
#  'emil = sambil',
#  'cus = cuma',
#  'emil = sambil',
#  'ajabiar = saja',
#  'lahatnya = lihatnya',
#  'ktp = tapi',
#  'selonjoran = benaran',
#  'tanak = kak',
#  'sejengkal = senangi',
#  'pastinyaud83dude00 = cantiknya',
#  'rk = kakak',
#  'dirubuhin = diputuskan',
#  'sertinya = sepertinya',
#  'ridwan = badan',
#  'kamil = kamu',
#  'jabar = jawaban',
#  'didzolimi = idola',
#  'ksalahan = kesalahan',
#  'misalakn = masalah',
#  'menngangu = memegang',
#  'kuburanya = dikuburnya',
#  'didepannya = dilihatnya',
#  'teriak2 = meriah',
#  'gietuh = begitu',
#  'ufffcufffc = lucu',
#  'ud83dude01 = duren',
#  'tetanga = memegang',
#  'ituamiinn = amin',
#  'taulah = enggak usah',
#  'biat = lihat',
#  'ngubur = mencebur',
#  'disertipikat = dibeginikan',
#  'perjuangankan = perjuangan',
#  'hartamu = ceritamu',
#  'nyati = mencari',
#  'keranah = karena',
#  'berung = beruntung',
#  'heterogen = setrong',
#  'masingmasing = maling',
#  'wataknya = kata-katanya',
#  'masingmasing = maling',
#  'lsolusi = asli',
#  'desisi = disisi',
#  'lamakelamaan = sama',
#  'ilahi = hilang',
#  'ame = sama',
#  'rukyah = sudah',
#  'menyang = memegang',
#  'tahak = kak',
#  'rebusan = seru-seruan',
#  'sirih = sih',
#  'mashook = masih',
#  'kirin = mengira',
#  'blkg = bilang',
#  'diwakafkan = dikatakan',
#  '2x = tak',
#  'sekalianjgn = sekalian',
#  'temboknyabenci = tembok',
#  'digencet = ingat',
#  'tahukan = tukang',
#  'imb = mbak',
#  'lokasibagaimana = bagaimana',
#  'hotman = botak',
#  'paris = persis',
#  'tolongi = menolong',
#  'obrak = banyak',
#  'abrik = adik',
#  'boro = boro-boro',
#  'boro = boro-boro',
#  'berung = beruntung',
#  'joni = jangan',
#  'ig = yang',
#  'hotman = botak',
#  'rezekinya = rezekinya',
#  'rt = ribu',
#  'dstrunya = waktunya',
#  'rk = kakak',
#  'tembuskan = terus-terusan',
#  'msyarakat = masyarakat',
#  'mendinga = mending',
#  'rejim = anjir',
#  'pidanakan = mendapatkan',
#  '667 = selamat',
#  'kuh = kah',
#  'rt = ribu',
#  'rw = ribu',
#  'agamahampuraaa = bagaimana',
#  'ud83dude02ud83dude02ud83dude02ud83dude02ud83dude02 = rindu',
#  'dterima = terima',
#  'bpn = bukan',
#  'sertifikat2 = sehat-sehat',
#  'pemiliki = memiliki',
#  'ahokmana = bagaimana',
#  'ahok = hendak',
#  'alhamdullih = alhamdulillah',
#  'jokowisama = bisa',
#  'ridwan = badan',
#  'kamil = kamu',
#  'belagu = membela',
#  'disikat = dilihat',
#  'instropeksi = stres',
#  'sejahat = kejahatan',
#  'rt = ribu',
#  'rw = ribu',
#  'hmmm = memang',
#  'maaalah = masalah',
#  'winwin = pengin',
#  'coin = cinta',
#  'nyogok = ayo',
#  'imb = mbak',
#  'satpol = sampai',
#  'pp = tapi',
#  'ngawasin = mengapai',
#  'mustinya = testimoninya',
#  'pidanakan = mendapatkan',
#  'semenamena = berteman',
#  'ud83dude01ud83dude01 = dulu',
#  'cengeng = pengin',
#  'egodan = badan',
#  'shm = sama',
#  'merubuhkan = mudah-mudahan',
#  'nutupi = menutupi',
#  'uupa = apa',
#  'sosialini = menyisakan',
#  'seenak = sebanyak',
#  'udel = sudah',
#  'baerani = berani',
#  'tersebuttjangan = kesenangan',
#  'janganahh = jangan-jangan',
#  'kuhp = tuh',
#  'bertegur = bentar',
#  'memag = memegang',
#  'berkerpimanusiaan = pengin',
#  'naon = menonton',
#  'wae = saja',
#  'masalahna = masalah',
#  'nutupna = lucunya',
#  'bagong = bohong',
#  'teu = itu',
#  'ngalieuk = mengambek',
#  'tangkurakna = teguran-teguran',
#  'ngaliwat = melihat',
#  'nincak = mengakak',
#  'batur = banget',
#  'bangpak = bangsat',
#  'tulak = pula',
#  'bantingkeun = bandingkan',
#  'punyaimb = punya',
#  'purnomo = promo',
#  'baikaamiinsabar = bagaimana',
#  'ngebangun = membantu',
#  'antaranusia = menyarankan',
#  'bettetanngga = kelihatannya',
#  'rt = ribu',
#  'rw = ribu',
#  'mbangun = bangun',
#  'raumah = enggak usah',
#  'bpn = bukan',
#  'biasay = biasa-biasa',
#  'shm = sama',
#  'harysnya = harusnya',
#  '60cm = cuma',
#  'ntk = cantik',
#  'rt = ribu',
#  'rw = ribu',
#  'budek = bulat',
#  'tetangganyatrus = kebanggaan',
#  'pertanahangmn = penasaran',
#  'horang = orang',
#  'lol = loh',
#  'wkwkwk = wow',
#  'maukah = enggak usah',
#  'modar = muda',
#  'murahpakai = durhaka-durhaka',
#  'begitudugaan = sebegitunya',
#  'imb = mbak',
#  'meteramal = mereka',
#  'seblum = sebelum',
#  'fairsblum = sebelum',
#  'ajapasti = awas',
#  'imb = mbak',
#  'imb = mbak',
#  'imb = mbak',
#  'mebangun = memegang',
#  'melapang = memegang',
#  'viralin = mengira',
#  'imbnya = jamnya',
#  'kuh = kah',
#  'servituut = seru',
#  'hukumbagaiman = kuberikan',
#  'gank = enggak',
#  'kepakek = pakai',
#  'ngebangun = membantu',
#  'imb = mbak',
#  'rt = ribu',
#  'lebuh = lebih',
#  'kedirinya = sendirinya',
#  'manysia2 = manusia',
#  'tamak = kak',
#  'ati = satu',
#  'bihongi = banget',
#  'ane = saja',
#  'gan = enggak',
#  'ane = saja',
#  'tempok = tembok',
#  'ane = saja',
#  'ane = saja',
#  'ane = saja',
#  'buangnya = barangnya',
#  'ane = saja',
#  'kesel = kali',
#  'beberpa = keberapa',
#  'ane = saja',
#  'mgaku = mengaku',
#  'ane = saja',
#  'kesel = kali',
#  'ds = bisa',
#  'puspasari = penasaran',
#  'kranggan = kebanggaan',
#  'citeurep = tetap',
#  'cibinong = bohong',
#  'ttangga = tinggi',
#  'belakangdapur = berangkat',
#  'heraan = pekerjaan',
#  'kmanusian = kasihan',
#  'bdempetan = menyempatkan',
#  'kluarmsk = keluarga',
#  'mentang2 = mentang-mentang',
#  'pikip = sip',
#  'kebakar = terbalas',
#  'siap2 = siapa-siapa',
#  'laknat = enggak kuat',
#  'emil = sambil',
#  'gub = hubungi',
#  'nyelesaikannya = menyelesaikan',
#  'penembokan = tembok',
#  'apes = habis',
#  'digencet = ingat',
#  'u2063pasal = juga',
#  '667 = selamat',
#  'kuhperdata = keberapa',
#  'u201cpemilik = cantik',
#  'tanahtanah = tentang',
#  'pemilikpemilik = memiliki',
#  'pekarangannya = kekurangannya',
#  'diakibatkannyau201d = diakibatkan',
#  'google = boleh',
#  'dimana2sejengkal = menyenangkan',
#  'kesel = kali',
#  'sosialny = soalnya',
#  'ngepung = mengomong',
#  'kompeni = komentar',
#  'mustinya = testimoninya',
#  'mendzalimi = memendam',
#  'ane = saja',
#  'ane = saja',
#  'ane = saja',
#  'betawi = berarti',
#  'mendzalimi = memendam',
#  'ane = saja',
#  'ane = saja',
#  'ane = saja',
#  'betawi = berarti',
#  'mafianya = kakaknya',
#  'pastimasa = pasti',
#  'pertanyaanya = pertamanya',
#  'imbnya = jamnya',
#  'imb = mbak',
#  'rtrw = terus',
#  'masingmasing = maling',
#  'alasanya = kakaknya',
#  'masingmasing = maling',
#  'apayang = sayang',
#  'ngebangun = membantu',
#  'imb = mbak',
#  'imb = mbak',
#  'akira = acara',
#  'belakangpegawai = belanja',
#  'imb = mbak',
#  'imb = mbak',
#  'imb = mbak',
#  'rt = ribu',
#  'tuatanah = tentang',
#  'sosialpernah = enggak pernah',
#  'ngalami = mengalahkan',
#  'tetanggadia = tengah',
#  'belakangtanah = belanja',
#  'belitapi = kelihatan',
#  'ditanah = dimana-mana',
#  'kanginsya = cantiknya',
#  'solusinyaini = sekalinya',
#  'ujiansabar = kebiasaan',
#  'kangterus = memantas',
#  'solusiyakin = memperlihatkan',
#  'solusinyaaamiin = sekalinya',
#  'dzolim = dalam',
#  'dimuka = bagaimana',
#  'setega = semoga',
#  'ituketerlaluan = kelakuan',
#  'kudu = ku',
#  'dilapangkan = diluangkan',
#  'tega2nya = tiga-tiganya',
#  'menyempitkan = menyenangkan',
#  'taroin = tahun',
#  'uler = boleh',
#  'uler = boleh',
#  'uler = boleh',
#  'uler = boleh',
#  'hehe = eh',
#  'cadas = enggak ada',
#  'setujubuat = setuju',
#  'imb = mbak',
#  'kanankiri = nanti',
#  'imb = mbak',
#  'distarcip = diajari',
#  'bandungterus = banget',
#  'kepolisiandemikian = kelihatan',
#  'sayasalam = saya',
#  'ghe = deh',
#  'ngebangun = membantu',
#  'imb = mbak',
#  'imb = mbak',
#  'kirikanan = kelihatan',
#  'depanbelakang = melarang',
#  'bossss = mas',
#  'karma = karena',
#  'tnggal = tanggal',
#  'aing = anjing',
#  'kumaha = kemana',
#  'aing = anjing',
#  'denahnya = namanya',
#  'memneli = membela',
#  'jalannnyasetelah = jalan-jalannya',
#  'ngebangun = membantu',
#  'sekalihatinya = melihatnya',
#  'tertutupduniawi = kerudungan',
#  'mengerikannya = mangkanya',
#  'swt = buat',
#  'kepengadilan = pengin',
#  'dikwalifikasikan = dibeginikan',
#  'kerumah = seru-seruan',
#  'bpn = bukan',
#  'ases = habis',
#  'imb = mbak',
#  'imb = mbak',
#  'tongkol = tanggal',
#  'savage = sampai',
#  'semrawutnya = syaratnya',
#  'rt = ribu',
#  'rw = ribu',
#  'jelasjelas = jelas',
#  'kuhp = tuh',
#  'bono = sono',
#  'bpn = bukan',
#  'hubunganya = hubungan',
#  'trdahulu = terlalu',
#  'tawarin = menawari',
#  'mudahmudahan = mudah-mudahan',
#  'kirakira = mengira',
#  'imb = mbak',
#  'bijitrus = terus',
#  'taro = entar',
#  'uler = boleh',
#  'fpi = tapi',
#  'fbr = sabar',
#  'wakakaka = kakak',
#  'pejabatnyahalo = kebayanya',
#  'emil = sambil',
#  'disadarkannya = kehadirannya',
#  'psl = pasti',
#  '667 = selamat',
#  '668 = selamat',
#  'kuhperdata = keberapa',
#  'kitaaminnn = amin',
#  'imb = mbak',
#  'berkuasasemoga = berkeluarga',
#  'sepaket = sempat',
#  'persenanjasa = mereka',
#  'dijatuhin = diputuskan',
#  'sampingnyaagar = gantengnya',
#  'kasihlah = kasihan',
#  'setapakjahat = tetaplah',
#  'dimusuhin = dimuseumkan',
#  'walkot = warung kopi',
#  'wkwkwkw = wow',
#  'greget = greget',
#  'wkwkwk = wow',
#  'ngandelin = mengantarkan',
#  'jegat = juga',
#  'skalian = kasihan',
#  'aizin = amin',
#  'rw = ribu',
#  'semeteran = benaran',
#  'rt = ribu',
#  'ngebangun = membantu',
#  'jahatnya = kakaknya',
#  'buminya = jamnya',
#  'bersama2 = bersama',
#  'keegoisan = mengepoi',
#  'keserakahan = keberkahan',
#  'berlembut = perebut',
#  'tjd = tadi',
#  'tamak = kak',
#  'apkh = apa',
#  'prgkt = banget',
#  'ridwan = badan',
#  'kamil = kamu',
#  'nytega = mencela',
#  'gusti = pasti',
#  'rezekinya = rezekinya',
#  'orang2x = orang-orang',
#  'kepung = kandung',
#  'rmhnya = jamnya',
#  'moga = semoga',
#  'emanh = memang',
#  'kadang2 = barang-barang',
#  'bangung = bangun',
#  'rt = ribu',
#  'rw = ribu',
#  'knapa = kenapa',
#  'ud83dude2bud83dude2d = terburu-buru',
#  'pemkotnya = pokoknya',
#  'imb = mbak',
#  'imb = mbak',
#  'imb = mbak',
#  'terbengkalaiu3002u3002gawat = mereka',
#  'amatsedih = terima kasih',
#  'negeriku = ngeri',
#  ...]
